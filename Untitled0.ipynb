# %% [markdown]
# <a href="https://colab.research.google.com/github/sonigay/qna/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 221kB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 10.1MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/04/90/a94a55a58edfd67360fef85894bfb136a2c28b2cc7227d3a44dc508d5900/JPype1-0.7.1-cp36-cp36m-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 51.8MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.17.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: beautifulsoup4, tweepy, JPype1, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-0.7.1 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.8.0

# %%
import os
import warnings
from gensim.models import doc2vec
from gensim.models.doc2vec import TaggedDocument
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.3)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.8.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.17.5)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.1)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)

# %%
import jpype
from konlpy.tag import Kkma

# %%
kkma = Kkma()

noun_kkm = ['NNP', 'NNG', 'OL']

def tokenize_kkma(doc):
    jpype.attachThreadToJVM()
    token_doc = ['/'.join(word) for word in kkma.pos(doc) if word[1] in noun_kkm ]
    return token_doc

# %%
import pandas as pd

df_faq = pd.read_csv(os.path.join('data', '/content/drive/My Drive/test.csv'), encoding='CP949')

# %%
#@title
df_faq[['제목', '내용']]
# Out:
#                                                     제목                                                 내용
# 0            1주택수가구 요금을 적용받고 있는데 가구수가 감소하면 어떻게 해야 합니까.  1주택수가구 요금을 적용받던 고객이 세입자 전출등 가구수가 감소하는 경우에는 1개월...
# 1    고객이 임시공급설비 설치공사비를 부담하여 한전에서 임시공급설비를 시설하였을 경우의 ...  임시공급설비를 한전에서 설치할 경우에는 상시전력 공급설비의 수급지점과 동일하게하여 ...
# 2                 변압기공동이용(모자거래)이란 무엇이며, 요금계산은 어떻게 합니까.  동일 전기사용장소내에 전기사용용도(계약종별)가 다르거나 회계단위가 상이한 2이상의 ...
# 3    공장을 새로 짓는데 옆 공장에서 변압기용량이 남는다고 하여 일부를 연결하여 같이 사...  동일한 전기사용 장소내에서 전기를 사용하고 계약종별 또는 회계단위가 상이한 2이상의...
# 4                   전기설비중 냉·난방기기가 있는데 계약전력은 어떻게 산정합니까.  여름철에만 사용하는 설비와 겨울철에만 사용하는 설비가 1Set로 구성되어 냉난방용 ...
# ..                                                 ...                                                ...
# 346                                   전기공급약관을 보고 싶습니다.  전기공급약관은 `전력거래약관(새창열림)`href=`http://cyber.kepco...
# 347                             법인회원으로 가입하는 방법을 알려주세요.  개인회원으로 가입하신 후, `기업서비스이용신청(새창열림)`href=`https://...
# 348                              전기요금을 미리 계산해 볼 수 있나요.  `전기요금계산기(새창열림)`href=`http://cyber.kepco.co.kr/...
# 349              아파트 관리사무소입니다. 종합계약과 단일계약을 비교해보고 싶습니다.  `아파트·오피스텔요금비교(새창열림)`href=`http://cyber.kepco.c...
# 350                         고객번호란 무엇이고, 어떻게 확인할 수 있나요.  ○ 고객번호는 전기사용 계약단위별로 부여되는 고유번호입니다. 전기요금 청구서 우측 ...
#
# [351 rows x 2 columns]

# %%
df_faq[['제목', '내용']]

# [index, 형태소분석(질문), 답]

pre_faqs = []
for i in range(len(df_faq)):
      pre_faqs.append([i, tokenize_kkma(df_faq['제목'][i]), df_faq['내용'][i]])

# %%
tagged_faqs = [TaggedDocument(c, [d]) for d, c, a in pre_faqs]

# %%
tagged_faqs
# Out:
# [TaggedDocument(words=['주택/NNG', '수가/NNG', '구/NNG', '요금/NNG', '적용/NNG', '가구/NNG', '수가/NNG', '감소/NNG'], tags=[0]),
#  TaggedDocument(words=['고객/NNG', '임시/NNG', '공급/NNG', '설비/NNG', '설치/NNG', '공사비/NNG', '부담/NNG', '한전/NNG', '임시/NNG', '공급/NNG', '설비/NNG', '시설/NNG', '경우/NNG', '임시/NNG', '공급/NNG', '설비/NNG', '유지/NNG', '보수/NNG', '책임/NNG', '한계점/NNG'], tags=[1]),
#  TaggedDocument(words=['변압기/NNG', '공동/NNG', '이용/NNG', '모자/NNG', '거래/NNG', '요금/NNG', '계산/NNG'], tags=[2]),
#  TaggedDocument(words=['공장/NNG', '옆/NNG', '공장/NNG', '변압기/NNG', '용량/NNG', '일부/NNG', '연결/NNG', '사용/NNG'], tags=[3]),
#  TaggedDocument(words=['전기/NNG', '설비/NNG', '중/NNG', '냉/NNG', '난방/NNG', '기기/NNG', '계약/NNG', '전력/NNG', '산정/NNG'], tags=[4]),
#  TaggedDocument(words=['고압/NNG', '전기/NNG', '공급/NNG', '계약/NNG', '전력/NNG', 'kW/OL', '인/NNG', '공장/NNG', '한전/NNG', '최대/NNG', '수요/NNG', '전력/NNG', '증설/NNG', '안내문/NNG', '조치/NNG'], tags=[5]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', 'kW/OL', '신청/NNG', '수전/NNG', '변압기/NNG', '설치/NNG', '저압/NNG', '계량/NNG', '가능/NNG'], tags=[6]),
#  TaggedDocument(words=['주택/NNG', '임시/NNG', '전력/NNG', '별도/NNG', '신청/NNG', '전기/NNG', '사용/NNG'], tags=[7]),
#  TaggedDocument(words=['동일/NNG', '구내/NNG', '공장/NNG', '증축/NNG', '임시/NNG', '전력/NNG', '신청/NNG', '기존/NNG', '구좌/NNG', '전기/NNG', '이용/NNG', '건물/NNG', '증축/NNG'], tags=[8]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '신규/NNG', '고객/NNG', '고객/NNG', '모든/NNP', '시설/NNG', '부담금/NNG', '부담/NNG', '별도/NNG', '보증금/NNG', '납/NNG', '부하/NNG'], tags=[9]),
#  TaggedDocument(words=['신축/NNG', '건물/NNG', '전기/NNG', '사용/NNG', '신청/NNG', '지중/NNG', '배전/NNG', '지역/NNG', '고시/NNG', '지중/NNG', '배/NNG', '전선로/NNG', '전기/NNG', '공급/NNG', '공중전/NNG', '선로/NNG', '전기/NNG', '공급/NNG'], tags=[10]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '외선/NNG', '공사/NNG', '전기/NNG', '사용자/NNG', '시공/NNG', '경우/NNG', '신청/NNG', '절차/NNG', '만일/NNG', '활/NNG', '선/NNG', '공사/NNG', '수반/NNG', '경우/NNG', '활/NNG', '선/NNG', '공사/NNG', '한전/NNG', '시공/NNG'], tags=[11]),
#  TaggedDocument(words=['일반용/NNG', '전기/NNG', '설비/NNG', '자가용/NNG', '전기/NNG', '설비/NNG', '각각/NNG', '대상/NNG'], tags=[12]),
#  TaggedDocument(words=['상가/NNG', '부/NNG', '공동/NNG', '주택/NNG', '상점/NNG', '주택/NNG', '구분/NNG', '별도/NNG', '계량기/NNG'], tags=[13]),
#  TaggedDocument(words=['계약/NNG', '전력/NNG', 'kW/OL', '이상인/NNP', '건물/NNG', '부동산/NNG', '임대업/NNG', '건물/NNG', '소유자/NNG', '층/NNG', '별/NNG', '계량기/NNG'], tags=[14]),
#  TaggedDocument(words=['다세대/NNG', '주택/NNG', '연립/NNG', '주택/NNG', '전문/NNG', '건축/NNG', '건설/NNG', '회사/NNG', '주택/NNG', '준공/NNG', '현재/NNG', '미분양/NNG', '상태/NNG', '호별/NNG', '계량기/NNG'], tags=[15]),
#  TaggedDocument(words=['계약/NNG', '전력/NNG', '계량기/NNG', '용량/NNG', '선정/NNG', '계약/NNG', '전력/NNG', '증설/NNG', '시/NNG', '계량기/NNG', '교환/NNG'], tags=[16]),
#  TaggedDocument(words=['행사장/NNG', '며칠/NNG', '임시/NNG', '전력/NNG', '사용/NNG', '계량기/NNG', '설치/NNG', '전기/NNG', '요금/NNG', '계산/NNG', '방법/NNG'], tags=[17]),
#  TaggedDocument(words=['현재/NNG', '옆/NNG', '건물/NNG', '전기/NNG', '사용/NNG', '가두/NNG', '판매대/NNG', '계량기/NNG', '별도/NNG', '전기/NNG', '사용/NNG'], tags=[18]),
#  TaggedDocument(words=['가구/NNG', '제조/NNG', '공장/NNG', '등록/NNG', '건물/NNG', '임차/NNG', '후/NNG', '건축물/NNG', '관리/NNG', '대장/NNG', '열람/NNG', '건축물/NNG', '용도/NNG', '축사/NNG', '전기/NNG', '공급/NNG', '가능/NNG'], tags=[19]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '전과/NNG', '수급/NNG', '지점/NNG', '수급/NNG', '지점/NNG'], tags=[20]),
#  TaggedDocument(words=['주택/NNG', '신축/NNG', '현장/NNG', '전기/NNG', '사용/NNG', '이웃집/NNG', '전기/NNG', '연결/NNG', '사용/NNG'], tags=[21]),
#  TaggedDocument(words=['엘리베이터/NNG', '층/NNG', '사무실/NNG', '임대/NNG', '빌딩/NNG', '신축/NNG', '층/NNG', '별/NNG', '계량기/NNG'], tags=[22]),
#  TaggedDocument(words=['수중/NNG', '전동기/NNG', '일반/NNG', '전동기/NNG', '방법/NNG', '계약/NNG', '전력/NNG', '산정/NNG', '구체적/NNG'], tags=[23]),
#  TaggedDocument(words=['신축/NNG', '건물/NNG', '고압/NNG', '전기/NNG', '공급/NNG', '변압기/NNG', '설치/NNG', '변압기/NNG', '용량/NNG', '표시/NNG', '표시/NNG', '변압기/NNG', '설비/NNG', '계약/NNG', '경우/NNG', '계약/NNG', '전력/NNG'], tags=[24]),
#  TaggedDocument(words=['계약/NNG', '전력/NNG', 'kW/OL', '초과/NNG', '대/NNG', '단위/NNG', '공장/NNG', '건립/NNG', 'V/OL', '전기/NNG', '공급/NNG', '900V-y/OL', '공급/NNG', '방법/NNG'], tags=[25]),
#  TaggedDocument(words=['W/OL', 'V/OL', '공급/NNG', '식당/NNG', '에어콘/NNG', '설치/NNG', '에어컨/NNG', '계량기/NNG', '별도/NNG', '부착/NNG'], tags=[26]),
#  TaggedDocument(words=['대지/NNG', '쓰레기/NNG', '처리장/NNG', '건립/NNG', '처리/NNG', '장내/NNG', '하천/NNG', '경우/NNG', '계량/NNG', '전기/NNG', '공급/NNG'], tags=[27]),
#  TaggedDocument(words=['저압/NNG', '특별/NNG', '고압/NNG', '구분/NNG', '말씀/NNG'], tags=[28]),
#  TaggedDocument(words=['계량기/NNG', '집이/NNG', '전기/NNG', '세입자/NNG', '전기/NNG', '요금/NNG', '분쟁/NNG', '한전/NNG', '계량기/NNG', '전기/NNG', '요금/NNG', '청구서/NNG', '가구/NNG'], tags=[29]),
#  TaggedDocument(words=['시의/NNG', '양수/NNG', '목적/NNG', '관정/NNG', '설치/NNG', '전동기/NNG', '명판/NNG', '표시/NNG', '단상/NNG', '공급/NNG'], tags=[30]),
#  TaggedDocument(words=['아파트/NNG', '전기/NNG', '사용/NNG', '계약/NNG', '방법/NNG'], tags=[31]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '약관/NNG', '적용/NNG', '구역/NNG'], tags=[32]),
#  TaggedDocument(words=['대형/NNG', '음식점/NNG', '냉장고/NNG', '에어콘/NNG', '설비/NNG', '전기/NNG', '사용/NNG', '설비/NNG', '용량/NNG', 'kW/OL', '정도/NNG', '저압/NNG', '공급/NNG'], tags=[33]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신청/NNG', '취소/NNG', '신청/NNG', '경우/NNG', '전기/NNG', '사용/NNG', '신청서/NNG', '구비/NNG', '서류/NNG', '제출/NNG'], tags=[34]),
#  TaggedDocument(words=['특수/NNG', '사용/NNG', '설비/NNG', '전기용접기/NNG', '의/NNG', '전기/NNG', '사용/NNG', '신청/NNG', '절차/NNG'], tags=[35]),
#  TaggedDocument(words=['태양광/NNG', '발전/NNG', '절차/NNG'], tags=[36]),
#  TaggedDocument(words=['공장/NNG', '이전/NNG', '전기/NNG', '설비/NNG', '사용/NNG'], tags=[37]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신설/NNG'], tags=[38]),
#  TaggedDocument(words=['건축물/NNG', '관련/NNG', '증빙/NNG', '서류/NNG', '무허가/NNG', '건물/NNG', '경우/NNG', '전기/NNG', '사용/NNG', '신청/NNG'], tags=[39]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신청/NNG', '후/NNG', '사정/NNG', '취소/NNG', '한/NNG', '납부/NNG', '시설/NNG', '부담금/NNG', '환불/NNG'], tags=[40]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신청/NNG', '후/NNG', '사/NNG', '정상/NNG', '신청/NNG', '내용/NNG', '변경/NNG'], tags=[41]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신청/NNG', '건물/NNG', '준공/NNG', '전기/NNG', '사용/NNG', '개시일/NNG', '연기/NNG'], tags=[42]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '신청/NNG', '며칠/NNG', '안/NNG', '전기/NNG', '공급/NNG'], tags=[43]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '사용/NNG', '빌딩/NNG', '공사장/NNG', '계약/NNG', '전력/NNG', 'kW/OL', 'kW/OL', '증설/NNG', '경우/NNG', '추가/NNG', '보증금/NNG', '납부/NNG'], tags=[44]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '해지/NNG', '상시/NNG', '전력/NNG', '수전/NNG', '경우/NNG', '납부/NNG', '임시/NNG', '전력/NNG', '보증금/NNG', '환불/NNG'], tags=[45]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '신청/NNG', '고객/NNG', '보증금/NNG', '현금/NNG', '예치/NNG', '대신/NNP', '이행/NNG', '보증/NNG', '보험/NNG', '증권/NNG', '제출/NNG', '보험/NNG', '내용/NNG', '기재/NNG'], tags=[46]),
#  TaggedDocument(words=['보증금/NNG', '납부/NNG', '대상/NNG', '금액/NNG', '보증/NNG', '기간/NNG', '환불/NNG'], tags=[47]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '사용시/NNG', '납부/NNG', '보증금/NNG', '산정/NNG'], tags=[48]),
#  TaggedDocument(words=['건축/NNG', '공사/NNG', '임시/NNG', '전력/NNG', '공급/NNG', '설비/NNG', '설치/NNG', '시설/NNG', '부담금/NNG', '전기/NNG', '사용자/NNG', '전액/NNG', '부담/NNG', '준공/NNG', '후/NNG', '상시/NNG', '전력/NNG', '시설/NNG', '부담금/NNG', '부담/NNG', '고객/NNG', '이중/NNG', '부담/NNG'], tags=[49]),
#  TaggedDocument(words=['공급/NNG', '설비/NNG', '변경/NNG', '경우/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[50]),
#  TaggedDocument(words=['건설/NNG', '공사장/NNG', '전기/NNG', '필요/NNG', '임시/NNG', '전력/NNG', '사용/NNG', '임시/NNG', '공급/NNG', '설비/NNG', '한전/NNG', '시설/NNG', '경우/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[51]),
#  TaggedDocument(words=['공중/NNG', '고압/NNG', '계약/NNG', '전력/NNG', 'kW/OL', '전기/NNG', '공급/NNG', '공장/NNG', '사업/NNG', '부진/NNG', '저압/NNG', 'kW/OL', '납부/NNG', '시설/NNG', '부담금/NNG', '얼마/NNG'], tags=[52]),
#  TaggedDocument(words=['단상/NNG', 'V/OL', '공급/NNG', '영업장/NNG', '삼상/NNG', 'V/OL', '대형/NNG', '냉장고/NNG', '설치/NNG', '계약/NNG', '전력/NNG', '변경/NNG', '공급/NNG', '방식/NNG', '변경/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[53]),
#  TaggedDocument(words=['고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '정산/NNG', '대상/NNG', '방법/NNG'], tags=[54]),
#  TaggedDocument(words=['고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '적용/NNG', '종류/NNG', '산정/NNG'], tags=[55]),
#  TaggedDocument(words=['지중/NNG', '확정/NNG', '지역/NNG', '저압/NNG', '신규/NNG', '사용/NNG', '신청/NNG', '시/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[56]),
#  TaggedDocument(words=['표준/NNG', '시설/NNG', '부담금/NNG', '단가/NNG', '조정/NNG', '경우/NNG'], tags=[57]),
#  TaggedDocument(words=['지은/NNG', '빌딩/NNG', '시설/NNG', '한전/NNG', '소유/NNG', '관로/NNG', '이용/NNG', '전기/NNG', '공급/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '납부/NNG'], tags=[58]),
#  TaggedDocument(words=['마을/NNG', '논/NNG', '개간/NNG', '산/NNG', '대책/NNG', '관정/NNG', '집단/NNG', '신청/NNG', '경우/NNG', '거리/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[59]),
#  TaggedDocument(words=['건물/NNG', '지중/NNG', '공급/NNG', '지역/NNG', '저압/NNG', 'kW/OL', '정도/NNG', '전기/NNG', '필요/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[60]),
#  TaggedDocument(words=['전기/NNG', '신규/NNG', '사용/NNG', '신청/NNG', '시/NNG', '고객/NNG', '장소/NNG', '일반/NNG', '전기/NNG', '사업자/NNG', '한전/NNG', '부담/NNG', '전기/NNG', '설비/NNG', '가설/NNG', '생각/NNG', '고객/NNG', '시설/NNG', '부담금/NNG', '부담/NNG'], tags=[61]),
#  TaggedDocument(words=['일반/NNG', '공급/NNG', '설비/NNG', '무엇/NNG', '경우/NNG', '고객/NNG', '부담금/NNG', '산정/NNG'], tags=[62]),
#  TaggedDocument(words=['공장/NNG', '규모/NNG', '대/NNG', '단위/NNG', '여/NNG', 'V/OL', '전기/NNG', '공급/NNG', '경우/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[63]),
#  TaggedDocument(words=['현금/NNG', '시설/NNG', '부담금/NNG', '납부/NNG', '현금/NNG', '영수증/NNG', '발행/NNG'], tags=[64]),
#  TaggedDocument(words=['사용/NNG', '동력/NNG', '구좌/NNG', '해지/NNG', '신청/NNG', '전기/NNG', '사용/NNG', '신청/NNG', '당시/NNG', '한전/NNG', '납부/NNG', '시설/NNG', '부담금/NNG', '환불/NNG'], tags=[65]),
#  TaggedDocument(words=['공장/NNG', '세/NNG', '저압/NNG', '단상/NNG', 'kW/OL', '신규/NNG', '사용/NNG', '신청/NNG', '사/NNG', '정상/NNG', '저압/NNG', 'kW/OL', '변경/NNG', '신청/NNG', '한전/NNG', '변압기/NNG', '설치/NNG', '공사/NNG', '완료/NNG', '경우/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '산정/NNG'], tags=[66]),
#  TaggedDocument(words=['고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '일시/NNG', '납부/NNG', '부담/NNG', '분할/NNG', '납부/NNG', '가능/NNG'], tags=[67]),
#  TaggedDocument(words=['일반용/NNG', '전기/NNG', '설비/NNG', '사용/NNG', '전/NNG', '점검/NNG', '대상/NNG', '절차/NNG'], tags=[68]),
#  TaggedDocument(words=['사용/NNG', '전/NNG', '검사/NNG', '시/NNG', '고객/NNG', '준비/NNG', '사항/NNG', '고압/NNG', '이상/NNG', '전기/NNG', '기계/NNG', '기구/NNG', '시험/NNG', '성적/NNG', '구체적/NNG', '무엇/NNG'], tags=[69]),
#  TaggedDocument(words=['지은/NNG', '주택/NNG', '전기/NNG', '공사/NNG'], tags=[70]),
#  TaggedDocument(words=['주택/NNG', '신축/NNG', '전기/NNG', '내선/NNG', '공사/NNG', '건축주/NNG', '계량기/NNG', '배선/NNG', '한전/NNG', '공사/NNG', '건축/NNG', '주가/NNG', '공사/NNG', '사실/NNG'], tags=[71]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '전기/NNG', '사용/NNG', '계약/NNG', '성립/NNG', '시기/NNG', '최초/NNG', '전기/NNG', '사용/NNG', '개시일/NNG', '결정/NNG', '기준/NNG'], tags=[72]),
#  TaggedDocument(words=['태풍/NNG', '집중/NNG', '호우/NNG', '재난/NNG', '이재민/NNG', '고객/NNG', '전기/NNG', '요금/NNG', '납기/NNG', '일/NNG', '연장/NNG', '한국/NNG', '전력/NNG', '공사/NNG', '전기/NNG', '공급/NNG', '약관/NNG', '준수/NNG', '의무/NNG', '위배/NNG'], tags=[73]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '약관/NNG', '명시/NNG', '사항/NNG', '결정/NNG'], tags=[74]),
#  TaggedDocument(words=['외국/NNG', '제조/NNG', '기기/NNG', '도입/NNG', '사용/NNG', '전압/NNG', '전기/NNG', '공급/NNG', '약관/NNG', '규정/NNG', '전기/NNG', '공급/NNG', '전압/NNG', '이외/NNG', '전압/NNG', '기기/NNG', '사용/NNG', '전압/NNG', '일치/NNG', '공급/NNG', '전압/NNG', '전기/NNG', '공급/NNG'], tags=[75]),
#  TaggedDocument(words=['예비/NNG', '전력/NNG'], tags=[76]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '약관/NNG', '한국/NNG', '전력/NNG', '공사/NNG', '내부/NNG', '제정/NNG', '규정/NNG', '전기/NNG', '사용자/NNG', '불리/NNG', '조건/NNG', '강제/NNG', '준수/NNG', '전기/NNG', '사업/NNG', '독점/NNG', '이용/NNG', '횡포/NNG'], tags=[77]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '약관/NNG', '제정/NNG', '개정/NNG', '절차/NNG'], tags=[78]),
#  TaggedDocument(words=['전기/NNG', '사용자/NNG', '명의/NNG', '변경/NNG'], tags=[79]),
#  TaggedDocument(words=['부친/NNG', '사망/NNG', '상속/NNG', '주택/NNG', '경우/NNG', '전기/NNG', '전화/NNG', '사용/NNG', '신청/NNG'], tags=[80]),
#  TaggedDocument(words=['매매/NNG', '임대차/NNG', '이사/NNG', '전기/NNG', '사용자/NNG', '경우/NNG', '명의/NNG', '변경/NNG', '전기/NNG', '요금/NNG', '정산/NNG', '하나/NNG'], tags=[81]),
#  TaggedDocument(words=['이메일/NNG', '청구서/NNG', '상/NNG', '고객/NNG', '명이/NNG', '실제/NNG', '수정/NNG'], tags=[82]),
#  TaggedDocument(words=['사업자/NNG', '등록증/NNG', '사본/NNG', '제출/NNG', '요청서/NNG', '공장/NNG', '한전/NNG', '사업자/NNG', '등록증/NNG', '사본/NNG', '제출/NNG'], tags=[83]),
#  TaggedDocument(words=['자동차/NNG', '관리법/NNG', '폐차장/NNG', '기타/NNG', '사업/NNG', '산업용/NNG', '전력/NNG', '적용/NNG', '자동차/NNG', '정비/NNG', '업체/NNG', '산업용/NNG', '요금/NNG', '적용/NNG'], tags=[84]),
#  TaggedDocument(words=['아파트/NNG', '구내/NNG', '도로/NNG', '설치/NNG', '조명등/NNG', '가로등/NNG', '요금/NNG', '적용/NNG', '지하/NNG', '주차장/NNG', '조명/NNG', '가로등/NNG', '요금/NNG', '적용/NNG'], tags=[85]),
#  TaggedDocument(words=['산업용/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '기타/NNG', '사업/NNG'], tags=[86]),
#  TaggedDocument(words=['주택/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '전기/NNG', '요금/NNG'], tags=[87]),
#  TaggedDocument(words=['논/NNG', '일부/NNG', '밭/NNG', '개조/NNG', '곳/NNG', '대책/NNG', '설치/NNG', '관정/NNG', '사용/NNG', '경우/NNG', '농/NNG', '사용/NNG', '전력/NNG', '갑/NNG', '계약/NNG', '종별/NNG', '적용/NNG'], tags=[88]),
#  TaggedDocument(words=['상수도/NNG', '수압/NNG', '고지대/NNG', '동네/NNG', '상수도/NNG', '가압/NNG', '장/NNG', '설치/NNG', '급수/NNG', '경우/NNG', '급수/NNG', '시설/NNG', '계약/NNG', '종별/NNG'], tags=[89]),
#  TaggedDocument(words=['홍수/NNG', '조절/NNG', '용/NNG', '배수/NNG', '펌프장/NNG', '배수/NNG', '펌프/NNG', '모터/NNG', '추가설치/NNG', '계약/NNG', '전력/NNG', 'kW/OL', 'kW/OL', '증설/NNG', '산업용/NNG', '전력/NNG', '을/NNG', '로/NNG', '적용/NNG'], tags=[90]),
#  TaggedDocument(words=['일반용/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '전기/NNG', '요금/NNG'], tags=[91]),
#  TaggedDocument(words=['근린/NNG', '생활/NNG', '시설/NNG', '상점/NNG', '부/NNG', '주택/NNG', '로/NNG', '허가/NNG', '건물/NNG', '일반용/NNG', '전력/NNG', '적용/NNG'], tags=[92]),
#  TaggedDocument(words=['민박/NNG', '주택/NNG', '전력/NNG', '일반용/NNG', '변경/NNG'], tags=[93]),
#  TaggedDocument(words=['장사/NNG', '주택/NNG', '전력/NNG', '요금/NNG', '부담/NNG', '일반용/NNG', '적용/NNG'], tags=[94]),
#  TaggedDocument(words=['행정/NNG', '관서/NNG', '허가/NNG', '정식/NNG', '등록/NNG', '음악/NNG', '미술/NNG', '학원/NNG', '교육/NNG', '적용/NNG'], tags=[95]),
#  TaggedDocument(words=['재택/NNG', '사업자/NNG', '주택/NNG', '누진제/NNG', '전기/NNG', '요금/NNG', '일반용/NNG', '전기/NNG', '요금/NNG', '적용/NNG'], tags=[96]),
#  TaggedDocument(words=['축산/NNG', '산업/NNG', '발전/NNG', '모/NNG', '현재/NNG', '산업용/NNG', '적용/NNG', '도축장/NNG', '농/NNG', '사용/NNG', '전력/NNG', '적용/NNG'], tags=[97]),
#  TaggedDocument(words=['과수원/NNG', '주거/NNG', '관리사/NNG', '현재/NNG', '공급/NNG', '농/NNG', '사용/NNG', '전력/NNG', '사용/NNG'], tags=[98]),
#  TaggedDocument(words=['현재/NNG', '농작물/NNG', '저온/NNG', '보관/NNG', '시설/NNG', '농/NNG', '사용/NNG', '적용/NNG', '수산물/NNG', '냉장/NNG', '저온/NNG', '보관/NNG', '시설/NNG', '농/NNG', '사용/NNG', '전력/NNG', '적용/NNG'], tags=[99]),
#  TaggedDocument(words=['지자체/NNG', '위탁/NNG', '청소년/NNG', '직업/NNG', '체험/NNG', '센터/NNG', '대안/NNG', '학교/NNG', '성격/NNG', '작업장/NNG', '학교/NNG', '개교/NNG', '영상/NNG', '디자인/NNG', '음악/NNG', '다양/NNG', '분야/NNG', '문화/NNG', '예술/NNG', '활동/NNG', '지원/NNG', '교육/NNG', '교육/NNG', '전력/NNG', '적용/NNG'], tags=[100]),
#  TaggedDocument(words=['공업/NNG', '고등학교/NNG', '산업용/NNG', '전력/NNG', '적용/NNG', '가능/NNG'], tags=[101]),
#  TaggedDocument(words=['공장/NNG', '곳/NNG', '양수장/NNG', '설치/NNG', '부족/NNG', '공업용수/NNG', '보충/NNG', '공장/NNG', '전기/NNG', '사용/NNG', '불가능/NNG', '별도/NNG', '전기/NNG', '사용/NNG', '경우/NNG', '계약/NNG', '종별/NNG'], tags=[102]),
#  TaggedDocument(words=['아파트/NNG', '주민/NNG', '공동/NNG', '사용/NNG', '오수/NNG', '정화/NNG', '시설/NNG', '상수도/NNG', '가압/NNG', '설비/NNG', '계약/NNG', '종별/NNG', '해당/NNG'], tags=[103]),
#  TaggedDocument(words=['세기/NNG', '부가/NNG', '가치/NNG', '핵심/NNG', '산업/NNG', '영상/NNG', '산업/NNG', '국제/NNG', '경쟁력/NNG', '강화/NNG', '영화/NNG', '필름/NNG', '복제/NNG', '업/NNG', '산업용/NNG', '요금/NNG', '적용/NNG'], tags=[104]),
#  TaggedDocument(words=['지역/NNG', '단위/NNG', '작목/NNG', '반/NNG', '감귤/NNG', '크기/NNG', '선/NNG', '과장/NNG', '운영/NNG', '감귤/NNG', '선/NNG', '과장/NNG', '농/NNG', '사용/NNG', '요금/NNG', '적용/NNG'], tags=[105]),
#  TaggedDocument(words=['백화점/NNG', '업무용/NNG', '건물/NNG', '민간/NNG', '시설/NNG', '야/NNG', '관/NNG', '경관/NNG', '조명/NNG', '시설/NNG', '가로등/NNG', '요금/NNG', '적용/NNG'], tags=[106]),
#  TaggedDocument(words=['전문/NNG', '매장/NNG', '인공/NNG', '빙벽/NNG', '암벽/NNG', '시설/NNG', '복합/NNG', '등산/NNG', '레저/NNG', '문화/NNG', '센터/NNG', '빙벽/NNG', '암벽/NNG', '교실/NNG', '운영/NNG', '교육/NNG', '전력/NNG', '적용/NNG'], tags=[107]),
#  TaggedDocument(words=['소외/NNG', '계층/NNG', '아동/NNG', '대상/NNG', '지역/NNG', '아동/NNG', '센터/NNG', '운영/NNG', '영/NNG', '유아/NNG', '보육/NNG', '시설/NNG', '교육/NNG', '전력/NNG', '적용/NNG'], tags=[108]),
#  TaggedDocument(words=['학점/NNG', '인정/NNG', '법률/NNG', '학습/NNG', '과정/NNG', '평가/NNG', '인정/NNG', '육군/NNG', '보병/NNG', '학교/NNG', '교육/NNG', '전력/NNG', '적용/NNG'], tags=[109]),
#  TaggedDocument(words=['계약/NNG', '종별/NNG', '결정/NNG', '원칙/NNG'], tags=[110]),
#  TaggedDocument(words=['공장/NNG', '사택/NNG', '경우/NNG', '사택/NNG', '계약/NNG', '종별/NNG', '주택/NNG', '산업용/NNG'], tags=[111]),
#  TaggedDocument(words=['계약/NNG', '종별/NNG', '변경/NNG'], tags=[112]),
#  TaggedDocument(words=['오수/NNG', '처리/NNG', '시설/NNG', '수질/NNG', '오염/NNG', '방지/NNG', '시설/NNG', '기타/NNG', '사업/NNG', '산업용/NNG', '전력/NNG', '적용/NNG', '고속도/NNG', '상의/NNG', '터널/NNG', '설치/NNG', '환기/NNG', '시설/NNG', '대기/NNG', '환경/NNG', '제공/NNG', '터널/NNG', '화재/NNG', '시/NNG', '소방/NNG', '설비/NNG', '기능/NNG', '공익/NNG', '시설/NNG', '산업용/NNG', '요금/NNG', '적용/NNG'], tags=[113]),
#  TaggedDocument(words=['지역/NNG', '경제/NNG', '활성화/NNG', '국가/NNG', '경쟁력/NNG', '제고/NNG', '전체/NNG', '항만/NNG', '물류/NNG', '시설/NNG', '산업용/NNG', '요금/NNG', '적용/NNG'], tags=[114]),
#  TaggedDocument(words=['청소년/NNG', '육성/NNG', '공익/NNG', '목적/NNG', '수행/NNG', '청소년/NNG', '수련/NNG', '시설/NNG', '교육/NNG', '요금/NNG', '적용/NNG'], tags=[115]),
#  TaggedDocument(words=['지자체/NNG', '조례/NNG', '설립/NNG', '학생/NNG', '외국어/NNG', '교육원/NNG', '교육/NNG', '전력/NNG', '적용/NNG'], tags=[116]),
#  TaggedDocument(words=['농업/NNG', '용수/NNG', '공급/NNG', '저수지/NNG', '수질/NNG', '개선/NNG', '녹조류/NNG', '제거/NNG', '산소/NNG', '공급/NNG', '분수/NNG', '시설/NNG', '고사/NNG', '분수/NNG', '농/NNG', '사용/NNG', '전력/NNG', '적용/NNG'], tags=[117]),
#  TaggedDocument(words=['농/NNG', '사용/NNG', '관정/NNG', '농/NNG', '사용/NNG', '요금/NNG', '적용/NNG', '농/NNG', '사용/NNG', '목적/NNG', '이외/NNG', '생활/NNG', '용수/NNG', '공급/NNG', '겸용/NNG', '이용/NNG', '관정/NNG', '농/NNG', '사용/NNG', '요금/NNG', '적용/NNG'], tags=[118]),
#  TaggedDocument(words=['공장/NNG', '신축/NNG', '전기/NNG', '필요/NNG', '공장/NNG', '건설/NNG', '전기/NNG', '임시/NNG', '전력/NNG', '사용/NNG', '공장/NNG', '가동/NNG', '필요/NNG', '수전/NNG', '설비/NNG', '사용/NNG', '경우/NNG', '산업용/NNG', '전력/NNG', '적용/NNG'], tags=[119]),
#  TaggedDocument(words=['돼지/NNG', '사육/NNG', '축사/NNG', '행정/NNG', '관청/NNG', '오수/NNG', '정화/NNG', '시설/NNG', '설치/NNG', '통고/NNG', '오수정/NNG', '시설/NNG', '별도/NNG', '계량기/NNG', '전기/NNG', '사용/NNG', '경우/NNG', '계약/NNG', '종별/NNG'], tags=[120]),
#  TaggedDocument(words=['산업용/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '전기/NNG', '요금/NNG'], tags=[121]),
#  TaggedDocument(words=['유원지/NNG', '음식점/NNG', '경영/NNG', '여름철/NNG', '장사/NNG', '휴업/NNG', '임시/NNG', '전력/NNG', '신청/NNG', '전기/NNG', '사용/NNG'], tags=[122]),
#  TaggedDocument(words=['양곡/NNG', '생산/NNG', '양수/NNG', '배수/NNG', '펌프/NNG', '사용/NNG', '전력/NNG', '농/NNG', '사용/NNG', '갑/NNG', '을/NNG', '적용/NNG', '도시/NNG', '재해/NNG', '예방/NNG', '용/NNG', '배수/NNG', '펌프장/NNG', '농/NNG', '사용/NNG', '갑/NNG', '요금/NNG', '적용/NNG'], tags=[123]),
#  TaggedDocument(words=['주택/NNG', '전력/NNG', '일반용/NNG', '일반용/NNG', '전력/NNG', '주택/NNG', '변경/NNG'], tags=[124]),
#  TaggedDocument(words=['계약/NNG', '종별/NNG'], tags=[125]),
#  TaggedDocument(words=['임시/NNG', '전력/NNG', '적용/NNG', '대상/NNG'], tags=[126]),
#  TaggedDocument(words=['농/NNG', '사용/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '기준/NNG'], tags=[127]),
#  TaggedDocument(words=['청정/NNG', '계곡/NNG', '수/NNG', '지하수/NNG', '이용/NNG', '담수어/NNG', '양어장/NNG', '운영/NNG', '농/NNG', '사용/NNG', '을/NNG', '이/NNG', '적용/NNG', '농/NNG', '사용/NNG', '갑/NNG', '요금/NNG', '적용/NNG'], tags=[128]),
#  TaggedDocument(words=['교육/NNG', '전력/NNG', '적용/NNG', '대상/NNG', '전기/NNG', '요금/NNG'], tags=[129]),
#  TaggedDocument(words=['삼상/NNG', '동력/NNG', '구좌/NNG', '단상/NNG', '구좌/NNG', '계량기/NNG', '이번/NNG', '업종/NNG', '변경/NNG', '삼상/NNG', '동력/NNG', '구좌/NNG', '해지/NNG', '신청/NNG', '절차/NNG', '소요/NNG', '기일/NNG'], tags=[130]),
#  TaggedDocument(words=['도시/NNG', '계획/NNG', '집이/NNG', '철거/NNG', '경우/NNG', '전기/NNG', '해지/NNG', '방법/NNG', '해지/NNG', '확인서/NNG', '발급/NNG', '방법/NNG'], tags=[131]),
#  TaggedDocument(words=['년/NNG', '사용/NNG', '소형/NNG', '기계/NNG', '관/NNG', '정용/NNG', '계량기/NNG', '한전/NNG', '철거/NNG', '주인/NNG', '의사/NNG'], tags=[132]),
#  TaggedDocument(words=['건물/NNG', '주가/NNG', '임대인/NNG', '동의/NNG', '일방적/NNG', '전기/NNG', '사용/NNG', '해지/NNG'], tags=[133]),
#  TaggedDocument(words=['건축법/NNG', '위반/NNG', '건축물/NNG', '행정/NNG', '기관/NNG', '시정/NNG', '명령/NNG', '단전/NNG', '얘기/NNG', '단전/NNG', '처리/NNG'], tags=[134]),
#  TaggedDocument(words=['전/NNG', '농촌/NNG', '농가/NNG', '주택/NNG', '구입/NNG', '여름/NNG', '휴가/NNG', '차/NNG', '방문/NNG', '때/NNG', '전기/NNG', '확인/NNG', '계량기/NNG', '전기/NNG', '요금/NNG', '기본/NNG', '요금/NNG', '옆집/NNG', '대신/NNP', '납부/NNG', '사용자/NNG', '동의/NNG', '해지/NNG', '가능/NNG'], tags=[135]),
#  TaggedDocument(words=['고압/NNG', '수전/NNG', '공장/NNG', '전기/NNG', '계약/NNG', '전력/NNG', '경우/NNG', '기본/NNG', '요금/NNG', '경감/NNG', '효과/NNG'], tags=[136]),
#  TaggedDocument(words=['계약/NNG', '전력/NNG', '변경/NNG', '증설/NNG', '감소/NNG'], tags=[137]),
#  TaggedDocument(words=['근린/NNG', '생활/NNG', '시설/NNG', '일반용/NNG', '전력/NNG', '요금/NNG', '적용/NNG', '여름철/NNG', '에어콘/NNG', '사용/NNG', '불필요/NNG', '계약/NNG', '전력/NNG', '가능/NNG'], tags=[138]),
#  TaggedDocument(words=['작년/NNG', '휴지/NNG', '농/NNG', '사용/NNG', '전력/NNG', '공급/NNG'], tags=[139]),
#  TaggedDocument(words=['휴업/NNG', '사유/NNG', '일시적/NNG', '전기/NNG', '공급/NNG', '중지/NNG', '휴지/NNG'], tags=[140]),
#  TaggedDocument(words=['설비/NNG', '변/NNG', '상금/NNG', '미납/NNG', '전기/NNG', '공급/NNG', '정지/NNG', '변/NNG', '상금/NNG', '납부/NNG', '전기/NNG', '공급/NNG', '며칠/NNG'], tags=[141]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '계약/NNG', '해지/NNG', '사용/NNG'], tags=[142]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '계약서/NNG', '계약/NNG', '기간/NNG', '전기/NNG', '사용/NNG', '계약/NNG', '변경/NNG', '성립/NNG', '일로/NNG', '요금/NNG', '적용/NNG', '개시일/NNG', '이후/NNG', '날/NNG', '고/NNG', '후/NNG', '전기/NNG', '사용/NNG', '계약/NNG', '체결/NNG'], tags=[143]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '한전/NNG', '내방/NNG', '전화/NNG', '구두/NNG', '신청/NNG', '내용/NNG'], tags=[144]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '계량기/NNG', '고장/NNG'], tags=[145]),
#  TaggedDocument(words=['전기/NNG', '계량기/NNG'], tags=[146]),
#  TaggedDocument(words=['노후/NNG', '계량기/NNG', '교환/NNG', '계량기/NNG', '이설/NNG', '신청/NNG', '하나/NNG'], tags=[147]),
#  TaggedDocument(words=['계량기/NNG', '소리/NNG', '교환/NNG'], tags=[148]),
#  TaggedDocument(words=['가정집/NNG', '지난달/NNG', '계량기/NNG', '실효/NNG', '계량기/NNG', '교환/NNG', '이달/NNG', '전기/NNG', '요금/NNG', '계량기/NNG', '전기/NNG', '요금/NNG'], tags=[149]),
#  TaggedDocument(words=['전기/NNG', '설비/NNG', '증감/NNG', '전력량계/NNG', '교환/NNG', '절차/NNG'], tags=[150]),
#  TaggedDocument(words=['계량기/NNG', '곳/NNG', '설치/NNG'], tags=[151]),
#  TaggedDocument(words=['계량기/NNG', '봉인/NNG'], tags=[152]),
#  TaggedDocument(words=['계량기/NNG', '집안/NNG', '대문/NNG', '밖/NNG'], tags=[153]),
#  TaggedDocument(words=['집수리/NNG', '개/NNG', '축/NNG', '관계/NNG', '계량기/NNG', '한전/NNG', '신청/NNG'], tags=[154]),
#  TaggedDocument(words=['계량기/NNG', '소/NNG', '손/NNG', '교환/NNG', '계기/NNG', '변/NNG', '상금/NNG', '고객/NNG', '부담/NNG'], tags=[155]),
#  TaggedDocument(words=['주택/NNG', '전기/NNG', '공급/NNG', '내선/NNG', '전기/NNG', '공사/NNG', '업체/NNG', '공사비/NNG', '청구/NNG', '내역/NNG', '계기함/NNG', '가액/NNG', '포함/NNG', '계기함/NNG', '전력량계/NNG', '보호/NNG', '부속/NNG', '장치/NNG', '한전/NNG', '시설/NNG'], tags=[156]),
#  TaggedDocument(words=['전력량계/NNG', '오차/NNG', '공차/NNG'], tags=[157]),
#  TaggedDocument(words=['현재/NNG', '한전/NNG', '인정/NNG', '최대/NNG', '수요/NNG', '전력/NNG', '계의/NNG', '측정/NNG', '시한/NNG', '분계/NNG', '계기/NNG'], tags=[158]),
#  TaggedDocument(words=['고압/NNG', '계기/NNG', '설치/NNG', '누/NNG', '비용/NNG', '부담/NNG', '누/NNG'], tags=[159]),
#  TaggedDocument(words=['시간대/NNG', '구분/NNG', '계기/NNG', '전자식/NNG', '계기/NNG', '설치/NNG', '대상/NNG', '말씀/NNG'], tags=[160]),
#  TaggedDocument(words=['주택/NNG', '수가/NNG', '구/NNG', '요금/NNG', '적용/NNG', '계약/NNG', '기간/NNG', '이/NNG', '재/NNG', '신청/NNG'], tags=[161]),
#  TaggedDocument(words=['한집/NNG', '가구/NNG', '전기/NNG', '요금/NNG', '혜택/NNG', '주택/NNG', '수가/NNG', '구/NNG', '신청/NNG'], tags=[162]),
#  TaggedDocument(words=['가구/NNG', '수/NNG', '과다/NNG', '추징/NNG', '금/NNG'], tags=[163]),
#  TaggedDocument(words=['주택/NNG', '수가/NNG', '가구/NNG', '수/NNG', '변동/NNG', '하나/NNG'], tags=[164]),
#  TaggedDocument(words=['장소/NNG', '사회/NNG', '복지/NNG', '시설/NNG', '운영/NNG', '신고/NNG', '증/NNG', '신청/NNG', '가능/NNG', '가요/NNG'], tags=[165]),
#  TaggedDocument(words=['영/NNG', '유아/NNG', '보육법/NNG', '영/NNG', '유아/NNG', '보육/NNG', '시설/NNG', '사회/NNG', '복지/NNG', '할인/NNG', '대상/NNG', '적용/NNG'], tags=[166]),
#  TaggedDocument(words=['장애인/NNG', '할인/NNG', '경우/NNG', '주거/NNG', '용/NNG', '대상/NNG'], tags=[167]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '복지/NNG', '할인/NNG', '대상/NNG', '범위/NNG', '선정/NNG', '기준/NNG'], tags=[168]),
#  TaggedDocument(words=['장애/NNG', '정도/NNG', '장애인/NNG', '적용/NNG', '장애인/NNG', '전기/NNG', '요금/NNG', '할인/NNG', '대상/NNG', '확대/NNG', '계획/NNG'], tags=[169]),
#  TaggedDocument(words=['차상/NNG', '위/NNG', '계층/NNG', '전기/NNG', '요금/NNG', '할인/NNG', '제도/NNG'], tags=[170]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '할인/NNG', '적용/NNG', '사회/NNG', '복지/NNG', '시설/NNG', '범위/NNG'], tags=[171]),
#  TaggedDocument(words=['장애인/NNG', '이면서/NNG', '기초/NNG', '생활/NNG', '수급자/NNG', '경우/NNG', '중복/NNG', '할인/NNG', '적용/NNG'], tags=[172]),
#  TaggedDocument(words=['장애인/NNG', '전기/NNG', '요금/NNG', '할인/NNG', '제도/NNG', '도입/NNG', '배경/NNG', '내용/NNG'], tags=[173]),
#  TaggedDocument(words=['주민/NNG', '센터/NNG', '전기/NNG', '요금/NNG', '복지/NNG', '할인/NNG', '신청/NNG'], tags=[174]),
#  TaggedDocument(words=['주택/NNG', '수가/NNG', '구/NNG', '경우/NNG', '전기/NNG', '요금/NNG', '복지/NNG', '할인/NNG', '적용/NNG'], tags=[175]),
#  TaggedDocument(words=['자녀/NNG', '가구/NNG', '전기/NNG', '요금/NNG', '할인/NNG', '제도/NNG'], tags=[176]),
#  TaggedDocument(words=['대가족/NNG', '요금/NNG', '무엇/NNG', '신청/NNG'], tags=[177]),
#  TaggedDocument(words=['출산/NNG', '가구/NNG', '할인/NNG', '대상/NNG', '신청/NNG', '방법/NNG'], tags=[178]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '기본/NNG', '요금/NNG', '계산/NNG'], tags=[179]),
#  TaggedDocument(words=['계시/NNG', '별/NNG', '요금/NNG', '계절/NNG', '시간대/NNG', '구분/NNG'], tags=[180]),
#  TaggedDocument(words=['부하율/NNG', '선택/NNG', '요금/NNG', '무엇/NNG'], tags=[181]),
#  TaggedDocument(words=['주택/NNG', '전기/NNG', '요금/NNG', '누진제/NNG', '적용/NNG', '이유/NNG'], tags=[182]),
#  TaggedDocument(words=['주택/NNG', '전기/NNG', '요금/NNG', '누진/NNG', '구조/NNG'], tags=[183]),
#  TaggedDocument(words=['주택/NNG', '전력/NNG', '고압/NNG', '요금/NNG'], tags=[184]),
#  TaggedDocument(words=['아파트/NNG', '전체/NNG', '구좌/NNG', '한전/NNG', '계약/NNG', '전기/NNG', '요금/NNG', '관리/NNG', '비/NNG', '관리/NNG', '사무실/NNG', '청구/NNG', '아파트/NNG', '전기/NNG', '요금/NNG', '계산/NNG'], tags=[185]),
#  TaggedDocument(words=['모자/NNG', '거래/NNG', '전기/NNG', '공급/NNG', '상가/NNG', '오/NNG', '배수/NNG', '시설/NNG', '상수도/NNG', '가압/NNG', '설비/NNG', '자/NNG', '고객/NNG', '저압/NNG', '계량/NNG', '경우/NNG', '자/NNG', '고객/NNG', '역률/NNG', '계산/NNG'], tags=[186]),
#  TaggedDocument(words=['역률/NNG', '계산/NNG'], tags=[187]),
#  TaggedDocument(words=['공장/NNG', '설비/NNG', '증가/NNG', '저압/NNG', '특별/NNG', '고압/NNG', '공급/NNG', '방식/NNG', '변경/NNG', '이달/NNG', '역률/NNG', '적용/NNG', '저압/NNG', '특별/NNG', '고압/NNG', '구분/NNG', '적용/NNG'], tags=[188]),
#  TaggedDocument(words=['비주거/NNG', '주택/NNG', '전력/NNG', '전기/NNG', '요금/NNG', '적용/NNG'], tags=[189]),
#  TaggedDocument(words=['전압/NNG', '별/NNG', '요금/NNG', '무엇/NNG'], tags=[190]),
#  TaggedDocument(words=['종합/NNG', '계약/NNG', '아파트/NNG', '고객/NNG', '한전/NNG', '계량기/NNG', '사용량/NNG', '보조/NNG', '계량기/NNG', '사용량/NNG', '합계/NNG', '경우/NNG'], tags=[191]),
#  TaggedDocument(words=['보조/NNG', '계량기/NNG', '사용량/NNG', '합계/NNG', '한전/NNG', '계량기/NNG', '사용량/NNG', '차이/NNG'], tags=[192]),
#  TaggedDocument(words=['사용량/NNG', '당월/NNG', '지침/NNG', '경우/NNG'], tags=[193]),
#  TaggedDocument(words=['보조/NNG', '계량기/NNG', '설치/NNG', '검침/NNG', '고장수리/NNG'], tags=[194]),
#  TaggedDocument(words=['계량기/NNG', '검침/NNG', '누/NNG', '집/NNG', '경우/NNG', '검침/NNG'], tags=[195]),
#  TaggedDocument(words=['전기/NNG', '검침/NNG', '미/NNG', '실시/NNG', '안내문/NNG'], tags=[196]),
#  TaggedDocument(words=['한전/NNG', '변전소/NNG', '직/NNG', '거래/NNG', '공장/NNG', '이달/NNG', '전기/NNG', '요금/NNG', '청구서/NNG', '상의/NNG', '사용량/NNG', '공장/NNG', '내/NNG', '부설/NNG', '전력량계/NNG', '검침/NNG', '사용량/NNG', '원인/NNG'], tags=[197]),
#  TaggedDocument(words=['농/NNG', '사용/NNG', '갑/NNG', 'kW/OL', '전기/NNG', '사용/NNG', '청구서/NNG'], tags=[198]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '청구서/NNG', '분실/NNG', '경우/NNG'], tags=[199]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '청구서/NNG', '이름/NNG', '호수/NNG', '확인/NNG'], tags=[200]),
#  TaggedDocument(words=['어르신/NNG', '맞춤/NNG', '형/NNG', '청구서/NNG', '무엇/NNG', '신청/NNG'], tags=[201]),
#  TaggedDocument(words=['아파트/NNG', '관리비/NNG', '전기/NNG', '요금/NNG', '청구/NNG', '고객/NNG', '번호/NNG', '인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '가입/NNG', '하나/NNG'], tags=[202]),
#  TaggedDocument(words=['이메일/NNG', '청구서/NNG', '발행/NNG'], tags=[203]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '을/NNG', '오늘/NNG', '신청/NNG', '청구서/NNG', '이메일/NNG'], tags=[204]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '가입/NNG'], tags=[205]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '을/NNG', '해지/NNG', '청구서/NNG', '지로/NNG'], tags=[206]),
#  TaggedDocument(words=['법인/NNG', '사업자/NNG', '카카오/NNG', '이/NNG', '청구서/NNG'], tags=[207]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '내역/NNG', '포함/NNG'], tags=[208]),
#  TaggedDocument(words=['이사/NNG', '이메일/NNG', '청구서/NNG', '계속/NNG'], tags=[209]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '전기/NNG', '요금/NNG', '납부/NNG', '일/NNG', '이전/NNG', '안내/NNG'], tags=[210]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '납부/NNG', '내역/NNG', '확인/NNG', '하나/NNG'], tags=[211]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '서비스/NNG', '회사/NNG'], tags=[212]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '서비스/NNG', '고객/NNG', '센터/NNG', '연락/NNG'], tags=[213]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '거래/NNG', '내역/NNG', '서/NNG', '출력/NNG'], tags=[214]),
#  TaggedDocument(words=['청구서/NNG', '이상/NNG'], tags=[215]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '이메일/NNG', '업체/NNG', '가입/NNG', '확인/NNG', '방법/NNG'], tags=[216]),
#  TaggedDocument(words=['세금/NNG', '계산서/NNG', '발급/NNG'], tags=[217]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '신청/NNG', '시/NNG', '기존/NNG', '청구서/NNG'], tags=[218]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '서비스/NNG'], tags=[219]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '요금/NNG', '납부/NNG', '도/NNG', '가능/NNG', '가요/NNG'], tags=[220]),
#  TaggedDocument(words=['자동/NNG', '이체/NNG', '고객/NNG', '카카오/NNG', '이/NNG', '청구서/NNG', '신청/NNG'], tags=[221]),
#  TaggedDocument(words=['카카오/NNG', '청구/NNG', '메신저/NNG', '발신/NNG', '하나/NNG'], tags=[222]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '신청/NNG'], tags=[223]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '신청/NNG', '시/NNG', '사전/NNG', '준비/NNG', '정보/NNG'], tags=[224]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '을/NNG', '신청/NNG', '이메일/NNG', '청구서/NNG'], tags=[225]),
#  TaggedDocument(words=['인터넷/NNG', '링/NNG', '이메일/NNG', '청구서/NNG', '을/NNG', '신청/NNG', '가입/NNG', '고객/NNG', '확인/NNG'], tags=[226]),
#  TaggedDocument(words=['청구서/NNG', '이메일/NNG', '주소/NNG'], tags=[227]),
#  TaggedDocument(words=['계량기/NNG', '다섯/NNG', '업체/NNG', '전기/NNG', '사용/NNG', '상가/NNG', '기본/NNG', '요금/NNG'], tags=[228]),
#  TaggedDocument(words=['요금/NNG', '적용/NNG', '전력/NNG'], tags=[229]),
#  TaggedDocument(words=['전기/NNG', '기기/NNG', '변동/NNG', '사용/NNG', '전기/NNG', '요금/NNG', '이유/NNG'], tags=[230]),
#  TaggedDocument(words=['이번/NNG', '달/NNG', '전기/NNG', '요금/NNG', '소액/NNG', '합산/NNG', '청구/NNG', '소/NNG', '액/NNG', '요금/NNG', '합산/NNG', '청구/NNG', '무엇/NNG'], tags=[231]),
#  TaggedDocument(words=['신규/NNG', '전기/NNG', '공급/NNG', '청구서/NNG', '약/NNG', '달/NNG', '전기/NNG', '요금/NNG', '청구/NNG', '경우/NNG', '전기/NNG', '요금/NNG', '계산/NNG'], tags=[232]),
#  TaggedDocument(words=['상수도/NNG', '오수/NNG', '처리/NNG', '시설/NNG', '저압/NNG', '계량/NNG', '모자/NNG', '거래/NNG', '변압기/NNG', '공동/NNG', '이용/NNG', '경우/NNG', '모/NNG', '계량/NNG', '전기/NNG', '요금/NNG', '계산/NNG'], tags=[233]),
#  TaggedDocument(words=['전력/NNG', '산업/NNG', '기반/NNG', '기금/NNG'], tags=[234]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '청구서/NNG', '표시/NNG', '융자금/NNG'], tags=[235]),
#  TaggedDocument(words=['시간/NNG', '대구분/NNG', '계기/NNG', '기록/NNG', '전자식/NNG', '계기/NNG', '고장/NNG', '시간대/NNG', '사용량/NNG', '산정/NNG'], tags=[236]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '개시일/NNG', '연기/NNG', '전기/NNG', '사용/NNG', '전기/NNG', '요금/NNG', '적용/NNG', '개시/NNG', '시기/NNG'], tags=[237]),
#  TaggedDocument(words=['계량기/NNG', '경우/NNG', '전기/NNG', '요금/NNG', '계산/NNG'], tags=[238]),
#  TaggedDocument(words=['당월/NNG', '전기/NNG', '요금/NNG', '사용/NNG'], tags=[239]),
#  TaggedDocument(words=['저압/NNG', '공급/NNG', '공장/NNG', '정전/NNG', '신고/NNG', '한전/NNG', '직원/NNG', '계량기/NNG', '소/NNG', '손/NNG', '직결/NNG', '송전/NNG', '경우/NNG', '전기/NNG', '요금/NNG', '계산/NNG'], tags=[240]),
#  TaggedDocument(words=['최대/NNG', '수요/NNG', '전력계/NNG', '고장/NNG', '수리/NNG', '철거/NNG', '철거/NNG', '기간/NNG', '기본/NNG', '요금/NNG', '계산/NNG'], tags=[241]),
#  TaggedDocument(words=['가구/NNG', '주택/NNG', '세입/NNG', '자인/NNG', '가구/NNG', '보조/NNG', '계량기/NNG', '설치/NNG', '요금/NNG', '분배/NNG', '방법/NNG'], tags=[242]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '방법/NNG', '계산/NNG'], tags=[243]),
#  TaggedDocument(words=['태풍/NNG', '자연재해/NNG', '피해/NNG', '고객/NNG', '전기/NNG', '요금/NNG', '감면/NNG', '제도/NNG'], tags=[244]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '계약/NNG', '위반/NNG', '무단/NNG', '사용/NNG', '벌금/NNG', '얼마/NNG', '신/NNG', '고시/NNG', '포/NNG', '상금/NNG', '얼마/NNG'], tags=[245]),
#  TaggedDocument(words=['저압/NNG', '고객/NNG', '초과/NNG', '사용/NNG', '부가/NNG', '금/NNG'], tags=[246]),
#  TaggedDocument(words=['초과/NNG', '사용/NNG', '부가/NNG', '금/NNG'], tags=[247]),
#  TaggedDocument(words=['공과금/NNG', '납/NNG', '기일/NNG', '말일/NNG', '전기/NNG', '요금/NNG', '불편/NNG', '납기/NNG', '일/NNG', '말일/NNG'], tags=[248]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '납기/NNG', '지역/NNG', '이유/NNG'], tags=[249]),
#  TaggedDocument(words=['착오/NNG', '전기/NNG', '요금/NNG', '환불/NNG'], tags=[250]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '인터넷/NNG', '뱅킹/NNG', '납부/NNG'], tags=[251]),
#  TaggedDocument(words=['편의점/NNG', '전기/NNG', '요금/NNG', '납부/NNG', '가능/NNG', '가요/NNG'], tags=[252]),
#  TaggedDocument(words=['청구서/NNG', '명의자/NNG', '납부/NNG', '이름/NNG', '요금/NNG', '납부/NNG', '가능/NNG'], tags=[253]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '현금/NNG', '영수증/NNG', '발행/NNG', '가능/NNG'], tags=[254]),
#  TaggedDocument(words=['신용/NNG', '카드/NNG', 'kW/OL', '초과/NNG', '일반용/NNG', '산업용/NNG', '전기/NNG', '요금/NNG', '납부/NNG', '독점/NNG', '기업/NNG', '횡포/NNG'], tags=[255]),
#  TaggedDocument(words=['카카오/NNG', '이/NNG', '청구서/NNG', '결제/NNG', '후/NNG', '결제/NNG', '취소/NNG'], tags=[256]),
#  TaggedDocument(words=['종이/NNG', '청구서/NNG', 'QR/OL', '요금/NNG', '납부/NNG', '카카오/NNG', '이로/NNP', '납부/NNG', '가능/NNG', '가요/NNG'], tags=[257]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '신용/NNG', '카드/NNG', '납부/NNG'], tags=[258]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '이체/NNG', '날짜/NNG', '인출/NNG', '경우/NNG'], tags=[259]),
#  TaggedDocument(words=['자동/NNG', '이체/NNG', '신청/NNG', '은행/NNG', '인터넷/NNG'], tags=[260]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '체시/NNG', '혜택/NNG'], tags=[261]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '이체/NNG', '오늘/NNG', '신청/NNG', '요금/NNG', '자동/NNG', '출금/NNG'], tags=[262]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '납부/NNG', '계좌/NNG', '카드/NNG'], tags=[263]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '계좌/NNG', '잔액/NNG', '부족/NNG'], tags=[264]),
#  TaggedDocument(words=['신용/NNG', '카드/NNG', '전기/NNG', '요금/NNG', '납부/NNG', '할인/NNG', '혜택/NNG'], tags=[265]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '자동/NNG', '이체/NNG', '신청/NNG', '해지/NNG', '방법/NNG'], tags=[266]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '납부/NNG', '가능/NNG'], tags=[267]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '미납/NNG', '경우/NNG', '연체료/NNG'], tags=[268]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '계약/NNG', '해지/NNG', '후/NNG', '미납/NNG', '전기/NNG', '요금/NNG', '채권/NNG', '소멸/NNG', '시효/NNG', '납부/NNG'], tags=[269]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '미납/NNG', '단전/NNG'], tags=[270]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '정지/NNG', '전/NNG', '의/NNG', '대상/NNG', '기준/NNG'], tags=[271]),
#  TaggedDocument(words=['한전/NNG', 'TV/OL', '신료/NNG', '수납/NNG', '근거/NNG'], tags=[272]),
#  TaggedDocument(words=['가정집/NNG', 'TV/OL', '신료/NNG', '달/NNG', '부과/NNG', '이유/NNG'], tags=[273]),
#  TaggedDocument(words=['장애인/NNG', 'TV/OL', '신료/NNG', '면제/NNG'], tags=[274]),
#  TaggedDocument(words=['TV/OL', '유선/NNG', '방송/NNG', '위성/NNG', '방송/NNG', '시청/NNG', 'TV/OL', '신료/NNG'], tags=[275]),
#  TaggedDocument(words=['제가/NNG', '지역/NNG', '난시청/NNG', '지역/NNG', '확인/NNG'], tags=[276]),
#  TaggedDocument(words=['TV/OL', '시청/NNG', 'TV/OL', '신료/NNG', '내야/NNG'], tags=[277]),
#  TaggedDocument(words=['해외/NNG', '출장/NNG', '이유/NNG', '집/NNG', '예정/NNG', '일시적/NNG', 'TV/OL', '신료/NNG', '면제/NNG'], tags=[278]),
#  TaggedDocument(words=['TV/OL', '신료/NNG', '면제/NNG', '차후/NNG', '이사/NNG', '경우/NNG', '면제/NNG'], tags=[279]),
#  TaggedDocument(words=['TV/OL', '신료/NNG', '부과/NNG', '기준/NNG', '면제/NNG', '대상/NNG'], tags=[280]),
#  TaggedDocument(words=['TV/OL', '수신/NNG', '청구/NNG'], tags=[281]),
#  TaggedDocument(words=['휴전/NNG', '정전/NNG'], tags=[282]),
#  TaggedDocument(words=['정전/NNG', '발생/NNG', '정전/NNG', '피해/NNG', '경우/NNG', '보상/NNG'], tags=[283]),
#  TaggedDocument(words=['정전/NNG', '피해/NNG', '배상/NNG', '관련/NNG', '법령/NNG', '규정/NNG', '내용/NNG'], tags=[284]),
#  TaggedDocument(words=['정전/NNG', '피해/NNG', '배상/NNG', '판정/NNG'], tags=[285]),
#  TaggedDocument(words=['전기/NNG', '사용/NNG', '기본/NNG', '요금/NNG', '부과/NNG', '전측/NNG', '사정/NNG', '정전/NNG', '경우/NNG', '기본/NNG', '요금/NNG', '감액/NNG'], tags=[286]),
#  TaggedDocument(words=['전기/NNG', '정전/NNG', '한전/NNG', '신고/NNG', '정전/NNG', '원인/NNG', '공장/NNG', '증축/NNG', '부하/NNG', '평형/NNG', '전기/NNG', '한전/NNG', '소유/NNG', '주상/NNG', '변압기/NNG', '소/NNG', '손/NNG', '변압기/NNG', '가액/NNG', '만큼/NNG', '배상/NNG', '배상/NNG', '금액/NNG'], tags=[287]),
#  TaggedDocument(words=['한전/NNG', '정전/NNG', '신고/NNG', '한전/NNG', '직원/NNG', '현장/NNG', '방문/NNG', '점검/NNG', '후/NNG', '옥내/NNG', '누전차단기/NNG', '불량/NNG'], tags=[288]),
#  TaggedDocument(words=['휴전/NNG', '시행/NNG'], tags=[289]),
#  TaggedDocument(words=['한전/NNG', '자가/NNG', '발전기/NNG', '설치/NNG', '권유/NNG', '자가/NNG', '발전기/NNG', '설치/NNG'], tags=[290]),
#  TaggedDocument(words=['광역/NNG', '정전/NNG', '사고/NNG', '대비/NNG', '예방/NNG', '대책/NNG'], tags=[291]),
#  TaggedDocument(words=['전기/NNG', '신청/NNG', '한참/NNG', '송전/NNG', '휴전/NNG', '휴전/NNG', '전기/NNG', '공급/NNG'], tags=[292]),
#  TaggedDocument(words=['전압/NNG', '전기/NNG', '제품/NNG', '소/NNG', '손/NNG', '보상/NNG'], tags=[293]),
#  TaggedDocument(words=['지하실/NNG', '옥상/NNG', '수전/NNG', '시설/NNG', '주위/NNG', '울타리/NNG', '설치/NNG', '변압기/NNG', '울타리/NNG', '정도/NNG', '이/NNG', '거리/NNG', '유지/NNG'], tags=[294]),
#  TaggedDocument(words=['가내/NNG', '공업/NNG', '소용량/NNG', '모터/NNG', '카바/NNG', '나이프/NNG', '스위치/NNG', '조작/NNG'], tags=[295]),
#  TaggedDocument(words=['전기/NNG', '누전/NNG', '점검/NNG'], tags=[296]),
#  TaggedDocument(words=['누전차단기/NNG', '무엇/NNG', '시설/NNG', '고장수리/NNG', '누/NNG'], tags=[297]),
#  TaggedDocument(words=['전기/NNG', '시설/NNG', '이상/NNG', '유무/NNG', '점검/NNG'], tags=[298]),
#  TaggedDocument(words=['콘덴서/NNG', '종합적/NNG', '부설/NNG'], tags=[299]),
#  TaggedDocument(words=['옥내/NNG', '설비/NNG', '불량/NNG', '하다/NNP', '한국/NNG', '전기/NNG', '안전/NNG', '공사/NNG', '통보/NNG'], tags=[300]),
#  TaggedDocument(words=['콘덴서/NNG', '부설/NNG'], tags=[301]),
#  TaggedDocument(words=['누전차단기/NNG', '누전/NNG', '때/NNG', '동작/NNG'], tags=[302]),
#  TaggedDocument(words=['누전차단기/NNG', '사용/NNG', '요령/NNG', '고장/NNG', '방법/NNG'], tags=[303]),
#  TaggedDocument(words=['콘센트/NNG', '소/NNG', '옥내/NNG', '배선/NNG', '회로/NNG', '사용/NNG', '용량/NNG', '한도/NNG', '얼마/NNG'], tags=[304]),
#  TaggedDocument(words=['보통/NNG', '가정/NNG', '사용/NNG', '규격/NNG', '얼마/NNG'], tags=[305]),
#  TaggedDocument(words=['우리집/NNG', '앞/NNG', '설치/NNG', '전주/NNG', '변압기/NNG', '소음/NNG', '이상/NNG'], tags=[306]),
#  TaggedDocument(words=['나무/NNG', '전력선/NNG'], tags=[307]),
#  TaggedDocument(words=['TV/OL', '안테나/NNG', '전선/NNG'], tags=[308]),
#  TaggedDocument(words=['지장/NNG', '배/NNG', '전선로/NNG', '전주/NNG', '전선/NNG', '의/NNG', '이설/NNG', '신청/NNG', '절차/NNG', '이설/NNG', '비용/NNG', '부담/NNG'], tags=[309]),
#  TaggedDocument(words=['도로/NNG', '상/NNG', '전주/NNG', '위치/NNG', '등/NNG', '하교/NNG', '길/NNG', '어린이/NNG', '통행/NNG', '지장/NNG', '줌/NNG', '교통사고/NNG', '위험/NNG', '이설/NNG', '요청/NNG', '경우/NNG', '신청/NNG', '방법/NNG', '비용/NNG', '관계/NNG'], tags=[310]),
#  TaggedDocument(words=['땅/NNG', '가운데/NNG', '전주/NNG', '집/NNG', '어려움/NNG', '절차/NNG', '비용/NNG', '관계/NNG'], tags=[311]),
#  TaggedDocument(words=['건축/NNG', '허가/NNG', '첨부/NNG', '불가능/NNG', '지역/NNG', '지장/NNG', '배/NNG', '전선로/NNG', '이설/NNG', '업무/NNG', '처리/NNG', '방법/NNG'], tags=[312]),
#  TaggedDocument(words=['건물/NNG', '법정/NNG', '격/NNG', '거리/NNG', '확보/NNG', '간판/NNG', '설치/NNG', '안전사고/NNG', '우려/NNG', '배전/NNG', '선로/NNG', '이설/NNG', '요청/NNG', '이설/NNG', '비용/NNG', '부담/NNG', '누/NNG'], tags=[313]),
#  TaggedDocument(words=['택지/NNG', '개발/NNG', '촉진법/NNG', '의거/NNG', '승인/NNG', '택지/NNG', '개발/NNG', '사업/NNG', '지구/NNG', '지장/NNG', '배/NNG', '전선로/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[314]),
#  TaggedDocument(words=['개인/NNG', '소유지/NNG', '전주/NNG', '이설/NNG', '비용/NNG', '개인/NNG', '부담/NNG', '이유/NNG'], tags=[315]),
#  TaggedDocument(words=['건물/NNG', '증축/NNG', '한전/NNG', '직원/NNG', '배/NNG', '전선로/NNG', '와의/NNG', '측방/NNG', '격/NNG', '거리/NNG', '미달/NNG', '전선/NNG', '이설/NNG', '후/NNG', '건물/NNG', '증축/NNG', '공사/NNG', '하면서/NNG', '위해/NNG', '통지서/NNG', '발부/NNG', '경우/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[316]),
#  TaggedDocument(words=['건조물/NNG', '신/NNG', '증축/NNG', '토지/NNG', '형질/NNG', '변경/NNG', '공사/NNG', '지장/NNG', '전선로/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[317]),
#  TaggedDocument(words=['토지/NNG', '구획/NNG', '정리/NNG', '사업/NNG', '지구/NNG', '내의/NNG', '토지/NNG', '소유자/NNG', '건축/NNG', '허가/NNG', '서/NNG', '첨부/NNG', '지장/NNG', '배/NNG', '전선로/NNG', '이설/NNG', '요청/NNG', '시/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[318]),
#  TaggedDocument(words=['사유지/NNG', '내/NNG', '통과/NNG', '전선로/NNG', '건조물/NNG', '신/NNG', '증축/NNG', '지장/NNG', '건조물/NNG', '신/NNG', '증축/NNG', '대지/NNG', '지형/NNG', '변경/NNG', '축대/NNG', '건조/NNG', '전선로/NNG', '지상/NNG', '고가/NNG', '미달/NNG', '경우/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[319]),
#  TaggedDocument(words=['논둑/NNG', '설치/NNG', '전주/NNG', '트랙터/NNG', '이설/NNG', '요청/NNG', '설비/NNG', '누/NNG', '부담/NNG'], tags=[320]),
#  TaggedDocument(words=['개설/NNG', '도로/NNG', '설치/NNG', '배/NNG', '전선로/NNG', '도로/NNG', '공사/NNG', '지장/NNG', '경우/NNG', '이설/NNG', '비용/NNG', '부담/NNG'], tags=[321]),
#  TaggedDocument(words=['사유지/NNG', '도로/NNG', '경계선/NNG', '설치/NNG', '전주/NNG', '아파트/NNG', '건물/NNG', '신축/NNG', '지장/NNG', '이설/NNG', '경우/NNG', '이설/NNG', '비용/NNG', '누/NNG', '부담/NNG'], tags=[322]),
#  TaggedDocument(words=['전선/NNG', '시내/NNG', '곳곳/NNG', '미관상/NNG', '땅/NNG', '밑/NNG', '시설/NNG'], tags=[323]),
#  TaggedDocument(words=['배선/NNG', '차단기/NNG', 'N/OL', 'F/OL', 'B/OL', '무엇/NNG'], tags=[324]),
#  TaggedDocument(words=['전기/NNG', '공사/NNG', '사용/NNG', '자재/NNG', '사용/NNG'], tags=[325]),
#  TaggedDocument(words=['한전/NNG', '배/NNG', '전선로/NNG', '운영/NNG', '기존/NNG', '공급/NNG', '설비/NNG', '보강/NNG', '공사/NNG', '고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '제외/NNG', '기존/NNG', '공급/NNG', '설비/NNG', '보강/NNG', '경우/NNG'], tags=[326]),
#  TaggedDocument(words=['전기/NNG', '기기/NNG', '접지/NNG', '이유/NNG'], tags=[327]),
#  TaggedDocument(words=['접지/NNG', '공사/NNG', '접지/NNG', '저항/NNG', '유지/NNG'], tags=[328]),
#  TaggedDocument(words=['옥내/NNG', '배선/NNG', '굵기/NNG', '얼마/NNG'], tags=[329]),
#  TaggedDocument(words=['절연/NNG', '저항/NNG', '옥내/NNG', '절연/NNG', '저항/NNG', '얼마/NNG', '이상/NNG', '유지/NNG'], tags=[330]),
#  TaggedDocument(words=['접지/NNG', '공사/NNG', '접지선/NNG', '굵기/NNG'], tags=[331]),
#  TaggedDocument(words=['전주/NNG', '위/NNG', '땅속/NNG', '접지선/NNG', '접촉/NNG', '위험/NNG'], tags=[332]),
#  TaggedDocument(words=['고압/NNG', '이상/NNG', '공급/NNG', '전압/NNG', '변압기/NNG', '결선/NNG', '방법/NNG', 'Y/OL', '공급/NNG', '선로/NNG', '구분/NNG', '공급/NNG', '전압/NNG', '별/NNG', '결선/NNG', '방식/NNG'], tags=[333]),
#  TaggedDocument(words=['전선/NNG', '전선로/NNG'], tags=[334]),
#  TaggedDocument(words=['전자파/NNG', '인체/NNG', '영향/NNG'], tags=[335]),
#  TaggedDocument(words=['송/NNG', '변전/NNG', '설비/NNG', '발생/NNG', '전자파/NNG', '유해/NNG', '논란/NNG', '현황/NNG', '대책/NNG'], tags=[336]),
#  TaggedDocument(words=['송/NNG', '전선/NNG', '로란/NNG', '무엇/NNG'], tags=[337]),
#  TaggedDocument(words=['송전/NNG', '선로/NNG', '아래/NNG', '안전/NNG', '작업/NNG', '거리/NNG', '정도/NNG'], tags=[338]),
#  TaggedDocument(words=['변전소/NNG', '기능/NNG', '곳/NNG'], tags=[339]),
#  TaggedDocument(words=['사이버/NNG', '지점/NNG', '나의/NNG', '고객/NNG', '번호/NNG', '등록/NNG', '관리/NNG', '방법/NNG'], tags=[340]),
#  TaggedDocument(words=['민원/NNG', '서식/NNG', '다운/NNG'], tags=[341]),
#  TaggedDocument(words=['내가/NNG', '지역/NNG', '관할/NNG', '사/NNG', '업소/NNG', '위치/NNG', '연락처/NNG'], tags=[342]),
#  TaggedDocument(words=['아이디/NNG', '비밀/NNG', '번호/NNG'], tags=[343]),
#  TaggedDocument(words=['민원/NNG', '신청/NNG', '현황/NNG', '확인/NNG'], tags=[344]),
#  TaggedDocument(words=['사이버/NNG', '지점/NNG', '전기/NNG', '요금/NNG', '조회/NNG', '서비스/NNG', '이용/NNG'], tags=[345]),
#  TaggedDocument(words=['전기/NNG', '공급/NNG', '약관/NNG'], tags=[346]),
#  TaggedDocument(words=['법인/NNG', '회원/NNG', '가입/NNG', '방법/NNG'], tags=[347]),
#  TaggedDocument(words=['전기/NNG', '요금/NNG', '계산/NNG'], tags=[348]),
#  TaggedDocument(words=['아파트/NNG', '관리/NNG', '사무소/NNG', '종합/NNG', '계약/NNG', '단일/NNG', '계약/NNG', '비교/NNG'], tags=[349]),
#  TaggedDocument(words=['고객/NNG', '번호/NNG', '무엇/NNG', '확인/NNG'], tags=[350])]

# %%
pre_faqs
# Out:
# [[0,
#   ['주택/NNG',
#    '수가/NNG',
#    '구/NNG',
#    '요금/NNG',
#    '적용/NNG',
#    '가구/NNG',
#    '수가/NNG',
#    '감소/NNG'],
#   '1주택수가구 요금을 적용받던 고객이 세입자 전출등 가구수가 감소하는 경우에는 1개월 이내에 가구수 감소 신청을 하셔야 합니다.신청방법은 한전 `업무찾기(새창열림)` 사이버지점신청접수업무찾기에서가구수감소 신청을 검색하시면신청이 가능합니다. 또는전기요금 영수증 1매를 가지고 전화로 관할 한전 사업소에 신청하시면 됩니다.※ 가구수 감소 신청을 하지 않고 수가구요금을 적용받다가 추후 가구수 감소사실이 발견되면 확인되는 달까지 소급하여위약금을 추징하게 됩니다.'],
#  [1,
#   ['고객/NNG',
#    '임시/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '설치/NNG',
#    '공사비/NNG',
#    '부담/NNG',
#    '한전/NNG',
#    '임시/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '시설/NNG',
#    '경우/NNG',
#    '임시/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '유지/NNG',
#    '보수/NNG',
#    '책임/NNG',
#    '한계점/NNG'],
#   '임시공급설비를 한전에서 설치할 경우에는 상시전력 공급설비의 수급지점과 동일하게하여 임시공급설비를 한전이 시설소유합니다. 이때 수급지점의 전원측은 한전에게,고객측은 고객에게 유지보수의 책임이 있습니다. 현장여건상 임시공급설비의 설치가용이하지 않거나 수급지점의 수시 변경이 예상되는 경우로서 한전이 필요하다고 인정하는경우에는 임시전력을 공급받기 위한 전기설비를 고객이 설치하고 소유할 수 있습니다.'],
#  [2,
#   ['변압기/NNG', '공동/NNG', '이용/NNG', '모자/NNG', '거래/NNG', '요금/NNG', '계산/NNG'],
#   '동일 전기사용장소내에 전기사용용도(계약종별)가 다르거나 회계단위가 상이한 2이상의 고객이 있는 경우에는 변압기를 공동으로 이용하면서 각 고객별로 전기사용계약을 체결하고 따로 계량하여 사용할 수 있습니다.즉, 변압기 공동이용은 2이상 전기사용계약단위에 대하여 하나의 수급지점을 정하고 계약종별 또는 사용자별로 전기요금을 계산청구하는 것으로 자고객의 수급지점은 모고객과 동일하며 자고객이 저압계량을 하는 경우에도 공급전압은 수급지점에서의 전압이 됩니다.변압기공동이용은 고객의 요청 또는 사전협의가 있는 경우에 적용하며 계약전력 및 전력사용량 조정은 사전에 한전과 약정하여야 합니다.그리고 변압기공동이용 고객은 대표고객과 동일한 유형의 전기계기를 부설함을 원칙으로 하나 변압기공동이용고객(자(子)고객) 대하여는 계약전력 500kW 미만까지 저압계량 할 수 있습니다.▣ 변압기 공동이용 방법(1) 66kV 이상으로 공급받는 고객이 동일구내에 있거나 인접하여 있는 대표고객의 동의 아래 변압기 설비를 공동이용하여 전기를 공급받고자 하는 경우(1사용장소 또는 별사용장소로 구분 가능)(2) 고압이나 22.9㎸ 이하 특별고압으로 공급받고 있는 고객과 동일 전기사용장소에서 계약종별 또는 회계단위가 서로 달라 전기사용계약단위를 분리하는 경우로서 대표고객의 동의를 얻어 변압기설비 를 공동이용하여 전기를 공급받고자 하는 경우▣ 변압기설비 공동이용고객의 요금계산(1) 계약전력 결정가. 대표고객(모고객)의 계약전력은 전체의 계약전력에서 공동이용고객(자고객)의 계약전력을 차감합 니다. 다만, 자고객이 심야전력(갑)인 경우에는 차감하지 아니하며, 공동주택의 주택용전력 적용 대상 고객은 먼저 호당 500W로 간주하여 차감합니다.나. 공동이용고객(자고객)의 계약전력이 비정상적으로 산정되어 가의 적용이 비합리적인 경우에 는 각 고객별 2차 변압기 또는 사용설비를 조사하여 전체 계약전력을 구분하여 다시 결정합니다.다. 공동이용고객(자고객)이 주택용전력인 경우에는 주택용전력 전체 사용설비를 1전기사용장소로 보아 사용설비에 따라 계약전력을 재산정하여 차감합니다.(2) 최대수요전력 및 사용전력량 조정 대표고객(모고객)과 공동이용고객(자고객)이 동일유형의 계기를 설치한 경우에는 대표고객(모고객)의 계기에 시현된 최대수요전력 및 사용전력량에서 공동 이용고객(자고객)의 계기에 시현된 최대수요전력 및 사용전력량을 각각 차감하고, 동일유형계기가 아닌 경우에는 전기공급약관 시행세칙 제49조 7항 2의 기준표를 적용합니다.'],
#  [3,
#   ['공장/NNG',
#    '옆/NNG',
#    '공장/NNG',
#    '변압기/NNG',
#    '용량/NNG',
#    '일부/NNG',
#    '연결/NNG',
#    '사용/NNG'],
#   '동일한 전기사용 장소내에서 전기를 사용하고 계약종별 또는 회계단위가 상이한 2이상의 고객이 변압기를공동이용하고자 할 경우로서 변압기설비를 공용하는 것이 타당하다고 한전에서 인정하면 각 고객별로전기사용계약을 체결하고 따로 계량하여 사용할 수 있습니다. 공동사용 고객들은 전기사업법에서 정한책임과 기타 공용으로 인하여 예상되는 제반사항의 처리방법 등의 내용을 고객간에 명확히 정하여야 합니다.한전과의 책임한계점은 대표고객의 수급지점이 되고 대표고객이 전기안전책임을 지게 됩니다.'],
#  [4,
#   ['전기/NNG',
#    '설비/NNG',
#    '중/NNG',
#    '냉/NNG',
#    '난방/NNG',
#    '기기/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    '산정/NNG'],
#   '여름철에만 사용하는 설비와 겨울철에만 사용하는 설비가 1Set로 구성되어 냉난방용 전기설비가섞여 있으나 냉난방 기능별로 분리 사용되는 전기설비는 고객이 희망하는 경우 그 중 용량이 큰쪽의사용설비를 계약전력 산정기준으로 할 수 있습니다.'],
#  [5,
#   ['고압/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    'kW/OL',
#    '인/NNG',
#    '공장/NNG',
#    '한전/NNG',
#    '최대/NNG',
#    '수요/NNG',
#    '전력/NNG',
#    '증설/NNG',
#    '안내문/NNG',
#    '조치/NNG'],
#   '최대수요전력이 계약전력을 초과한 첫번째 달에는 증설 안내를 해드리며 초과사용부가금을 적용하지 않으나, 계약전력을 초과한 첫번째 달로부터 3년이내에 최대수요전력이 다시 계약전력을 초과하거나최종 초과사용부가금을 부과한 월로부터 3년이내에 최대수요전력이 다시 계약전력을 초과할 경우에는 초과전력에 해당 계약종별 기본요금 단가의 150%를 적용한 초과사용부가금을 부과합니다.[전기공급약관 제 44조, 전기공급약관 시행세칙 제 29조]'],
#  [6,
#   ['임시/NNG',
#    '전력/NNG',
#    'kW/OL',
#    '신청/NNG',
#    '수전/NNG',
#    '변압기/NNG',
#    '설치/NNG',
#    '저압/NNG',
#    '계량/NNG',
#    '가능/NNG'],
#   '고압으로 공급받는 계약전력 500kW 미만의 임시전력고객은 고객이 수전변압기를 설치하여저압으로 계량 할 수 있으며 이 때 발생하는 변압기 손실량은 사용량에 가산합니다.이 경우수급지점이 변압기 1차측이므로 자가용전기설비설치고객에 해당되어 안전관리자 선임 및 전기안전공사 사용전 검사, 전기사용계약서를 작성하여야 합니다.'],
#  [7,
#   ['주택/NNG', '임시/NNG', '전력/NNG', '별도/NNG', '신청/NNG', '전기/NNG', '사용/NNG'],
#   '주택용전력을 사용하는 고객이 동일 전기사용 장소에서 동일용도의 건물을 재건축하는 경우 재건축에필요한 전기는 별도의 임시전력 신청없이 계속 주택용전력 1계약을 적용하여 사용할 수 있습니다.다만 주택철거 및 건물 준공에 따른 계기이설은 고객부담으로 시공하셔야 하며 계기이설시는 반드시한전 관할사업소에 연락하셔야 합니다.주택 재건축시 전기사용신청 절차건축물 철거(목적물 멸실) -- 건축공사 -- 건축물준공 계기이설(인입선위치변경) 주택용전력으로계속 사용 계기이설(인입선위치변경)'],
#  [8,
#   ['동일/NNG',
#    '구내/NNG',
#    '공장/NNG',
#    '증축/NNG',
#    '임시/NNG',
#    '전력/NNG',
#    '신청/NNG',
#    '기존/NNG',
#    '구좌/NNG',
#    '전기/NNG',
#    '이용/NNG',
#    '건물/NNG',
#    '증축/NNG'],
#   '기설고객이 계약전력의 범위내에서 기존설비의 확장(건물 및 기계설비의 신증축포함)이나 건물기계기타설비의 보수 또는 개조를 위하여 제한된 기간동안 전기를 사용할 경우에는별도의 임시전력 신청없이도 전기를 사용할 수 있으며 그 부분에 대한 사용량도 기 계약된계약종별을 적용할 수 있습니다.'],
#  [9,
#   ['임시/NNG',
#    '전력/NNG',
#    '신규/NNG',
#    '고객/NNG',
#    '고객/NNG',
#    '모든/NNP',
#    '시설/NNG',
#    '부담금/NNG',
#    '부담/NNG',
#    '별도/NNG',
#    '보증금/NNG',
#    '납/NNG',
#    '부하/NNG'],
#   '임시전력에 대한 보증금은 전기사용형태의 특성상 사용 개시후의 전기요금을 납기일에납부하지 아니할 경우 대체하기 위한 것이며 고객이 희망할 때는 현금예치 대신 이행보증보험증권, 금융기관의 지급보증서, 건설공제조합주택사업공제조합전기공사공제조합의 임시전력 보증금보증서 제출로 대신할 수 있습니다.'],
#  [10,
#   ['신축/NNG',
#    '건물/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '지중/NNG',
#    '배전/NNG',
#    '지역/NNG',
#    '고시/NNG',
#    '지중/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '공중전/NNG',
#    '선로/NNG',
#    '전기/NNG',
#    '공급/NNG'],
#   '한전의 전기공급설비 시설은 공중전선로와 지중전선로의 2가지 방법이 있는데, 한전이시설하는 전선로는 공중전선로로 하는 것이 원칙입니다. 다만, 법령상 지중으로 시설하도록되어 있거나 이미 지중으로 공급되고 있는 지역또는 기술적으로 부득이한 경우는지중으로 시설하고 있습니다.'],
#  [11,
#   ['임시/NNG',
#    '전력/NNG',
#    '외선/NNG',
#    '공사/NNG',
#    '전기/NNG',
#    '사용자/NNG',
#    '시공/NNG',
#    '경우/NNG',
#    '신청/NNG',
#    '절차/NNG',
#    '만일/NNG',
#    '활/NNG',
#    '선/NNG',
#    '공사/NNG',
#    '수반/NNG',
#    '경우/NNG',
#    '활/NNG',
#    '선/NNG',
#    '공사/NNG',
#    '한전/NNG',
#    '시공/NNG'],
#   '일반고객의 공급에 지장이 없을 경우, 한전 기설 공급설비에 연결하여 고객소유선로를구성한 후 임시전력을 공급할 수 있습니다. 이 경우에는 외선공사 설계서를 한전에제출하여 설계의 적정여부를 검토받은 후 한전 감독의 입회하에 고객이 책임 시공(착준공계 제출)하셔야 합니다. 그리고 수급지점 연결공사시 활선이 수반될 경우 활선작업에 따른 소요공사비는 고객부담으로 하여 한전에서 활선작업을 합니다.'],
#  [12,
#   ['일반용/NNG',
#    '전기/NNG',
#    '설비/NNG',
#    '자가용/NNG',
#    '전기/NNG',
#    '설비/NNG',
#    '각각/NNG',
#    '대상/NNG'],
#   '일반용 전기설비란 전기사업법에 따라 수전전압 600V 이하(한전 표준전압기준：380V 이하)로서 계약전력 75kW 미만의 전기설비(제조업 또는 심야전력이용 설비 계약전력 100kW 미만)가 이에 속합니다. 그리고 일반용전기설비 이외의 전기설비를 자가용전기설비라고 합니다(자가용전기설비의 경우 안전관리자를 선임해야하나 저압200kW 미만인 제조업제조업관련 서비스업 및 심야전력 이용설비는 면제합니다). 다만 수전전압 600V 이하로서 계약전력 75kW 미만 고객이라 하더라도 사용설비 규모가 20kW 이상인 아래의 경우는 자가용전기설비의 대상이 됩니다.(1) 다음의 위험시설에 설치하는 전기설비 가. 「총포도검화약류 등 단속법」 제2조 제3항에 따른 화약류(장난감용 꽃불은 제외)를 제조하는 사업장 나. 「광산보안법 시행령」 제3조 제1항 제2호 가목에 따른 갑종탄광다. 「도시가스사업법」에 따른 도시가스사업장, 「액화석유가스의 안전관리 및 사업법」에 따른 액화석유가스의 저장ㆍ충전 및 판매사업장 또는 「고압가스 안전관리법」에 따른 고압가스의 제조소 및 저장소 라. 「위험물 안전관리법」 제2조제1항제3호 및 제5호에 따른 위험물의 제조소 또는 취급소(2) 다음의 여러 사람이 이용하는 시설에 설치하는 전기설비가. 「공연법」 제2조제4호에 따른 공연장나. 「영화 및 비디오물의 진흥에 관한 법률」 제2조제10호에 따른 영화상영관다. 「식품위생법 시행령」에 따른 유흥주점ㆍ단란주점라. 「체육시설의 설치ㆍ이용에 관한 법률」에 따른 체력단련장마. 「유통산업발전법」 제2조제3호 및 제6호에 따른 대규모점포 및 상점가바. 「의료법」 제3조에 따른 의료기관사. 「관광진흥법」에 따른 호텔아. 「소방시설 설치유지 및 안전관리에 관한 법률 시행령」에 따른 집회장'],
#  [13,
#   ['상가/NNG',
#    '부/NNG',
#    '공동/NNG',
#    '주택/NNG',
#    '상점/NNG',
#    '주택/NNG',
#    '구분/NNG',
#    '별도/NNG',
#    '계량기/NNG'],
#   '1전기사용장소에 독립된 주택부분과 상점부분이 있고 그 사이가 고정된 벽으로 구분되어있을 경우에는 주택, 상점을 포함하여 1사용장소로 할 경우 그 전체를 1전기사용계약 단위로할 수 있습니다.그리고 주택은 주거부분 전부 또는 독립된 가구별로, 상점은 상가부분 전부또는 각 상점별로각각 1전기사용계약을 체결할 수도 있습니다.'],
#  [14,
#   ['계약/NNG',
#    '전력/NNG',
#    'kW/OL',
#    '이상인/NNP',
#    '건물/NNG',
#    '부동산/NNG',
#    '임대업/NNG',
#    '건물/NNG',
#    '소유자/NNG',
#    '층/NNG',
#    '별/NNG',
#    '계량기/NNG'],
#   '고압이상의 전압으로 공급하는 전기사용장소의 전기사용계약단위 구분기준은 아래와 같습니다.(가)1 전기사용장소 전체 계약전력의 합계가 1,000kW 이상인 경우 - 고정된 벽 등으로 구분된 소유자별, 층별, 전용변압기별로 전기사용계약단위 구분가능(나) 1 전기사용장소 전체 계약전력의 합계가 1,000kW 미만인 경우 - 고정된 벽 등으로 구분되고 사용자가 다른 2이상의 부분이 있을 경우 각 부분을 1전기사용계약단위로 구분가능상기 가, 나 의 경우 모두 승강기등 공동설비는 별개 전기사용계약단위로 구분하는것이 원칙'],
#  [15,
#   ['다세대/NNG',
#    '주택/NNG',
#    '연립/NNG',
#    '주택/NNG',
#    '전문/NNG',
#    '건축/NNG',
#    '건설/NNG',
#    '회사/NNG',
#    '주택/NNG',
#    '준공/NNG',
#    '현재/NNG',
#    '미분양/NNG',
#    '상태/NNG',
#    '호별/NNG',
#    '계량기/NNG'],
#   '연립주택, 다세대주택과 같은 공동주택은 소유권에 관계없이 독립된 각1호를 1 전기사용계약 단위로보기 때문에 호별로 계량기를 설치할 수 있습니다.양배수설비와 복도계단현관 등에 설치한 조명용전등 및 소형기기는 별 전기사용계약 단위로 하여야 합니다.'],
#  [16,
#   ['계약/NNG',
#    '전력/NNG',
#    '계량기/NNG',
#    '용량/NNG',
#    '선정/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    '증설/NNG',
#    '시/NNG',
#    '계량기/NNG',
#    '교환/NNG'],
#   '계량기는 계약전력에 따라 아래와 같이 적정용량의 계량기를 선정하셔야 하며, 계약전력의변경시에는 적정한 계량기로 교체하셔야 안전하고 사용량을 적정하게 계량할 수 있습니다.단, 일부해지나 증설의 경우에 변경후의 계기용량이 변경전 계기용량의 120%이내일 경우는그대로 사용할 수도 있습니다.'],
#  [17,
#   ['행사장/NNG',
#    '며칠/NNG',
#    '임시/NNG',
#    '전력/NNG',
#    '사용/NNG',
#    '계량기/NNG',
#    '설치/NNG',
#    '전기/NNG',
#    '요금/NNG',
#    '계산/NNG',
#    '방법/NNG'],
#   '현장여건에 따라 전력량계를 설치하는 것이 부적당하거나 기타 부득이한 사정으로전력량계를 설치할 수 없는 경우에는 전기공급약관 세칙 제54조 ① 3에 의하여고객과 한전이 사용전력량을 협정하여 전기요금을 계산할 수 있습니다. 만약 사용설비를무단으로 설치하여 전기를 사용할 경우는 위약으로 처리됩니다.사용량 협정방법: 사용설비용량(입력kW)1일사용시간협정대상일수=협정사용량 계량기를 설치하지 않는 경우에도 시설부담금은 부과됩니다.'],
#  [18,
#   ['현재/NNG',
#    '옆/NNG',
#    '건물/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '가두/NNG',
#    '판매대/NNG',
#    '계량기/NNG',
#    '별도/NNG',
#    '전기/NNG',
#    '사용/NNG'],
#   '토큰판매나 가두판매대에서도 전기를 사용할 수 있습니다. 다만, 행정기관으로부터 가두판매 허가를 필한 사용장소만 한전 계량기를 달 수 있습니다.'],
#  [19,
#   ['가구/NNG',
#    '제조/NNG',
#    '공장/NNG',
#    '등록/NNG',
#    '건물/NNG',
#    '임차/NNG',
#    '후/NNG',
#    '건축물/NNG',
#    '관리/NNG',
#    '대장/NNG',
#    '열람/NNG',
#    '건축물/NNG',
#    '용도/NNG',
#    '축사/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '가능/NNG'],
#   '건축물용도와 전기사용 용도가 일치하지 않더라도 실제용도에 따라 계약종별을 적용합니다. 만약 고객이 농사용(을)로 전기공급을 받은 후 산업용으로 전기를 사용하는 경우에는 전기사용계약 위반(계약종별)에 해당되어 위약추징금을 부과하고 전기공급을 정지할 수 있습니다.'],
#  [20,
#   ['전기/NNG', '사용/NNG', '전과/NNG', '수급/NNG', '지점/NNG', '수급/NNG', '지점/NNG'],
#   '수급지점이라 함은 고객의 전기설비와 한전 전선로 또는 인입선과의 연결점으로서 전기설비의소유한계점을 말합니다.즉, 한전과 고객간의 전기설비의 안전 및 유지보수의 책임한계점으로수급지점까지의 전기공급설비는 한전에서 시설 소유하고 수급지점 이후의 전기설비는 고객이시설, 소유하고 유지 보수합니다.수급지점의 결정은 원칙적으로 한전 배전선로에서 가장 가까운거리에 있는 전기사용장소내의 한 지점을 기준으로 경제성, 안전성을 고려 고객과 협의하여 결정합니다.다만 수급지점을 전기사용장소내의 지점으로 할 수 없을 경우에는 예외적으로 전기사용장소 이외의 지점을수급지점으로 할 수 있습니다. 공급설비 유형에 따른 수급지점가. 전용공급설비인 경우의 수급지점은 전 2의 고압인 경우 수급지점과동일하게 적용나. 변압기설비를 공동이용하는 경우의 수급지점은 대표고객의 수급지점과 동일하게 적용다. 고객이 시설소유하는 공급설비의 수급지점은 한전 전선로와 고객소유 전선로의 분기 접속점이 됨라. 22.9kV S.N.W 방식으로 공급하는 경우의 수급지점은 한전에서 시설하는 케이블 분기접속장치 부하측접속점으로 한다. 다만, 한전 전기공급설비의 구성상 부득이한 경우에는 22.9kV S.N.W 변압기 1차측에 고객이 시설하는 개폐장치의전원측 접속점으로 함(3) 고압 임시공급설비의 수급지점은 전 2의 고압인 경우 수급지점과 동일하게 적용하되 고객이 희망 할경우에는 개폐기 고객측 단자 접속점을 수급지점으로 할 수 있음.(4) 기타 특별한 사정으로 부득이하다고 사업소장이 인정하는 경우 전기사용장소의 위치 및 특성을 고려하여수급지점을 달리 정할 수 있음.'],
#  [21,
#   ['주택/NNG',
#    '신축/NNG',
#    '현장/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '이웃집/NNG',
#    '전기/NNG',
#    '연결/NNG',
#    '사용/NNG'],
#   '전기는 고객과 한전간에 계약된 사용장소 이외의 다른 장소에 전선을 임의로 연결하여 사용할 수없습니다.따라서 주택을 신축하거나 재해복구, 전람회 등 일정기간 전기를 사용하고자 하는 경우에는 임시전력으로 전기를 공급하고 있으니 한전에 임시전력을 신청하신 후 사용하셔야 합니다.'],
#  [22,
#   ['엘리베이터/NNG',
#    '층/NNG',
#    '사무실/NNG',
#    '임대/NNG',
#    '빌딩/NNG',
#    '신축/NNG',
#    '층/NNG',
#    '별/NNG',
#    '계량기/NNG'],
#   '저압으로 공급하는 경우 계약전력 999㎾까지 건물내 계약단위 분할이 가능합니다.(단 1계약단위의 계약전력은 500kW미만이어야 함) 고압으로 전기를 공급받는 고객은 1전기장소의 계약전력이 1,000㎾ 이상인 경우 고정된 벽 등으로 구분된 소유자별, 사용자가 다른 전용변압기별, 층별로 전기사용계약단위로 구분가능하며 1,000㎾미만인 경우 고정된 벽 등으로 구분된 경우 사용자별 전기사용계약단위로 구분 가능합니다.'],
#  [23,
#   ['수중/NNG',
#    '전동기/NNG',
#    '일반/NNG',
#    '전동기/NNG',
#    '방법/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    '산정/NNG',
#    '구체적/NNG'],
#   '수중전동기에 표시된 정격출력은 수중전동기와 직결된 펌프의 기계적 출력을 표시한 것이므로수중전동기의 계약전력은 기계적 출력에 대하여 수중전동기의 실제출력을 환산한 후 일반전동기환산율을 적용하여 결정하며 전동기 가동 성격상 오배수용, 깊은 우물용으로 구분합니다.'],
#  [24,
#   ['신축/NNG',
#    '건물/NNG',
#    '고압/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '변압기/NNG',
#    '설치/NNG',
#    '변압기/NNG',
#    '용량/NNG',
#    '표시/NNG',
#    '표시/NNG',
#    '변압기/NNG',
#    '설비/NNG',
#    '계약/NNG',
#    '경우/NNG',
#    '계약/NNG',
#    '전력/NNG'],
#   '변압기용량 표시가 두가지로 되어 있는 것은 큰 것을 기준으로 계약전력을 산정하며 변압기상의두가지 용량표시가 풍냉장치(Fan：변압기이용률 향상장치)에 의한 것은 고객이 원하는 경우에풍냉장치를 전부 제거하는 조건으로 용량이 작은 것을 기준으로 계약전력을 산정할 수 있습니다.'],
#  [25,
#   ['계약/NNG',
#    '전력/NNG',
#    'kW/OL',
#    '초과/NNG',
#    '대/NNG',
#    '단위/NNG',
#    '공장/NNG',
#    '건립/NNG',
#    'V/OL',
#    '전기/NNG',
#    '공급/NNG',
#    '900V-y/OL',
#    '공급/NNG',
#    '방법/NNG'],
#   '계약전력이 40,000kW를 초과 400,000kW 이하인 경우에는 원칙적으로 154kV로 수전하여야 합니다. 다만, 한전 요청에 의거 한전에 154kV 변전소건설 부지를 영구제공(유상 또는 무상)할 경우에는 22.9kV-y(고객소유선로) 공급전압으로 수전받을 수 있습니다.'],
#  [26,
#   ['W/OL',
#    'V/OL',
#    '공급/NNG',
#    '식당/NNG',
#    '에어콘/NNG',
#    '설치/NNG',
#    '에어컨/NNG',
#    '계량기/NNG',
#    '별도/NNG',
#    '부착/NNG'],
#   '동일 전기사용 장소내에 전기공급방식이 서로 다른 저압사용설비가 있는 경우에 전기공급방식별로전기사용계약을 체결할 수 없습니다. 에어콘 사용전압이 380V이면 별계량이 불가능하므로 기존12W 220V 구좌를 34W 220V/380V로 공급방식을 변경, 증설 신청하셔야 합니다.'],
#  [27,
#   ['대지/NNG',
#    '쓰레기/NNG',
#    '처리장/NNG',
#    '건립/NNG',
#    '처리/NNG',
#    '장내/NNG',
#    '하천/NNG',
#    '경우/NNG',
#    '계량/NNG',
#    '전기/NNG',
#    '공급/NNG'],
#   '전기를 공급하기 위한 전기사용장소 구분기준은 담장, 도로 등으로 구분되고 1회계 주체에의하여 관리되어 1구내를 이루는 것은 1구내를,독립된 각동의 건물일 경우는 독립된 건물 1동을1전기사용장소로 합니다. 전체를 1구내로 하여 1계량으로 공급하는 경우 인접한 2이상의 구내로서그사이에 제3자가 전기사용장소를 설정할 수 없는 도로(공로), 하천 등에 의하여 구분되고 각 구내가동일 회계주체에 속하는 경우에는 그 전체를1구내로 볼 수 있기 때문에 1계량(전기사용계약)으로전기공급이 가능합니다.※ 전기사용장소란 단순한 지리적 개념이 아니고 토지나 건물 등의 소유자 또는 사용자별로 전기를공급하는 장소로서 1구내1건물을 말하며 전기공급방식 및 공급전압을 결정하는기준이 됩니다.다만, 1구내 또는 1건물이라도 회계주체, 계약종별 및 전기공급방식이 상이할 경우는 1구내 또는1건물을 분할하여 전기사용계약을 체결할 수 있습니다.'],
#  [28,
#   ['저압/NNG', '특별/NNG', '고압/NNG', '구분/NNG', '말씀/NNG'],
#   '저압, 고압, 특별고압이라고 하는 것은 표준전압을 의미하는데 표준전압이라는 것은한국전력공사가 고객에게 전기를 공급하는 전선로의 전압을 말하며 저압은 220V, 380V이고,특별고압은 22,900V, 154,000V, 345,000V로 공급하는 것을 의미하며 그 표시는 전선로를대표하는 선간전압으로 표시한 것입니다. * 전기사업법상 저압은 교류 600V 이하 전압,고압은 교류 600V 초과 7,000V 이하, 특별고압은 7,000V를 초과하는 전압으로 분류됩니다.'],
#  [29,
#   ['계량기/NNG',
#    '집이/NNG',
#    '전기/NNG',
#    '세입자/NNG',
#    '전기/NNG',
#    '요금/NNG',
#    '분쟁/NNG',
#    '한전/NNG',
#    '계량기/NNG',
#    '전기/NNG',
#    '요금/NNG',
#    '청구서/NNG',
#    '가구/NNG'],
#   '1주택에 여러가구가 거주하는 경우 세대별 전기요금 배분에 대한 분쟁을 막기 위한 방법으로는 구좌분할을 하여 한전계량기를 각각 설치하시거나 보조계량기를 설치하여 사용자별 사용량을 확인하는 방법이 있습니다.▣ 구좌분할 ㅇ 별도로 한전계량기를 달기 위한 구좌분할은 먼저 전기공사업면허를 가진 전기공사업자를 선정하여 옥내 배선공사를 하신후 한전지사에 전기사용신청을 하시면 되는데, 한전에 납부하셔야할 시설부담금은 특별한 경우를 제외하고 1대(계약전력 5kW) 당 242,000원(부가세포함, 저압 공중공급의 경우)이며 이는 전기공사업체에 지불하는 옥내 내선분리공사비와는 별개입니다.전기사용신청은`전기사용신규신청(새창열림) 사이버지점신청접수전기사용신규신청에서 인터넷으로 신청하시거나 관할 한전에 우편이나 FAX로 직접 신청하실 수 있으며,전기공사업체를 통한 대행신청도 가능합니다.전기사용신청서 이외에 별도의 구비서류는 없으며, 신청서에 건축물관리대장(또는 건물등기부등본) 번호와 신청인의 주민등록번호를 정확히 기재하시고,내선공사업체를 통해 신청서 뒷면의 내선설비시공내역 및 점검표를 작성하여 관할 한전에 제출하시면 됩니다.▣ 보조계량기 설치 ㅇ 옥내배선공사 등의 절차와 비용이 부담스러우시면 구좌분할 없이 보조계량기를 설치하시면 사용자별로 전기사용량을 확인하실 수 있으며, 전기요금 배분에 참고하실 수 있습니다.단, 보조계량기는 고객께서 직접 전기공사업체를 통해 구입하여 설치하셔야 합니다.'],
#  [30,
#   ['시의/NNG',
#    '양수/NNG',
#    '목적/NNG',
#    '관정/NNG',
#    '설치/NNG',
#    '전동기/NNG',
#    '명판/NNG',
#    '표시/NNG',
#    '단상/NNG',
#    '공급/NNG'],
#   '전동기 사용설비는 기기의 특수성으로 인하여 기동형별로 조금씩 다른데 기동전류가 37A를 초과하는 경우 삼상전동기를 구입하여 설치하셔야 합니다.다만, 삼상전원이 없는 지역에서는 전동기 1대의 출력(동시 기동이 가능한 경우는 그 합계)이 변압기 출력의 1/10이하일 경우에는 전등공용변압기에서 공급할 수 있으며, 1/10을 초과할 경우에는 단독변압기를 설치하여 공급이 가능합니다.'],
#  [31,
#   ['아파트/NNG', '전기/NNG', '사용/NNG', '계약/NNG', '방법/NNG'],
#   '1. 단일계약 (1구내 전부를 1전기사용계약)가. 전기사용계약단위 구분(1) 아파트전체를 1전기사용계약(2) 공동설비는 주택용 전력을 적용하며 아파트 상수도 가압설비, 오수정화설비 및 구내보안등을 모자거래에 의하여 계량할 경우에는 해당 계약종별(산업용, 가로등)을 적용합니다.* 상가부분은 아파트와 별개의 전기사용장소로 간주하여 전기사용계약단위를 결정합니다.나. 공동설비등에 대한 공급방법 전기요금요율을 달리하는 공동설비(상수도가압설비, 오수정화설비, 구내보안 등)가 산업용전력 또는 가로등(을)로 계약된 경우에는 변압기 공동이용방식으로 각자 고객의 계약전력 500kW 미만까지 저압 계량 할 수 있습니다.(다만, 고객이 전기사용계약을 희망하지 않을 경우 모든 공동설비는 주택용전력 적용)다. 요금청구방법 전기요금청구서 1매로 청구하고 한전의 청구요금에 대한 아파트 자체내의 호별 배분은 아파트관리자 (대표자)가 처리라. 적용시기 : 건물 준공일(준공전 임시사용승인의 경우 임시사용승인일) 이후 최초 입주자가 입주한 날부터 적용2. 종합계약가. 적용대상 : 아파트의 1구내에 대하여 고압 이상으로 전기를 공급하고 요금계산은 고객이 제출하는 호별 사용전력량에 의하여 계산하는 경우에 적용(한전에서 호별 요금 내역서 또는 호별 영수증 교부)나. 요금계산 : 주거부분 호별 사용량은 주택용 저압요금, 공동설비 사용량은 일반용 고압요금 적용다. 종합계약서 작성 : 고객의 요청에 의하여 아파트관리자 또는 건축주와 아파트 종합계약서에 의거 계약체결 (종합계약기간 은 요금적용개시일 이후 1년이 되는 날까지로 하며 쌍방 종합계약의 해지변경요청이 없는 한 1년 마다 동일한 조건으로 계약 지속)라. 요금청구방법 : 종합 전기요금청구서와 호별 요금내역서 또는 호별 영수증을 교부하면 아파트 관리자(대표자)가 호별 로 요금을 수금하여 종합전기요금 청구서로 납부마.적용시기 : 상시수전설비 준공일로부터 적용가능※아파트 고객이종합계약에서 단일계약으로 변경을 요청하는 경우- 신청일이 속하는 월분부터 단일계약으로 계약변경※ 아파트 고객이 단일계약에서 종합계약으로 변경을 요청하는 경우- 신청일부터 검침일까지 기간이 5영업일 이상일 경우 계약변경 : 전산등록, 세대별 검침장 제작, 검침장 제출 등 행정소요일 필요※ 요금계산 방법을 변경한 고객은 변경후 1년 이내에 다른 요금계산 방법으로 변경할 수 없습니다.(예외) - 고압아파트 요금제도 변경,아파트 관리주체가 건설 사업주체에서 관리사무소 등으로 변경되는 경우에는 1년이내라도 1회에 한하여 계약방법 변경 가능 - 신규고객은 신설 후 1년이내 2회에 한하여 계약방법 변경 가능※종합계약이나 단일계약같은 고압 일괄공급방식을 저압 호별공급방식으로 변경요구시 전력설비 시설공간 영구 무상제공 및시설부담금 추가부담에 대한 아파트 입주민의 전원합의가 있으면 계약방법변경이 가능합니다.'],
#  [32,
#   ['전기/NNG', '공급/NNG', '약관/NNG', '적용/NNG', '구역/NNG'],
#   '일반전기사업자인 한국전력공사가 전기공급구역을 설정할 때는 산업통상자원부장관의 허가를 받도록되어 있습니다. 따라서, 전기공급약관 적용은 산업통상자원부장관의 허가를 받은 공급구역에 적용합니다.'],
#  [33,
#   ['대형/NNG',
#    '음식점/NNG',
#    '냉장고/NNG',
#    '에어콘/NNG',
#    '설비/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '설비/NNG',
#    '용량/NNG',
#    'kW/OL',
#    '정도/NNG',
#    '저압/NNG',
#    '공급/NNG'],
#   '○ 전기사용 장소내의 계약전력이 1,000kW 미만일 경우 저압으로 공급할 수 있으며 고객희망시 기준전압보다 상위전압으로 공급할 수 있습니다. 다만, 1,000kW 미만까지 저압으로 공급시 1계약단위의 계약전력은 500kW미만이어야 합니다.'],
#  [34,
#   ['전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '취소/NNG',
#    '신청/NNG',
#    '경우/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '신청서/NNG',
#    '구비/NNG',
#    '서류/NNG',
#    '제출/NNG'],
#   '전기사용신청이 취소된 후 재신청하는 경우에는 전기사용신청서를 새로 제출하셔야 하며구비서류는내용변경이 없는 한 다시 제출하실 필요는 없습니다.'],
#  [35,
#   ['특수/NNG',
#    '사용/NNG',
#    '설비/NNG',
#    '전기용접기/NNG',
#    '의/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '절차/NNG'],
#   '용접기, 전기로 등 다른 고객의 전기사용을 방해할 우려가 있을 경우에는 단독변압기를 설치하여별도 전기사용계약을 체결합니다. 다만 34W 220V/380V 공급고객이 단상용접기를 사용할 경우로서 아래와 같은 경우에 해당하는 경우에는 증설 신청을 하셔야 하며 전용저압선 및 인입선을 시설하셔야 합니다. - 사용 용접기가 10kVA 이하로서 공용변압기 용량이 50kVA 이상인 경우- 공급하는 변압기가 당해 고객만 공급하는 경우'],
#  [36,
#   ['태양광/NNG', '발전/NNG', '절차/NNG'],
#   '태양광 발전은 여러 기관이 연계되어 있어서 다소 복잡하게 느껴지실 수 있습니다.먼저 산업통상자원부(3,000kW 초과)나 시도(3,000kW 이하)를 통해 발전사업 허가를 받으신 후에 가까운 한전으로 전력수급계약(PPA) 신청을 하면 됩니다.자세한 내용은 붙임파일의 가이드북을 참고하시기 바랍니다'],
#  [37,
#   ['공장/NNG', '이전/NNG', '전기/NNG', '설비/NNG', '사용/NNG'],
#   '고객의 전기사용설비는 옮길 수 있으나 전기는 전기사용계약시 계약된 일정사용장소에서만사용할 수 있습니다. 따라서 전기사용설비를 다른 곳으로 옮겨 사용하고자 하는 경우에는이전된 장소에서 새로이 전기사용신청을 하셔야 하며 종전에 사용하던 전기사용계약은 해지신청하셔야 합니다.'],
#  [38,
#   ['전기/NNG', '사용/NNG', '신설/NNG'],
#   '전기 신설 및 증설에 따른 사용 신청은 먼저 전기공사 면허업체를 선정하여 내선공사를 하고 전기사용신청서 등 구비서류를 준비하여 관할한전에 신청하시면 됩니다.1. 신청방법- 직접방문, 우편 또는 FAX 이용(고객희망시 해당 전기공사업자가 대행 가능)-사이버지점 신청 (심야전력, 정액제 고객은 제외) (`업무찾기(새창열림)`>사이버지점신청접수업무찾기에서 전기사용신청 조회)2. 구비서류전기사용신청서(II) (한전양식)※ 단, 건물소유자가 아닌 사용자(임차인 등) 명의로 신청시는 전기사용신청서의 전기사용자란 밑에 소유자 날인 후 임대차계약서 사본 첨부 필요하며 계약전력 20㎾초과시 보증조치 필요(현금보증이 원칙이며, 고객희망시 이행보증보험, 지급보증 및 연대보증으로 가능) * 주민등록증 사본* 건축허가신고서 사본, 건축물관리대장, 건물등기부등본 중 택일※ 위 증빙서류를 첨부할 수 없는 경우 지방자치단체에 등록된 무허가건물은 무허가건축물확인서 제출하고, 지방자치단체에 등록되지 않은 무허가건물 및 건축허가(신고)제외 고객(모래및골재채취장,광산,간이상수도,농사용지하수 등)은 토지대장, 공급정지동의각서, 보증금 제출(단, 컨데이너등 조립식 가건물은 가설건축물 축조신고필증 제출)* 사용전 점검신청서 및 전기설비단선결선도(사용전점검 수행기관이 안전공사인 경우 사용전점검필증 사본 제출)* 사업자등록증 사본(산업용 및 세금계산서 필요시)* 사용전검사필증 사본 및 내선설계도(자가용전기설비)* 전기사용신청서의 사용설비 및 콘덴서 내역※ 사용전점검 수행기관이 한전인 경우 전기사용신청서와 별도로 사용전점검신청서와 단선결선도(옥내배선도)를 사용전점검 희망일 3일전까지 제출해야 하고,사업자등록증 사본, 사용전 검사실시 확인서는 전기사용개시전까지 제출하면 되고, 사업자등록증 사본을 전기사용개시전까지 제출하지 못하는 경우에는 주민등록증 사본 또는 다른 전기사용장소의 사업자등록증 사본(사업체 이전의 경우)의 제출도 가능(단, 사업자등록증 발급즉시 그 사본 제출)※ 농사용 관정(지하수): 시장,군수의 지하수개발 신고서(허가서)와 토지대장 제출※ 전기사용신청이 취소된 후 재신청하는 경우에는 전기사용신청서를 새로 제출하셔야 하며 첨부서류는 내용변경이 없는 한 다시 제출하실 필요는 없습니다.3.전기사용신청과 관련하여 고객께서 한전에 납부해야할시설부담금은 특별한 경우를 제외하고 대부분 표준시설부담금을 적용합니다.(이는 고객께서 전기공사업체에 지불하는 옥내 내선공사비와는 별개이오니 착오 없으시기 바랍니다.) 거리시설부담금 단가표참고4. 전기공급시기 - 기존설비로 공급이 가능한 경우에는 24시간 이내에- 전주 및 변압기 설치 등 외선공사가 필요한 경우에는 고객의 희망일에 송전하여 드리며(다만, 지중으로 전기를 공급받는 고객에 대해서는 처리 기준 일정을 고객과 협의하여 공급가능시기를 결정하게 됨)- 빌딩, 공장 등 대용량고객께서는 신증축 계획단계에서 한전과 협의하여 주시면 보다 원활하게 전기 를 공급받으실 수 있습니다.'],
#  [39,
#   ['건축물/NNG',
#    '관련/NNG',
#    '증빙/NNG',
#    '서류/NNG',
#    '무허가/NNG',
#    '건물/NNG',
#    '경우/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '신청/NNG'],
#   '한전은 전기사용신청시 적법한 건축물인지를 확인하기 위하여 건축허가(신고)서, 건축물관리대장, 건물등기부등본 중 하나를 제출하도록 하고 있습니다.만일 상기 서류를 제출할 수 없는 경우 전기공급은 다음의 조건이 구비되는 경우에 한하여 이루어집니다.- 지방자치단체에 등록된 무허가건물：무허가건축물확인서 제출- 지방자치단체에 등록되지 않은 무허가건물 및 건축허가(신고)제외 고객(모래 및 골재채취장, 광산, 간이 상수도, 농사용지하수 등)：토지대장,보증금- 콘테이너 등 조립식 가건물: 가설건축물 축조신고필증(가설건축물 신고대상이 아닌 경우 토지대장)※ 토지소유주와 사용자가 다른 경우 토지소유주의 동의가 필요합니다.※ 다수인의 민원이 야기될 수 있는 집단무허가건물, APT, 연립주택, 도로변지역, 그린벨트 지역, 농사용 이외의 용도로 무단변경 사용우려가 있는 비닐하우스 등에 대한 전기공급은 지방자치단체와 협의하여 처리하고 있습니다.'],
#  [40,
#   ['전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '후/NNG',
#    '사정/NNG',
#    '취소/NNG',
#    '한/NNG',
#    '납부/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '환불/NNG'],
#   '고객이 전기사용신청 후 사용신청 취소를 요청할 경우에는 『전기사용변경신청서』를 제출(계약해지)하셔야 하며, 당해 전기공급을 위하여 외선설계완료, 외선공사 착공 혹은이미 준공한경우에는 외선설계소요비용, 공급설비의 시설 및 철거에 소요되는 비용, 환입불능 자재가액(주로 전선류)을 기 납부하신 시설부담금에서 공제하고 그 차액을 환불하여 드립니다. 만약 실소요비용이 납부한시설부담금을 초과하는 때에는 별도 부과하지 않습니다.환불을 요청하실 경우에는 전기사용신청서에 날인한 도장과 주민등록증을 가지고 관할 사업소에 요청하시면 됩니다.'],
#  [41,
#   ['전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '후/NNG',
#    '사/NNG',
#    '정상/NNG',
#    '신청/NNG',
#    '내용/NNG',
#    '변경/NNG'],
#   '전기사용을 신청한 고객이 전기사용개시전에 신청내용을 변경(고객명, 전기공급방식, 계약전력 등)하는 것은 가능하며 새로이 전기사용을 신청하는경우와 같이 전기사용신청서에 변경내용을 명시하여 서면으로 제출하시면 됩니다.'],
#  [42,
#   ['전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '건물/NNG',
#    '준공/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '개시일/NNG',
#    '연기/NNG'],
#   '전기사용계약서를 작성한 고객이 당초의 수급개시일을 연기하고자 하는 경우에는 다음과 같이 수급개시일을 변경할 수 있으며 연기원 제출을 우편에 의하는 경우에는 발송우체국 소인일을 기준으로 합니다.(1) 공급준비(공급설비공사의 착공) 착수전 수급개시일이 경과하였다 하더라도 연기가 가능하고 연기기간 및 연기횟수에 제한없이 고객의 요청 기일로 수급개시일을 변경할 수 있습니다.(2) 공급준비(공급설비공사의 착공) 착수후 연기요청한 날이 당초 수급개시일을 경과하였다 하더라도 당초 수급개시일로부터 6개월의 범위내 에서 연기횟수에 제한없이 고객의 요청기일로 수급개시일을 변경할 수 있습니다.(3) 공급설비 준공후 한전에서 전기공급 설비를 준공한 후 고객측 사유로 장기간 송전되지 않을 경우에는 외선공사 준공 일로부터 6개월이 되는 날을 기준으로 전기사용신청을 취소합니다. 다만, 고객이 전기사용신청 취소 연기 신청을 할 경우에는 한전이 필요하다고 인정이 되면 취소 조치를 연기할 수 있습니다.'],
#  [43,
#   ['전기/NNG', '사용/NNG', '신청/NNG', '며칠/NNG', '안/NNG', '전기/NNG', '공급/NNG'],
#   'ㅇ 한전에서는 고객의 전기사용에 더 큰 만족을 드리고자 고객희망일에 전기를 송전해 드리고 있습니다.- 기존설비로 공급이 가능한 경우에는 영업일로 부터 3일(사용전점검 소요일 별도)이내에- 전주 및 변압기 설치 등 외선공사가 필요한 경우에는 저압 14일, 고압이상 16일 이후 고객희망일에 송전하여 드리며- 인터넷 전기사용신청의 경우 기존설비로 부터 공급시 2일, 외선공사 필요시 저압 11일, 고압 13일이내 공급해 드립니다.-지중으로 전기를 공급받는 고객에 대해서는 처리기준 일정을 고객과 협의하여 공급가능시기를 결정합니다.※단, 아래의 사항이 수반될 경우에는 소요되는 기간만큼 상기 기준일자에가산합니다. (자재처치기간, 도로굴착 등 대관 인허가 소요기간, 용지교섭 및 민원발생시 그 처리기간, 공사입찰 및 휴전공사 소요시 해당 기간, 외선공사가5일을 초과하는 경우 그 해당기간 등)○ 빌딩, 공장 등 전기사용 신청용량이 5,000kW 이상인 대규모 고객은 수전희망일 일정기간 전에 전기사용전 통지를 하여야 합니다.사용전 통지 이유는 대규모 고객에게 전기를 공급하기 위하여 한전 전기공급설비를 시설(변전소 신증설 등) 하는데 상당한 기일이 소요되기 때문입니다.사용전 통지시기- 5,000kW(일반업무시설은 2,000kW) 이상 ~ 10,000kW 이하 : 사용예정일 1년전까지- 10,000kW 초과~100,000kW 이하 : 사용예정일 2년전까지- 100,000kW 초과~300,000kW 이하 : 사용예정일 3년전까지- 300,000kW 초과 : 사용예정일 4년전까지※ 전기사용전 통지사항 : 전력사용량, 전력사용용도, 공급방식 및 전압,수전지점, 전력사용 예정일, 수전설비내용.'],
#  [44,
#   ['임시/NNG',
#    '전력/NNG',
#    '사용/NNG',
#    '빌딩/NNG',
#    '공사장/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    'kW/OL',
#    'kW/OL',
#    '증설/NNG',
#    '경우/NNG',
#    '추가/NNG',
#    '보증금/NNG',
#    '납부/NNG'],
#   '임시전력고객의 보증금 산정은 건축공사장인 경우 계약전력 3kW이하인임시전력(갑) 고객은호당 100,000원이적용되며, 계약전력 4kW이상인 임시전력(을) 고객의 보증금은 계약전력에 따라 결정됩니다.임시전력의 계약전력을 증설하실경우에는 증설 후 계산된 보증금 차액만큼의보증금을 추가 납부하여야 합니다.※ 보증금은 부가세 과세대상이 아님.'],
#  [45,
#   ['임시/NNG',
#    '전력/NNG',
#    '해지/NNG',
#    '상시/NNG',
#    '전력/NNG',
#    '수전/NNG',
#    '경우/NNG',
#    '납부/NNG',
#    '임시/NNG',
#    '전력/NNG',
#    '보증금/NNG',
#    '환불/NNG'],
#   '임시전력을 해지하고 보증금을 환불받고자 할 경우에는 보증금에서 미납전기요금 및 계기변상금 등을대체한 잔액을 환불하여 드립니다. 전기사용해지 신청시 보증금 납부 영수증을 함께 제출해 주시면 됩니다.최초 신규사용신청시 계좌이체약정서를 제출한 고객은 고객의 금융기관 통장계좌로 자동입금이 되며고객이 희망할 때는 직불 또는 우편송금을 할 수 있습니다. 우편송금인 경우 송금수수료는 고객환불액중에서 지불하고, 배달증명의 우편료는 한전에서 부담합니다.'],
#  [46,
#   ['임시/NNG',
#    '전력/NNG',
#    '신청/NNG',
#    '고객/NNG',
#    '보증금/NNG',
#    '현금/NNG',
#    '예치/NNG',
#    '대신/NNP',
#    '이행/NNG',
#    '보증/NNG',
#    '보험/NNG',
#    '증권/NNG',
#    '제출/NNG',
#    '보험/NNG',
#    '내용/NNG',
#    '기재/NNG'],
#   '임시전력 고객이 이행 보증보험증권 제출로서 현금예치를 대신하고자 할 경우, 이행보증보험증권내용은 다음과 같습니다.1. 보험계약자：임시전력 사용자(사용신청서 또는 전력수급계약서상의 고객명)2. 피보험자：한국전력공사 ○○본부장(지사장)3. 보험가입금액：임시전력고객 보증금 산정기준에 따라 계산된 금액 이상4. 보험기간：임시전력사용 예정기간보다 3개월 가산한 기간이상'],
#  [47,
#   ['보증금/NNG', '납부/NNG', '대상/NNG', '금액/NNG', '보증/NNG', '기간/NNG', '환불/NNG'],
#   '한전에서는 고객에게 전기사용개시, 재공급 또는 공급계속의 조건으로 예상월액 요금의 3개월분에 상당하는 금액을 기준으로 보증금을 수납하고 있습니다.다만, 고객이 희망하고 한전에서 인정하는 경우 현금 이외에 이행보증보험에 의한 보증, 지급보증, 연대보증, 근저당의 설정 등으로 보증금을 대신할 수 있습니다.(1) 보증 금액 및 예치기간① 보증금액은 연체 또는 해지직전 3개월간 평균요금을 기준으로 산정② 보증금의 예치 또는 보증기간은 2년 이내로 합니다. 다만, 임시전력 신청고객 등의 경우에는 전기 사용계약 해지일까지로 합니다.③ 사용자 명의의 전기사용고객이나 체납단전경험고객에 대해 설정된 보증금에 대하여는 2년내 단 1 회도 연체하여 납부한 사실이 없는 경우에 보증금 예치 2년 후 환불이 가능합니다.④ 보증기간중 연체납기후에 납부한 사실이 있는 고객은 그 연체일로부터 2년간 보증기간을 다시 연장 합니다.(2) 보증금 납부 대상가. 요금 납부에 보증이 필요한 고객 (주거용 주택용전력 고객 제외)① 요금 미납으로 전기사용계약 해지가 있었던 고객② 고객 신용상태, 요금납부실적등이 불량한 고객(요금을 납기+2개월 경과후 납부한고객)③ 요금 및 기타의 채무에 대하여 소유자 보증없이 사용자 명의로 신청하는 고객④ 건조물이 없는 고객이거나 가건물에 전기사용을 신청하는 고객(농사용 5kW이하 고객 제외)⑤ 한전에서 요금분납을 승인한 고객⑥ 시장, 상가아파트, 복합건물 등 단일구좌 내에서 여러 사용자가 있는 경우로서 지불보증이 필요하다고 인정되는 고객⑦ 신용평가법의 신용정보를 이용하여 신용이 불량한 것으로 판단되는 법인으로서 요금을 납기일로 부터 1개월이 되는 날까지 납부하지 않은 고객⑧ 요금미납으로 공급정지되었으나 전기사용계약 해지를 유예한 고객⑨ 임시전력을 사용하는 고객⑩ 부도, 화의 법정관리 등으로 보증설정이 필요한 고객⑪ 기타 사유로 사업소장이 보증설정이 필요하다고 인정하는 경우나. 보증금 적용 제외 대상- ①⑩중：국가 또는 지방자치단체 예산으로 운영하는 기관이나, 특별한 사유로 사업소장이 인정하 는 경우- ①, ②중：계약전력 4kW미만 또는 예상월액요금이 10만원 미만인 고객은 보증금 예치 및 보증설정을 면제(3) 보증금 이자 지급현금으로 예치한 보증금은 이자를 지급하며 이자율은 아래와 같습니다.가. 예치기간이 2년 미만인 경우 : 예치기간중 시중은행 1년만기 정기예금 평균 이자율수준나. 예치기간이 2년이상인 경우 : 예치기간중 시중은행 2년만기 정기예금 평균 이자율 수준다. 보증기간 만료 후의 예치기간 : 년 0.2%(4) 보증금 환불보증금은 전기요금을 납기내에 성실히 납부하였을 경우 예치 2년 후 환불이 가능합니다.보증금을 환불 받고자 할 경우에는 보증금 납부 영수증을 제출해 주시면 됩니다.최초 신규사용신청시 계좌이체약정서를 제출한 고객은 고객의 금융기관 통장계좌로 입금이 되며 고객이 희망할 때는 직불 또는 우편송금을 할 수 있습니다.'],
#  [48,
#   ['임시/NNG', '전력/NNG', '사용시/NNG', '납부/NNG', '보증금/NNG', '산정/NNG'],
#   '임시전력에 대한 보증금은 전기사용형태의 특성상 사용 개시후의 전기요금을 납기일에 납부하지 아니할 경우 대체하기 위한 것이며 고객이 희망할 때는 현금예치 대신 이행보증보험증권, 금융기관의 지급보증서, 건설공제조합주택사업공제조합전기공사공제조합의 임시전력 보증금보증서 제출로 대신할 수 있습니다.▣ 임시전력 보증금 산정기준1.건축공사장 등 이와 유사한 용도고객유형별로 아래 기준금액으로 산정하되, 고객의 요청이 있는 경우 또는 한전이 필요하다고 인정되는경우에는 3개월이상 정상조업기간의 전기사용 실적금액을 기준으로 재산정할 수 있습니다.가. 임시전력(갑) : 호당 100,000원나. 임시전력(을) 저압전력 : 계약전력 1kW당 45,000원다. 임시전력(을) 고압전력 : 계약전력 1kW당 33,000원2. 기타 임시전력 현장가. 건축공사장 이외의 임시전력 고객에 대한 보증금은 원칙적으로 전 1을 준용합니다.나. 전 1에 따른 보증금기준 적용이 불합리하다고 인정될 경우에는 전기공급약관 시행세칙 별표 1의 위약유형별 산정기준에서 정하는 사용설비의 사용시간을 기준으로 산정한 요금에 따라 결정할 수 있습니다.다. 터널, 관로, 지하철공사장 등과 같이 현장설비 상황에 따라 기준보증금이 현저히 부족하다고 인정될 경우나 임시전력 신청기간이 3개월 미만인 경우에는 다르게 운영할 수 있습니다.3. 전기계기를 부설할 수 없거나 전기계기의 부설이 비경제적인 고객은 협정한 사용량에 따른 전기요금을 기준으로 보증금을 산정합니다.※전기공급약관 시행세첵 제61조(보증금)'],
#  [49,
#   ['건축/NNG',
#    '공사/NNG',
#    '임시/NNG',
#    '전력/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '설치/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '전기/NNG',
#    '사용자/NNG',
#    '전액/NNG',
#    '부담/NNG',
#    '준공/NNG',
#    '후/NNG',
#    '상시/NNG',
#    '전력/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '부담/NNG',
#    '고객/NNG',
#    '이중/NNG',
#    '부담/NNG'],
#   '한전에서 임시공급설비를 시설소유하는 경우로서 임시전력 고객이 계약사용기간 만료 이후에상시전력으로의 전환이 명확히 예상되고 고객이 희망할 경우에는 상시전력을 기준으로 한 고객부담시설부담금을 받고 한전이 시설소유하여 임시와 상시를 같은 선로로 공급합니다. 따라서, 한전은 상시전력에 대한 시설부담금만 청구하며 임시전력공급설비 설치에 대한 시설부담금은 청구하지 않습니다.(통상적으로 상 시전제 임시신청이라 함)◆ 계약사용기간 만료후에 상시계약종별 변경이 명확히 예상되는 조건 - 임시전력과 상시전력을동시에 신청(고객명의가 다른 경우 포함) - 건축허가서(건축물 불요고객인 경우에는 사업자등록증또는 영업허가서) 사본 제출 - 상시전력을 공급하기 위한 공급설비로 임시전력 공급가능(단, 인입선은 제외함) - 임시전력과 상시전력의 전기사용장소 동일 - 임시전력 인입선을 고객의 부담으로 시설소유'],
#  [50,
#   ['공급/NNG',
#    '설비/NNG',
#    '변경/NNG',
#    '경우/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '공급설비의 변경이란 기설고객이 동일 사용장소에서 새로운 전기사용 또는 계약전력 증가없이 고객의 희망에의하여 공급방식 변경, 공급전압 변경, 전기사용계약단위 분할, 전기사용계약단위 합병, 공급선로나 수급지점 변경을수반하는 경우를 말하며 고객부담 시설부담금 결정기준은 다음과 같습니다.`공급설비현황에 따른 대상, 고객부담 시설부담금 안내입니다` 시설부담금 결정기준공급설비현황대상고객부담 시설부담금비고공급방식 및공급전압 변경에어콘 등 삼상사용설비 설치12W 220V 34W 220V/380V기존 삼상사용설비 교체33W 200V 34W 220V/380V공급전압 증가34W 220V/380V 34W 22,900V공급설비 변경신청 시점이 표준시설부담금 적용대상 고객이면 변경전과 변경후를 각각 신설로 간주하여 산정한 고객부담 시설부담금의 차액 적용 공급설비 변경신청 시점이 설계조정시설부담금 적용대상 고객이면 설계조정시설부담금 적용저압고객이 고압이상으로 공급전압을 변경시는 저압시설부담금만 차감전기사용계약단위 분할1주택수가구 사용시 요금분쟁 또는 건물 사용자별 계량을 위한 분할- 12W 220VA고객: 12W 220VB고객: 12W 220V- 34W 220V/380VA고객: 34W 220V/380VB고객: 12W 220V 순수 주택용고객은 수급개시일과 관계없이 표준시설부담금 적용전기사용계약단위 합병사용자별 전기사용계약 체결후 고객변동으로 1고객만이 사용-삼상220V사용설비를 380V로 교체{12W 220V, 33W 220V}= 34W 220V/380V 공급방식 및수급지점 변경고객구내 변전실 위치 변경고객의 희망에 의하여 단순히 공급선로 및 수급지점 변경만 이루어질 경우에는 계조정시설부담금 적용표준시설부담금 적용대상고객이 증설, 공급방식 변경 등과 동시에 공급선로 및 수급지점 변경이 발생될 경우는 계약전력 증가분에 대한 기본시설부담금과 설계조정시설부담금 중 큰 것 적용단순 인입선위치 변경건물증개축고객희망에 의한 단순인입선 위치 변경은 설계시설부담금 적용한전 직원이 시공할 경우는 재료비+노무비로 하며 도급공사 시행시는 경비, 일반관리비, 이윤 추가'],
#  [51,
#   ['건설/NNG',
#    '공사장/NNG',
#    '전기/NNG',
#    '필요/NNG',
#    '임시/NNG',
#    '전력/NNG',
#    '사용/NNG',
#    '임시/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '한전/NNG',
#    '시설/NNG',
#    '경우/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '임시전력고객이 새로 전기를 사용하거나 계약전력을 증가하는 경우 또는 고객의 희망에의하여 임시공급설비를 변경하는 경우에는 새로이 시설 및 변경하는 임시공급설비에대하여는 설계시설부담금을 적용합니다. 다만 변압기, 개폐기, 지중관로 설치공사비에 대하여는 설계조정시설부담금을 적용합니다. 한전이 시설소유하는 기설변압기나 개폐기의 변경 없이 이용 가능할 경우, 즉 외선공사가소요되지 않으면 고객부담시설부담금은 없습니다.'],
#  [52,
#   ['공중/NNG',
#    '고압/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    'kW/OL',
#    '전기/NNG',
#    '공급/NNG',
#    '공장/NNG',
#    '사업/NNG',
#    '부진/NNG',
#    '저압/NNG',
#    'kW/OL',
#    '납부/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '얼마/NNG'],
#   '일부해지와 동시에 공급전압을 변경하고 기존 특고압선로에서 선로 연장없이 저압공급이가능한 경우에는 공급설비 변경전과 변경후를 각각 신설한 것으로 보고 산정한 시설부담금의차액을 받습니다.단, 변경후를 신설한 것으로 보고 산정한 시설부담금이적을 경우 추가 시설부담금은 없습니다.변경후 고객 시설부담금 = 저압70kW 고객 시설부담금- 특별고압300kW 고객시설부담금'],
#  [53,
#   ['단상/NNG',
#    'V/OL',
#    '공급/NNG',
#    '영업장/NNG',
#    '삼상/NNG',
#    'V/OL',
#    '대형/NNG',
#    '냉장고/NNG',
#    '설치/NNG',
#    '계약/NNG',
#    '전력/NNG',
#    '변경/NNG',
#    '공급/NNG',
#    '방식/NNG',
#    '변경/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '표준시설부담금 적용대상 고객이 공급방식을 변경 신청하는 경우에는 공급방식 변경전과변경후를 각각 신설한 것으로 보고 산정한 시설부담금의 차액을 받습니다.이때 삼상공급을 위한 전선 첨가거리와 첨가공사가 끝나는 전주에서 전기사용장소까지거리의 합계가 200m 이내인 경우에는 시설부담금을 받지 않습니다.'],
#  [54,
#   ['고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '정산/NNG', '대상/NNG', '방법/NNG'],
#   '고객부담시설부담금정산대상은 설계조정시설부담금 또는 설계시설부담금으로 고객부담시설부담금을 산정한 경우(표준시설부담금 적용대상 고객 제외)에 해당합니다. 고객부담시설부담금의 확정은, 고객부담 대상 시설부담금의 실집행금액에서시설부담금을 자재와 기타금액으로 구분하여 자재비는 출고가액으로, 기타 금액은 실집행금액으로 하여 철거환입물자의 잔존가액을 공제한 금액을 고객이 부담하여야 할 시설부담금으로 확정합니다.정산결과 고객부담시설부담금 잔액을 환불하는 경우에는 환불대상금액(설계(조정)시설부담금 환불금액 및 과수납한 표준시설부담금 환불금액 : 부가세제외)에그 동안의 이자를 가산하여 환불하며 보증금 환불절차에 준합니다.※ 보증금 이자율가. 예치기간이 2년 미만인 경우 : 예치기간중 시중은행 1년만기 정기예금 평균 이자율수준나. 예치기간이 2년이상인 경우 : 예치기간중 시중은행 2년만기 정기예금 평균 이자율 수준'],
#  [55,
#   ['고객/NNG', '부담/NNG', '시설/NNG', '부담금/NNG', '적용/NNG', '종류/NNG', '산정/NNG'],
#   '고객이 새로 전기를 사용하거나 계약전력(정액제요금 고객은 사용설비를 말합니다)을 증가시키는 경우 또는 고객의 희망에 따라 공급설비를 변경하는 경우에 배전선로 시설부담금은 고객이 부담하는 것을 원칙으로 합니다. 고객부담시설부담금 적용방법은 다음과 같이 세 가지가 있습니다.(1) 표준시설부담금: 고객이 새로 전기를 사용하거나 계약전력을 증가시켜 일반공급설비로 전기를 공급받는 경우 배전선로 공사의 유무 및 공사내역에 관계없이 한전에서 정한시설부담금 단가에 따라 산정한 고객부담시설부담금 (저압고객 및 가공지중고압고객)※ 일반공급설비란 불특정 다수의 고객에게 저압, 고압 또는 특별고압(22,900V이하)으로 공급하기 위한 설비를 말함.(2) 설계시설부담금 : 특정한 고객만이 전용하는 공급설비 또는 적정설계이상의 설계로 시설하여 전기를 공급하는 경우에 공사설계서에 의하여 산정한 고객부담시설부담금 (특별공급설비고객 등)가. 전용공급설비나. 고객의 희망에 따라 기술기준 또는 한전 설계기준 등을 초과하여 설치하는 공급설비다. 22,900V를 초과하는 특별고압으로 설치하는 공급설비(3) 설계조정시설부담금 :고객에게 전기를 공급하기 위한 배전선로의 시설에 필요로 하는 설계공사비중 변압기, 배전함, 전선, 지중개폐기, 관로 전력구 등의 공사비에 대하여는 당해고객이 이용하는 부분에 해당하는 금액만을 부담하고, 기존 공급설비의 보강 공사비는 한전의 부담으로 하여 산정한 고객부담시설부담금가. 철탑이나 해저케이블을 시설하여 22,900V 이하의 전압으로 공급하는 고객나. 가공 배전지역에서 고객의 희망에 따라 지중배전선로를 설치하여 전기를 공급하는 고객다. 기타 특별한 사정으로 설계조정공사비의 적용이 타당하다고 한전이 인정하는 고객① 주택단지 등에서 약관 제84조 〔일반공급설비의 시설부담금〕 제3항에 따라 전기간선시설 및 단지내 배전시설을 미리 설치하고 설치비용을 사업 주체가 전액 부담한 경우로서, 동 선로를 이용하여 22,900V 이하 일반공급 설비로 단지내 신 증설 고객에게 상시전력을 공급하는 경우.다만 설계 조정시설부담금이 표준시설부담금보다 많은 경우 에는 표준시설부담금 적용② 고객의 희망에 따라 22.9kV S.N.W 방식으로 전기를 공급하는 경우③공중배전지역에서 고객의 희망에 따라지중배전선로를 설치하여 공급하는 경우. 이 경우 설계조정시설부담금이표준시설부담금 보다 적을 경우에는표준시설부담금을 적용함.※ 시설부담금의 산정 방법에 대한 자세한 내용은 `전기공급약관의 시설부담금 (새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/D/C/CYDCHP00109.jsp`>전기공급약관의 시설부담금 내용을 참고하신 후 가까운 관할 한전으로 문의하시기 바랍니다.'],
#  [56,
#   ['지중/NNG',
#    '확정/NNG',
#    '지역/NNG',
#    '저압/NNG',
#    '신규/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '시/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '지중화 확정지역 등 실제 지중선로가 구성되지 아니한 경우에도 기존 배전선로가 지중화된것으로 간주하여 지중선로를 구성공급하는 것을 원칙으로 하며시설부담금은 지중공급에의한 표준시설부담금을 적용하여 기본시설부담금 및 거리시설부담금을 받습니다.신설거리는 한전의지중화 설계서상의 공급설비 위치(설치예정 고압개폐기, 변압기, 전선)를 측정기점으로 하여산정합니다. 또한 실질적으로는 신규공급설비를 기존공중 배전선로로부터 연장공급한다하더라도 시설부담금은지중으로 공급하는 것으로 간주하여 계산청구합니다.고객사정에의한 긴급요청으로공중 배전선로에 의한 잠정공급이 불가피한 경우의 잠정공급설비에대한 소요 공사비는 고객이 부담하되, 변압기개폐기지중관로 설치공사비에 대해서는 당해고객이이용하는 비율에 따라 조정하는 설계조정시설부담금을 고객이 부담합니다.※ 노무비경비 등에대해서도 조정 (한전 사정에 의하여 지중 배전선로 시설시까지 잠정적으로가공 배전선로를 시설하여 공급하는 경우에는 가공 배전선로 설치 및 철거공사비는 한전이 부담)'],
#  [57,
#   ['표준/NNG', '시설/NNG', '부담금/NNG', '단가/NNG', '조정/NNG', '경우/NNG'],
#   '한전은 한국은행 또는 통계청에서 조사한 매년 9월 기준 생산자 물가지수에 의한 주요자재가격(시멘트, 전선, 철강)과 시중 노임단가(배전전공)의 변동이 있을 경우에 표준시설부담금 단가를 조정하며, 조정율이 5% 미만일 경우에는 조정하지 않습니다.'],
#  [58,
#   ['지은/NNG',
#    '빌딩/NNG',
#    '시설/NNG',
#    '한전/NNG',
#    '소유/NNG',
#    '관로/NNG',
#    '이용/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '납부/NNG'],
#   '고객소유설비는 고객이 별도로 시설함이 원칙이나 특별한 사정으로 고객소유 선로구성을위하여 한전소유의 전주, 지중관로, 전력구(공동구 포함)를 사용하여야 할 경우에는 그 이용부분을 새로 설치하는 것으로 간주하여 산정한 설계조정시설부담금을 고객부담시설부담금으로 합니다. 고객부담시설부담금은 고객이 이용하는 회선수 비율에 해당하는 금액(관로시설 총공사비사용공수/시설공수)으로 합니다.(관로시설 준공연한과 관계 없음)'],
#  [59,
#   ['마을/NNG',
#    '논/NNG',
#    '개간/NNG',
#    '산/NNG',
#    '대책/NNG',
#    '관정/NNG',
#    '집단/NNG',
#    '신청/NNG',
#    '경우/NNG',
#    '거리/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '저압으로 전기를 공급받는 고객이 동일 배전선로를 이용 연장공급하는 것으로 설계되었을경우의 직선거리 산정은, 측정기점에서 가장 가까운 고객으로부터 1호씩 순차적으로 신청하는것으로 간주하여 거리시설부담금을 산정합니다.다만, 22,900V 이하의 특별고압, 고압 또는 저압으로전기를 공급받는 고객이 동일설계로 공사하는경우에는 그 중 가장 높은 전압 즉, 특별고압,고압, 저압순서로 직선거리를 먼저 측정하고 다른 고객에대하여는 먼저 측정한 고객에게공급하기 위한 배전선로가 이미 시설되어 있는 것으로 보고 순차적으로 직선거리를 측정합니다.'],
#  [60,
#   ['건물/NNG',
#    '지중/NNG',
#    '공급/NNG',
#    '지역/NNG',
#    '저압/NNG',
#    'kW/OL',
#    '정도/NNG',
#    '전기/NNG',
#    '필요/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '지중공급 저압고객이 전기를 새로이 신청할 경우 표준시설부담금을 적용하는데, 기본거리(50m)이내일 경우는 기본공사비 2,971,000원(부가세별도){421,000원+(30kW-5kW)98,000원}을 고객부담시설부담금으로 납부하셔야 합니다. 다만, 신설거리가 기본거리(50m)를 초과할 경우에는 초과거리 매 1m당 60,000원씩을 계산하여 추가로 거리시설부담금을 부담하셔야 합니다. 신설거리 측정방법은, 수급지점으로부터 측정기점(한전 고압개폐기, 기설 공급변압기, 공급전압이 같은 전선의 접속점 등)까지의 배전선로 실거리로 합니다.'],
#  [61,
#   ['전기/NNG',
#    '신규/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '시/NNG',
#    '고객/NNG',
#    '장소/NNG',
#    '일반/NNG',
#    '전기/NNG',
#    '사업자/NNG',
#    '한전/NNG',
#    '부담/NNG',
#    '전기/NNG',
#    '설비/NNG',
#    '가설/NNG',
#    '생각/NNG',
#    '고객/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '부담/NNG'],
#   '전기시설부담금은 특정고객이 새로 생겨남에 따라 발생하는 것으로서 이 시설부담금은 당해고객을위하여 소요되는 비용이므로 수익자부담 원칙에 따라 그 원인을 발생시킨 고객이 부담하여야합니다. 만약시설부담금을 한전이 전액 부담할 경우에는 한전 부담액이 결국 전기요금으로전가되어 전기요금 인상요인이 되며 또한 일정한시설부담금을 당해 고객에 부담시키지 않을 경우무분별한 전기사용신청에 따라 막대한 재원이 비효율적으로 투자됨으로써 에너지공급 자원의효율적 배분에 왜곡을 초래하게 되는 것입니다. 외국의 경우에도 전기 시설부담금은 고객부담으로하고 있습니다.'],
#  [62,
#   ['일반/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '무엇/NNG',
#    '경우/NNG',
#    '고객/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '일반공급설비란 불특정 다수의 고객에게 저압, 고압 또는 특별고압(22,900V이하)으로 공급하기 위한 설비로서이 경우의 고객시설부담금은 당해 고객의 전기공급에 따른 공급설비, 공사유무 및 공사규모에 관계없이 정액단가를 적용하는 표준시설부담금과 당해 고객의 전기공급에 소요되는 부분에 해당하는 금액만 부담하게 하는 설계조정시설부담금이 있습니다.1. 표준시설부담금 적용대상 : 22,900V 이하 전압으로 가공지중배전선로를 이용 공급하는 고객2. 설계조정시설부담금 적용대상가. 철탑이나 해저케이블을 시설하여 22,900V 이하의 전압으로 공급하는 고객나. 공중 배전지역에서 고객의 희망에 따라 지중배전선로를 설치하여 전기를 공급 하는 고객다. 기타 특별한 사정으로 설계조정시설담금의 적용이 타당하다고 한전이 인정하는 고객(1) 주택단지 등에서 약관 제84조 〔일반공급설비의 시설부담금〕 제3항에 따라 전기간선시설 및 단지내배전시설을 미리 설치하고 설치비용을 사업주체가 전액 부담한 경우로서, 동 선로를 이용하여 22,900V 이하일반공급설비로 단지내 신증설 고객에게 상시전력을 공급하는 경우.다만, 설계 조정시설부담금이 표준시설부담금 보다 많은 경우에는 표준공사시설부담금 적용(2) 고객의 희망에 따라 22.9kV S.N.W 방식으로 전기를 공급하는 경우(3)공중배전지역에서 고객의 희망에 따라지중배전선로를 설치하여 공급하는 경우.이 경우 설계조정시설부담금이표준시설부담금 보다적을 경우에는표준시설부담금을 적용함.전기요금 자동이체처리는 신청 즉시 처리되는 것이 아니라, 약간씩 차이가 있지만 한전에서 정상 신청접수완료 후 약 26일 후 도래되는 납기일 요금부터 자동이체가 개시됩니다. 이는 고객마다 검침일과 요금 납기일이 다르고 이와 함께 자동이체 신청에 따른 금융결제원의승인 일정이 다소 다르게소요되기 때문입니다.고객이 사이버지점을 통하여 전기요금 자동이체를 신청하시면 당장에 입력사항에 오류가 없는 경우 한전에서는정상적으로 접수처리를 합니다.그리고 신청고객에게 자동이체 처리완료라는 메시지를 SMS를 통하여 알려드립니다.이는한전에서 자동이체 접수처리를 완료하였다는 의미이며 당장 발생한 전기요금을자동이체로 인출하겠다는 내용은 아닙니다.또한 금융결제원 확인 결과 계좌번호나 신청고객정보가 잘못되어 추후에오류가 발생하여 전기요금 자동이체 처리가 되지 않는 경우도 있습니다.그러나 신청고객이 정확한 계좌번호와 고객정보를입력하셨다면 늦어도 신청 후 약 26일 후 도래하는 납기일에해당하는 전기요금부터는 자동이체로 전기요금이 납부됩니다.'],
#  [63,
#   ['공장/NNG',
#    '규모/NNG',
#    '대/NNG',
#    '단위/NNG',
#    '여/NNG',
#    'V/OL',
#    '전기/NNG',
#    '공급/NNG',
#    '경우/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '전기를 154,000V로 공급받는 경우 특별공급설비에 해당하여 수급지점까지의 실제 공사 설계서에 의해 산정된 설계시설부담금을 시설부담금으로 부담하셔야 합니다.'],
#  [64,
#   ['현금/NNG', '시설/NNG', '부담금/NNG', '납부/NNG', '현금/NNG', '영수증/NNG', '발행/NNG'],
#   '개인이 현금으로 납부하는 신규 시설부담금과 지장배전선로이설 시설부담금에 대하여 발행이 가능합니다.발행형태 : 근로소득자의 소득공제용으로만 발행(사업자는 세금계산서 발행)발행방법 : `개인`이 납부한 시설부담금에 대한현금영수증은 거래시점에 전기사용계약 명의자에게 발급되며(소급발행불가),시설부담금 납부 익일 국세청으로 자동 통보 됩니다.* 전기요금은 조세특례제한법상 `현금영수증 발행대상`이 아닙니다.'],
#  [65,
#   ['사용/NNG',
#    '동력/NNG',
#    '구좌/NNG',
#    '해지/NNG',
#    '신청/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '당시/NNG',
#    '한전/NNG',
#    '납부/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '환불/NNG'],
#   '고객에게 전기를 공급하기 위한 배전선로는 한전에서 시설 소유하면서 고객들에게 양질의 전기를 계속 공급하기 위하여 막대한 예산을 노후선로 교체, 선로 보강공사 등 배전선로 유지보수에 투자하고 있습니다. 따라서 사용하시던 전기를 해지하시더라도 기납부한 시설부담금은 환불되지 않습니다.'],
#  [66,
#   ['공장/NNG',
#    '세/NNG',
#    '저압/NNG',
#    '단상/NNG',
#    'kW/OL',
#    '신규/NNG',
#    '사용/NNG',
#    '신청/NNG',
#    '사/NNG',
#    '정상/NNG',
#    '저압/NNG',
#    'kW/OL',
#    '변경/NNG',
#    '신청/NNG',
#    '한전/NNG',
#    '변압기/NNG',
#    '설치/NNG',
#    '공사/NNG',
#    '완료/NNG',
#    '경우/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '산정/NNG'],
#   '새로이 전기를 신청한 고객이 전기사용개시전에 사용신청 내용을 변경함으로써 변경공급에 따른 한전의 설비공사 내용도 변경될 경우에는 증설 기본시설부담금(860,000원)외에 이미 시설한 부분의 변경에 따른 소요 시설부담금을추가로 납부하셔야 합니다.'],
#  [67,
#   ['고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '일시/NNG',
#    '납부/NNG',
#    '부담/NNG',
#    '분할/NNG',
#    '납부/NNG',
#    '가능/NNG'],
#   '□ 전기사용신청 고객은 희망에 따라 전체 시설부담금의 30%를 공급준비 착수전에 납부하고, 잔여시설부담금은 수급개시예정일 전까지 3회 이내 분할 납부할 수 있습니다. 다만, 수급개시 이후 잔여시설부담금 납부를 희망하는 고객은 아래의 조건으로 1년이내 매월 균등 분할납부 할 수 있습니다.가. 수급개시 이후에 납부하는 잔여시설부담금에 대하여는 수급개시일부터 약관 제79조(요금의 보증) 제5항에서 정한 보증기간 2년 미만인 경우의 이자율을 준용하여 이자를 부과나. 고객은 잔여시설부담금 납부에 대한 이행보증보험증권을 공사비부담계약 체결전까지 한전에 제출하며, 보증금액은 잔여시설부담금과 이자를 합산한 금액으로 산정 다. 고객이 잔여시설부담금을 2회이상 미납시 고객에게 통보후 이행보증금액을 청구주택단지산업단지 기타 이와 유사한 단지(이하 단지라 한다)로서 전기간선시설 및 단지내 배전시설 공사기간이 1년이상 소요되는 경우에는 전체시설부담금의 30%를 공급준비 착수전에 납부하고, 잔여시설부담금은 단지조성완료일 전까지 3회 이내 분할납부할 수 있습니다.'],
#  [68,
#   ['일반용/NNG',
#    '전기/NNG',
#    '설비/NNG',
#    '사용/NNG',
#    '전/NNG',
#    '점검/NNG',
#    '대상/NNG',
#    '절차/NNG'],
#   '▣ 한전이 점검할 수 있는 설비는 다음과 같습니다. 아래대상 이외에는 전기안전공사 점검분입니다. 다음 각 호의 설비 또는 시설(그 부속설비를 포함한다)에 설치한 전기설비로 한다.(전기사업법 시행령 제42조의 2) 1) 「건축법」 제2조제2항에 따른 단독주택 및 공동주택 2) 「건축법」 제20조에 따른 가설건축물 중 임시전력을 공급받는 가설건축물 ㅇ 3층 이하의 가설건축물 ㅇ 재해복구, 흥행, 전람회, 공사용 가설건축물 등 3) 「건축법 시행령」 별표 1 제3호가목부터 다목까지의 근린생활시설 ㅇ 일용품(식품잡화의류완구서적건축자재의약품의료기기 등) 등의 소매점으로 같은 건축물에 해당용도로 쓰는 바닥면적의 합계가 1,000㎡ 미만인 것 ㅇ 휴게음식점 또는 제과점으로서 같은 건축물에 해당 용도로 쓰는 바닥면적의 합계가 300㎡ 미만인 것 ㅇ 이용원, 미용원, 목욕장 및 세탁소(공장이 부설된 것과 배출시설의 설치허가 또는 신고의 대상이 되는 것은 제외)4) 「민간임대주택에 관한 특별법」제2조에 따른 민간임대주택과 「공동주택 특별법」제2조제1호가목에 따른 공공임대주택 5) 「농지법」 제2조제1호에 따른 농지 ㅇ 전, 답, 과수원, 실제 농작물 경작지, 다년생 식물(목초, 종묘, 인삼, 약초, 잔디, 조림용 묘목, 과수, 뽕나무, 유실수,조경 또는 관상용 수목과 묘목)재배지로 이용되는 토지 ※ 제외대상- 지목이 전,답,과수원이 아닌 토지로서 다년생식물 재배지로 계속하여 이용되는 기간이 3년 미만인 토지 - 지목이 임야인 토지로서 그 형질을 변경하지 아니하고 다년생식물(과수,뽕나무,유실수,조경 또는 관상용 수목과 묘목)의 재배에 이용되는 토지 - 초지 ㅇ 상기 토지의 개량시설로서 유지(溜池), 양배수시설, 수로, 농로, 제방, 토양의 침식이나 재해로 인한 농작물의 피해를 방지하기 위하여 설치한 계단, 흙막기, 방풍림과 그 밖에 이에 준하는 시설 ㅇ 상기 토지의 농축산물 생산시설로서 고정식온실, 버섯재배사 및 비닐하우스와 그 부속시설, 축사, 축사와 연접하여 설치된 시설로서 가축의 사육관리출하 등 일련의 생산과정에 직접 이용되는 급여(給與)시설, 착유시설, 위생시설, 가축분뇨처리시설, 농기계보관시설, 진입로 및 가축운동장, 자가 소비용 사료의 간이처리 또는 보관시설, 해당 축사에서 사육하는 가축의 관리를 위해 설치하는 주거목적이 아닌 시설, 농막, 간이저온저장고, 간이퇴비장, 간이액비저장조 ※ 상기 설비나 시설에 설치한 전기설비라도 한국전기안전공사가 사용전점검을 할 수 있음▣ 사용전점검은 전기설비의 설치공사 또는 변경공사 완료후 전기를 공급받기 전에 실시하여야 하며 점검을 받고자 하는 날의 3일전까지 한전 또는 안전공사에 구비서류를 포함하여 신청하여야 합니다. ㅇ 사용전점검신청서 ㅇ 전기설비 단선결선도 ㅇ 전기사용신청서 사본(안전공사에 신청하는 경우에 한함)'],
#  [69,
#   ['사용/NNG',
#    '전/NNG',
#    '검사/NNG',
#    '시/NNG',
#    '고객/NNG',
#    '준비/NNG',
#    '사항/NNG',
#    '고압/NNG',
#    '이상/NNG',
#    '전기/NNG',
#    '기계/NNG',
#    '기구/NNG',
#    '시험/NNG',
#    '성적/NNG',
#    '구체적/NNG',
#    '무엇/NNG'],
#   '사용전검사에 대한 사항은 전기안전공사에 문의하시기 바랍니다.'],
#  [70,
#   ['지은/NNG', '주택/NNG', '전기/NNG', '공사/NNG'],
#   '전기를 신규로 공급하기 위하여 필요한 공사는 크게 외선공사와 내선공사로 구분됩니다.전기는 한전과 고객의 일련의 전기설비가 접속됨으로서 전기사용거래가 이루어지는데 그 접속점이 곧 전기를 공급 및 사용하는 지점인 수급지점(재산한계점)이 됩니다.수급지점까지의 전기공급설비는 한전에서 시설 소유하고 수급지점 이후의 전기설비는 고객이 시설 소유하고 유지보수 하게 됩니다. 따라서 수급지점까지 한전에서 시공하는 전기설비공사를 외선공사라 하고 수급지점이후의 고객이 시공하는 전기설비공사를 내선공사라고 합니다. 주택을 예로 들면 전선로의 설치 및 전주로부터 인입선연결점까지의 공사가 외선공사이며, 인입선연결점에서 전기사용장소내의 인입개폐기에 이르는 인입구 배선 및 배전함 설치공사, 주택내부 배선공사가 내선공사가 됩니다. 내선공사는 고객이 전기공사업자를 직접 선정하여 시공하셔야 하고 공사비도 직접 공사업자에게 지불하셔야 하며, 부담금은는 기본시설부담금과거리시설부담금의 합계로 하는 표준시설부담금을 적용하며 그 단가는 다음과 같습니다.○ 기본시설부담금(부가가치세 불포함)기본시설부담금(부가가치세 불포함)구분금액가공공급지중공급저압매 1계약에 대하여 계약전력 5kW까지220,000원421,000원계약전력 5kW 초과분의 매 1kW에 대하여86,000원98,000원고압또는특별고압신증설 계약전력 매 1kW에 대하여17,000원35,000원○ 거리시설부담금(부가가치세 불포함)가공공급, 기중공급에 따른 거리시설부담금 안내입니다거리시설부담금(부가가치세 불포함)구분금액가공공급지중공급가공공급지중공급신설거리시설부담금기본거리를 초과하는 신거리 매 1m에 대하여저압39,000원43,000원60,000원고압또는 특별고압43,000원110,000원첨가거리시설부담금기본거리를 초과하는 첨가거리 매 1m에 대하여저압5,000원고압또는 특별고압10,000원'],
#  [71,
#   ['주택/NNG',
#    '신축/NNG',
#    '전기/NNG',
#    '내선/NNG',
#    '공사/NNG',
#    '건축주/NNG',
#    '계량기/NNG',
#    '배선/NNG',
#    '한전/NNG',
#    '공사/NNG',
#    '건축/NNG',
#    '주가/NNG',
#    '공사/NNG',
#    '사실/NNG'],
#   '전기사용량을 측정하는 지점 즉, 전력량계 부설위치까지의 배선을 한전에서 시설하여주는 것으로 오해할 수 있습니다만 전주로부터 인입선연결점까지는 한전에서 시설소유하고인입선연결점에서 전기사용장소내의 인입개폐기에 이르는 인입구배선은 고객이 시설소유합니다.시공방법은 저압용 인입구배선인 경우는 케이블선, 금속관 배선 또는 합성수지관 배선으로시설하여야 합니다.'],
#  [72,
#   ['전기/NNG',
#    '사용/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '계약/NNG',
#    '성립/NNG',
#    '시기/NNG',
#    '최초/NNG',
#    '전기/NNG',
#    '사용/NNG',
#    '개시일/NNG',
#    '결정/NNG',
#    '기준/NNG'],
#   '고객과 한전간의 전기사용에 관한 전기사용계약 및 변경계약은 한전이 전기공급을 승락한 때에성립하는데 공급을 승락한 때라 함은 다음과 같습니다.- 전기사용계약서 작성고객 : 전기사용계약체결일- 공급예정서 작성고객 : 공급예정서 발송일- 전기사용계약서와 공급예정서 작성 이외 고객 : 고객부담 시설부담금 청구서 발송일 (단, 고객부담 시설부담금이 없는 고객 : 전기사용신청 접수일)'],
#  [73,
#   ['태풍/NNG',
#    '집중/NNG',
#    '호우/NNG',
#    '재난/NNG',
#    '이재민/NNG',
#    '고객/NNG',
#    '전기/NNG',
#    '요금/NNG',
#    '납기/NNG',
#    '일/NNG',
#    '연장/NNG',
#    '한국/NNG',
#    '전력/NNG',
#    '공사/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '약관/NNG',
#    '준수/NNG',
#    '의무/NNG',
#    '위배/NNG'],
#   '전기는 생산 즉시 소비하는 물리적 특성이 있으므로 불특정 다수 고객과의 거래조건을 공급약관으로정함에 있어 사용장소, 전기공급방식, 전기요금 등 구체적인 사항은 규범적으로 정해 두지 않을 수없습니다. 그러나 천재지변 등 불가피한 경우 전기공급약관 이외의 공급조건을 적용할 수 있도록전기공급약관에 명시하고 있기 때문에 전기공급약관 준수의무를 위배한 것이 아닙니다.'],
#  [74,
#   ['전기/NNG', '공급/NNG', '약관/NNG', '명시/NNG', '사항/NNG', '결정/NNG'],
#   '전기공급약관은 고객에게 전기를 공급할 때의 요금 및 기타의 공급조건을 정하고 있으나 세부사항까지구체적으로 전기공급약관에 명시하기는 불가능하므로 약관의 시행에 필요한 세부사항은 한국전력공사에서별도로 시행세칙을 정하여 운영하고 있으며 약관과 세칙에 명시되지 아니한 사항은 전기공급약관의 취지에따라 고객과 한국전력공사가 협의 결정합니다.'],
#  [75,
#   ['외국/NNG',
#    '제조/NNG',
#    '기기/NNG',
#    '도입/NNG',
#    '사용/NNG',
#    '전압/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '약관/NNG',
#    '규정/NNG',
#    '전기/NNG',
#    '공급/NNG',
#    '전압/NNG',
#    '이외/NNG',
#    '전압/NNG',
#    '기기/NNG',
#    '사용/NNG',
#    '전압/NNG',
#    '일치/NNG',
#    '공급/NNG',
#    '전압/NNG',
#    '전기/NNG',
#    '공급/NNG'],
#   '고객이 전기를 사용하고자 신청하는 경우에는 정당한 사유 없이 전기공급을 거절하지 않고 공급하여드립니다.다만 법령이 정하는 바에 따라 전기공급을 제한하는 때 또는 전기공급약관 이외의 조건(전기공급약관에명시된 표준전압 이외의 전압)으로 공급요청이 있을때 등 부득이한경우에는 전기사용 신청을 거절할 수있습니다.따라서 규정된 전압이외의 공급은 불가능합니다.'],
#  [76,
#   ['예비/NNG', '전력/NNG'],
#   '예비전력은 상용공급설비의 보수 또는 돌발사고로 전기공급이 불가능할 경우 예비전선로를 설치하여정전없이 계속 전기를 공급받고자 희망하는 경우 적용되는 계약종별입니다.(모든 계약종별의 상용전력에 적용할 수 있으며 상용전력이 저압인 경우도 포함)(1) 계약전력 및 요금적용전력 -계약전력은 예비전력과 상용전력을 동시에 사용할 수 없도록 시설되어 있는 경우를 제외하고는예비전력의 계약전력 및 요금적용전력은 원칙적으로 상용공급분과 동일하게 적용합니다. 다만, 예비전력 계량장치와 상용전력 계량장치를 따로 설치할 경우에는 예비전력의 계약전력 및요금적용전력을 상용전력과 구분하여 적용합니다.(2) 전기요금 예비전력은 상용공급변전소에서 상용공급전압과 같은 전압으로 공급하는 예비전력(갑),상용공급 변전소 이외의 변전소에서 공급하거나 상용공급전압과 다른 전압으로 공급하는 예비전력(을)로구분됩니다. 특별한 사정이 있는 경우 예비전력(갑)과 예비전력(을)을 동시에 공급가능합니다.가. 기본요금 : 예비전력(갑)은 전기사용 유무와 관계없이 상용계약종별 기본요금 단가에 예비전력의요금적용전력을 적용하여 산정한 금액의 5%(당사선로의 경우) 또는 2%(고객소유선로의 경우),예비전력(을)은 10%(당사선로의 경우) 또는 6%(고객소유선로의 경우)로 합니다.이 때 예비전력의 공급전압이 상용전력의 공급전압과 다를 경우에는 예비전력의 공급전압에 해당하는계약종별의 기본요금 단가를 적용합니다.나. 전력량요금 : 상용전력에 대한 해당 계약종별의 전력량요금을 적용하지만 예비전력의 공급전압이상용전력의 공급전압과 다를 경우에는 예비전력의 공급전압에 해당하는 전력량요금을 적용합니다.다. 역 률 : 역률에 따른 요금의 추가 또는 감액은 예비전력의 특성(대체전력이므로 사용 시간이 적다)을고려하여 별도로 적용하지 않고 예비전력에 의하여 사용한 전력은 상시공급분에 의하여 사용한 것으로간주하여 상용전력에 포함하여 역률을 적용합니다.(3) 계량방법 예비전력은 상시공급분과 동일계량 또는 합성계량을 원칙으로 하되 예비전력의 계약전력이나 공급전압이상시공급분과 다를 경우에는 별도로 계량하며 상시 전선로와 예비전선로로부터 공급되는 전기가 동시에투입되지 않도록 고객시설 소유로 자동전환장치(ALTS)를 설치하여야 합니다.'],
#  [77,
#   ['전기/NNG',
#    '공급/NNG',
#    '약관/NNG',
#    '한국/NNG',
#    '전력/NNG',
#    '공사/NNG',
#    '내부/NNG',
#    '제정/NNG',
#    '규정/NNG',
#    '전기/NNG',
#    '사용자/NNG',
#    '불리/NNG',
#    '조건/NNG',
#    '강제/NNG',
#    '준수/NNG',
#    '전기/NNG',
#    '사업/NNG',
#    '독점/NNG',
#    '이용/NNG',
#    '횡포/NNG'],
#   '전기공급약관은 전기사용거래의 특성상 동형의 거래가 반복적, 계속적으로 되풀이되고 또한 전 국민을상대로 행하여지기 때문에 거래의 신속화와 능률화라는 관점에서 전기공급절차를 정형화한 것입니다.따라서, 일반적인 상거래에서의 약관과 마찬가지로 전기공급약관은 곧 전기사용거래에 관한 것이며,전기공급약관에 대한 고객의 인지여부와 관계없이 전기공급자와 전기사용자 양자에 대해 구속력을 가지게되는 것입니다.한전에서는 고객이 전기공급약관을언제든지 볼 수 있도록본사 또는 각 사업소에 비치하고있으며(전기사업법 제16조4항), 고객이 요청할 때는 전기공급약관을 교부하도록 하고 있습니다.'],
#  [78,
#   ['전기/NNG', '공급/NNG', '약관/NNG', '제정/NNG', '개정/NNG', '절차/NNG'],
#   '전기공급약관의 제정이나 개정절차는 공정거래를 통한 국민보호측면에서 전기사업법제16조(전기의 공급약관)에 명시되어 있습니다.구체적으로 한전이 전기공급약관개정(안)의 이사회 의결 후전기위원회의 심의를 거쳐 산업통상자원부 장관의 인가를 받아 제,개정이 이루어 지게 됩니다.'],
#  [79,
#   ['전기/NNG', '사용자/NNG', '명의/NNG', '변경/NNG'],
#   '□계약전력 5kW 이하 저압고객의 명의변경은 필요 구비서류는 없으며,`업무찾기(새창열림)`>사이버지점신청접수업무찾기에서 명의 변경을조회하셔서신청하시거나,고객센터(☎ 국번없이 123)로도 신청이 가능합니다.□계약전력 6kW이상 저압고객 명의변경은구비서류를 갖추시어 관할 한전방문,우편, Fax로 신청하시면 됩니다. ㅇ 소유자 명의로 신청할 경우 - 전기사용변경신청서(한전 양식)- 주민등록등본 또는 사업자등록증 사본(개인의 경우), 법인등기부등본 또는 사업자등록증 사본(법인의 경우) ㅇ 임차인 명의로 신청할 경우- 전기사용변경신청서(한전 양식) -임차인 신분증 사본 혹은 주민등록등본 - 임대차계약서 사본 - 사업자등록증 사본(세금계산서 발행고객) - 보증설정(20㎾이하 제외): 현금보증, 이행보증보험증권, 사용자 신용보증,연대보증 중 택일 ① 현금보증 : 통장사본, 예금주 신분증 사본② 사용자 신용보증 : 신용등급 6등급 이상인 개인만 가능 ③ 건물주 연대보증 : 건물주가 법인인 경우 법인의 대표자 또는 임원이 연대보증 가능 - 내방가능 : 연대보증서, 신분증 사본 - 내방불가 : 연대보증서(인감날인), 연대보증인 신분증 사본, 재산세 납부증명서, 인감증명서 원본 ④ 제3자 연대보증 : 신용등급 6등급 이상만 개인만 가능 - 내방가능 : 연대보증서, 신분증 사본, 재산세 납부증명서(영수증) - 내방불가 : 연대보증서(인감날인), 신분증 사본, 인감증명서 원본,재산세 납부증명서(영수증)□고압고객의 경우에는 다음의 구비서류를 갖추시어 관할 한전에 방문 또는우편, Fax로 신청하시면 됩니다. ㅇ 모고객 - 전기사용변경신청서(소유자 도장날인) - 전기요금 영수증, 건물주 신분증 사본 - 건축물관련서류(전자정부 열람 동의시 불요) - 사업자등록증 사본(산업용, 세금계산서 발행고객) - 보증 설정(20㎾이하 제외) ㅇ자고객 - 전기사용변경신청서 (소유자 도장날인) - 전기요금 영수증, 건물주와 사용자 신분증 사본 - 건축물 관련서류 (전자정부 열람 동의시 불요) - 사업자등록증(산업용, 세금계산서발행고객) - 전기사용계약서(변압기 공동이용고객) - 보증 설정(20㎾이하 제외)※전기사용변경신청서 이면의 행정정보 공동이용에 대한 사전동의서에 고객이동의할 경우주민등록등본, 건축허가서는 제출하지 않으셔도 됩니다.※ 이미 보증금이 설정된 고객의 명의 변경시는 신 고객명의로 신규 보증설정 하여야 합니다.'],
#  [80,
#   ['부친/NNG',
#    '사망/NNG',
#    '상속/NNG',
#    '주택/NNG',
#    '경우/NNG',
#    '전기/NNG',
#    '전화/NNG',
#    '사용/NNG',
#    '신청/NNG'],
#   '상속, 증여, 기업합병 및 취득에 의하여 고객변경이 있는 경우에는, 신고객은 한전에 대하여 전기사용에 관련된 구고객의 모든 권리의무를 승계한다는 조건의 명의변경 절차에 의하여 별도의 전기사용 신청없이 계속 전기를 사용할 수 있으며 명의변경 신청방법은 주택용전력 등 한전에서 따로 정하는 경우에는 전화(국번없이 123번) 또는 구두로 신청할 수 있습니다.※ 주택용 및 계약전력 5kW 이하 고객의 명의변경은 한전 `업무찾기(새창열림)`>사이버지점신청접수업무찾기에서 명의 변경을 검색하신 후신청이 가능합니다.'],
#  [81,
#   ['매매/NNG',
#    '임대차/NNG',
#    '이사/NNG',
#    '전기/NNG',
#    '사용자/NNG',
#    '경우/NNG',
#    '명의/NNG',
#    '변경/NNG',
#    '전기/NNG',
#    '요금/NNG',
#    '정산/NNG',
#    '하나/NNG'],
#   '매매 등으로 전기사용자가 변경되는 경우 신고객과 구고객은 그 변경내용을 발생후 14일 이내에 한전에 통지하여야 합니다.매매, 임대차 등에 의해서 고객이 변동되고 신고객이 명의변경에 따른 사용자별 요금 구분청구를 신청할 경우에는 변동일을 기준으로 신,구고객별로 각각 계산하여 청구하게 되므로 구고객의 전기요금을 신고객이 납부하실 필요가 없습니다.명의변경 신청은 구고객의 이사일 하루전 한전 근무시간까지 아래의 구비서류를 갖추시어 관할 한전에 직접 내방또는 우편이나 fax로 신청하시면 됩니다.(단, 1주택 수가구 및 종합계약아파트 고객은 신청불가)구비서류가. 계약전력 5kW 이하 고객 (전화신청 가능)* 소유자로 변동된 경우 - 전기사용 변경 신청서 (한전양식)- 고객변동일을 입증할 수 있는 서류 : 매매계약서 또는 건물(토지)등기부 등본 등* 사용자로 변동된 경우- 전기사용변경신청서 (한전양식)- 고객변동일을 입증할 수 있는 서류 : 임대차계약서(법원 확정필인 날인)또는 사업자등록증 사본(전기사용장소와 동일주소지 사업장)나. 계약전력 6Kw이상 고객* 소유자로 변동된 경우- 전기사용변경신청서(한전양식)- 매매계약서 또는 건물(토지)등기부 등본 등* 사용자로 변경된 경우- 전기사용변경신청서(한전양식) : 소유주 동의 날인- 사용자 주민등록등본 (또는 법인 등기부등본)- 고객변동을 확인할 수 있는 서류 : 임대차계약서, 건축물대장- 계약전력 20kw 초과 고객의 경우 전기요금 보증서류 (현금 원칙, 고객희망시 이행보증보험, 지급보증 및 연대보증으로 가능)- 소유주 주민등록증 사본 (또는 법인 인감증명원) - 사업자등록증 사본(필요시)다. 나 의 경우저압으로 공급받는 고객은 소유주동의 날인과 소유주 관련 서류는 생략 가능☞ 변동일 이후에 사용자별 요금 구분청구를 신청할 경우에는 미납요금에 한하여 신ㆍ구고객별로 각각 계산하여 청구합니다. (변동일이 속한 월의 신ㆍ구고객별 사용전력량은 고객과 한전이 협의 결정합니다.)'],
#  [82,
#   ['이메일/NNG', '청구서/NNG', '상/NNG', '고객/NNG', '명이/NNG', '실제/NNG', '수정/NNG'],
#   '이메일청구서상 고객명은 한전 고객DB상의 고객 명의를 그대로 보여주는 것입니다. 만일 고객명이 틀리다면 명의변경 신청을 하셔야 합니다. 계약전력 5kW 이하 고객의 명의변경 신청의경우에는 별다른 첨부서류 없이`업무찾기(새창열림)`>사이버지점신청접수업무찾기에서 명의 변경을 조회하셔서 신청이 가능합니다.단,세금계산서 발행을 위해서는 관련서류(사업자등록증)가 필요합니다. 계약전력 6kW이상 소유자인 경우의명의변경 신청은 구비서류와 함께 관할사업소로 신청하셔야 합니다.'],
#  [83,
#   ['사업자/NNG',
#    '등록증/NNG',
#    '사본/NNG',
#    '제출/NNG',
#    '요청서/NNG',
#    '공장/NNG',
#    '한전/NNG',
#    '사업자/NNG',
#    '등록증/NNG',
#    '사본/NNG',
#    '제출/NNG'],
#   '산업용 고객 등 매월 세금계산서를 교부받은 고객은 변경사항이 발생할 시 거래시기가 속하는달의 다음날 10일까지 그 내용을 한전에 신고하여야 합니다.만일 한전이 요청한 사업자등록증 확인서류 제출을 거절또는 지연하거나, 부실자료를 제출함으로서 한전이 불명가산세를 부담하였을 경우,그 금액을 당해고객이 배상하셔야 합니다.'],
#  [84,
#   ['자동차/NNG',
#    '관리법/NNG',
#    '폐차장/NNG',
#    '기타/NNG',
#    '사업/NNG',
#    '산업용/NNG',
#    '전력/NNG',
#    '적용/NNG',
#    '자동차/NNG',
#    '정비/NNG',
#    '업체/NNG',
#    '산업용/NNG',
#    '요금/NNG',
#    '적용/NNG'],
# ...
#  [312,
#   ['건축/NNG',
#    '허가/NNG',
#    '첨부/NNG',
#    '불가능/NNG',
#    '지역/NNG',
#    '지장/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '이설/NNG',
#    '업무/NNG',
#    '처리/NNG',
#    '방법/NNG'],
#   '건축허가서 첨부가 불가능한 지역의 지장배전선로 이설에 대하여는 건축행위 및 지장을객관적으로 증명할 수 있는 행정기관의 확인 및 현장사진 등으로 건축허가를 대신할 수 있습니다.'],
#  [313,
#   ['건물/NNG',
#    '법정/NNG',
#    '격/NNG',
#    '거리/NNG',
#    '확보/NNG',
#    '간판/NNG',
#    '설치/NNG',
#    '안전사고/NNG',
#    '우려/NNG',
#    '배전/NNG',
#    '선로/NNG',
#    '이설/NNG',
#    '요청/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '부담/NNG',
#    '누/NNG'],
#   '한전에서는 전기안전사고 방지를 위하여 안전거리를 철저히 지키고 있습니다. 그러나고객의 사정으로배전선로 이설을 요청하시면 고객께서 이설비용을 부담하셔야 합니다.'],
#  [314,
#   ['택지/NNG',
#    '개발/NNG',
#    '촉진법/NNG',
#    '의거/NNG',
#    '승인/NNG',
#    '택지/NNG',
#    '개발/NNG',
#    '사업/NNG',
#    '지구/NNG',
#    '지장/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '택지개발사업 등 법률에 정한 사업시행시 지장배전선로 이설공사비는 당해 법률의 손실보상 규정에 따라 이설되는 설비는 이설비용을, 철거만 되는 설비에 대하여는 철거비용 및 손실보상금을 요청자인 사업시행자가 부담합니다.ㅇ손실보상규정내용 : 사업시행자가 시행 지역안에 있는 건축물 및 장애물 등을 이전, 제거할 경우 그 처분으로 인하여 손실 받은자가 있을때에는 시행자가 그 손실을 보상하여야 함.ㅇ주요대상사업：택지개발사업, 토지구획 정리사업, 도시재개발사업, 주택건설촉진법 적용 사업, 도시계획법 적용사업,도시철도사업,농어촌정비사업, 토지수용사업 등'],
#  [315,
#   ['개인/NNG',
#    '소유지/NNG',
#    '전주/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '개인/NNG',
#    '부담/NNG',
#    '이유/NNG'],
#   '공익기업으로서 한전의 책무는 국민편의 생활에 필수불가결한 전기에너지를 원활히 공급하는 것인바,이러한 방대한 전력사업을 추진하기 위하여 발전소에서 부터 송변전 설비 전주를 비롯한 각종 배전설비가전국 방방곡곡을 방대하게 상호연결하고 있으므로 사유지를 경과하지 않을 수 없습니다.이러한 방대한 전력공급 설비를 관리 유지함에 있어서는 고객 즉 국민 모두의 절대적인 협조가 절실합니다.전력설비를 공급함에 있어 무보상 미협의를 사유로 하여 이설을 무작정 요구하고 그 이설비용을 한전에서 모두 부담하게 된다면 그 비용은 곧 전기요금으로 전가되어 국민 모두에게 큰 부담으로 돌아가게 되는 것입니다.비록 전주가 사유지에 건주되어 있다하더라도 개인의 전기사용 신청으로 전용으로 공급하고 있는 경우, 개인의사유지 활용에 별 불편이 없는 경우, 미관상의 이유 등으로 이설요청하는 경우에는 이설비용을 요청자가 부담하도록 하고 있습니다.'],
#  [316,
#   ['건물/NNG',
#    '증축/NNG',
#    '한전/NNG',
#    '직원/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '와의/NNG',
#    '측방/NNG',
#    '격/NNG',
#    '거리/NNG',
#    '미달/NNG',
#    '전선/NNG',
#    '이설/NNG',
#    '후/NNG',
#    '건물/NNG',
#    '증축/NNG',
#    '공사/NNG',
#    '하면서/NNG',
#    '위해/NNG',
#    '통지서/NNG',
#    '발부/NNG',
#    '경우/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '건물 신,증축 등으로 인하여 한전 배전선로와의 측방이격거리가 전기설비 기술기준에 규제된 것보다 미달되면 전기안전상의 문제로 재해가 발생할 우려가 있어 한전에서는 위해통지서를 발행합니다.이 경우에는 배전선로이설 등 적절한 조치를 취한 후 건축 공사를 하셔야 하며 이설비용은 건축주가 부담하셔야 합니다. (관련법령 : 건축법, 산업안전보건법)'],
#  [317,
#   ['건조물/NNG',
#    '신/NNG',
#    '증축/NNG',
#    '토지/NNG',
#    '형질/NNG',
#    '변경/NNG',
#    '공사/NNG',
#    '지장/NNG',
#    '전선로/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '사유지에 설치된 배전선로가 건조물 신증축을 전제로 한 토지형질 변경공사에 지장이되는 경우의 이설비용은 한전 부담입니다. 다만, 토지구획 정리사업으로 인한 토지형질변경에 따른 지장전주이설 비용은 토지구획정리 사업시행자가 부담하여야 합니다.'],
#  [318,
#   ['토지/NNG',
#    '구획/NNG',
#    '정리/NNG',
#    '사업/NNG',
#    '지구/NNG',
#    '내의/NNG',
#    '토지/NNG',
#    '소유자/NNG',
#    '건축/NNG',
#    '허가/NNG',
#    '서/NNG',
#    '첨부/NNG',
#    '지장/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '이설/NNG',
#    '요청/NNG',
#    '시/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '토지구획정리사업에 지장이 되어 토지구획 정리사업 시행자가 이설을 요청하는 경우의 이설 비용은 사업시행자가 부담하는 것이며, 토지구획정리사업 시행 지역내 일지라도 사유지내의 건조물 신증축에 지장이 되는 배전선로의 이설비용은 한전 부담입니다.'],
#  [319,
#   ['사유지/NNG',
#    '내/NNG',
#    '통과/NNG',
#    '전선로/NNG',
#    '건조물/NNG',
#    '신/NNG',
#    '증축/NNG',
#    '지장/NNG',
#    '건조물/NNG',
#    '신/NNG',
#    '증축/NNG',
#    '대지/NNG',
#    '지형/NNG',
#    '변경/NNG',
#    '축대/NNG',
#    '건조/NNG',
#    '전선로/NNG',
#    '지상/NNG',
#    '고가/NNG',
#    '미달/NNG',
#    '경우/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '전선로가 건조물의 신증축에 지장되어 토지소유자 또는 건축주가 요청하여 이설하는 경우의이설공사비 는 한전이 부담합니다.사유 토지내에서 시행하는 건조물 신증축에 수반하는 축대담장공사 등은 건조물 설치의 부대공사이므로 이로 인해 필요하게 된 조치(지상고 유지 전선로 이설)에 요하는 비용도 한전에서부담합니다.참고--------------------------------------1. 건조물이란 건축법 제2조 제2호에서 규정한 건축물을 말하며 이설요청시에는 행정기관의건축허가 신고관련 서류를 첨부하여야 합니다.2. 건조물 신증축에 지장이라 함은 다음의 경우를 말합니다. 가. 배전선로가 건조물의 신증축부지내에 위치하여 건조물 신증축에 직접 지장이 되거나 대문, 창고, 주차장 등 건조물의 효용을저해하는 경우나. 신증축 부지내의 배전선로와 건조물 사이의 이격거리가 전기설비 기술기준에관한 규칙에 미달 되는 경우3. `건조물의 신증축 부지`란 행정관서의 건축허가, 신고관련 서류상의 대지를 말합니다.4. 배전선로가 건조물의 신증축 부지내에 위치한 경우는 지지물이 신증축 부지내에 시설되었거나전선이 신증축 부지를 통과한 경우입니다.'],
#  [320,
#   ['논둑/NNG',
#    '설치/NNG',
#    '전주/NNG',
#    '트랙터/NNG',
#    '이설/NNG',
#    '요청/NNG',
#    '설비/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '농경지내에 설치된 배전선로가 다음 각호에 정한 농경지 활용에 지장이 되어 토지소유자가이설을 요청하는 경우 이설비는 한전이 부담합니다.가. 구획정리 및 개전 또는 개답나. 비닐하우스 설치다. 트랙터, 콤바인 등의 농기계 사용(논에 한함)위의 규정에도 불구하고 다음 각호에 해당하는 경우의이설비는 고객이 부담합니다.가. 농경지의 둑이나 농로에 설치된 전선로를 구획정리 또는 농기계 출입이외 사유로 지장이 되어이설 요청하는 경우(둑이나 농로에 근접하여 시설된 경우 포함)나. 전선로가 시설된 토지에 관정 및 농사용 전력공급을 위하여 설치된 전선로를 당해토지의 활용에지장이 되어 이설요청하는 경우다. 경지정리 대상지역의 토지에 설치된 전선로를 이설요청하는 경우(경지정리시 한전부담 이설)라. 토지소유자와 협의 보상하여 설치된 전선로를 이설요청하는 경우마. 토지소유자의 요청에 의하여 한전 부담으로 이설된 전선로를 동일소유자가 재이설 요청하는 경우'],
#  [321,
#   ['개설/NNG',
#    '도로/NNG',
#    '설치/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '도로/NNG',
#    '공사/NNG',
#    '지장/NNG',
#    '경우/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '부담/NNG'],
#   '도로법, 농어촌 도로정비법 및 국토의 계획및 이용에 관한법에 의한 도로공사의 경우,도로관리청에서 시행하는 도로공사에 지장이 되는 배전선로가 도로점용료 1/2의 금액을감면받은 경우의 이설비용은 한전이 부담하며, 다른 공사 또는 행위로 인하여 필요하게된 도로공사에 지장이 되는 배전선로의 이설비용은 점용료 감면여부에 관계없이 도로공사원인을 유발한 자가 부담합니다. 다만, 도로구역으로 고시는 되었으나 개설되지 않은도로부지(신설 또는 확장부지)에 설치된 배전선로가 도로공사에 지장되는 경우의 이설비용부담주체는 다음과 같이 결정합니다.- 배전선로가 도로 고시 이전에 설치된 경우에는고객 부담- 배전선로가 도로 고시 이후에 설치된 경우에는 한전 부담'],
#  [322,
#   ['사유지/NNG',
#    '도로/NNG',
#    '경계선/NNG',
#    '설치/NNG',
#    '전주/NNG',
#    '아파트/NNG',
#    '건물/NNG',
#    '신축/NNG',
#    '지장/NNG',
#    '이설/NNG',
#    '경우/NNG',
#    '이설/NNG',
#    '비용/NNG',
#    '누/NNG',
#    '부담/NNG'],
#   '전주가 사유지와 도로경계선에 건주되었다 하더라도 전주일부가 사유지를 점유하고있고 전주이외의 배전시설물이 사유지를 통과함으로 인하여 아파트 신축에 지장이되어 이설할 경우의이설비용은 한전이 부담합니다.'],
#  [323,
#   ['전선/NNG', '시내/NNG', '곳곳/NNG', '미관상/NNG', '땅/NNG', '밑/NNG', '시설/NNG'],
#   '전주 없이 전선을 땅속으로 가설하는 공사를 지중화공사라고 합니다. 지중화공사는가공전선로에 비하여 전력공급 신뢰도면이나 도시미관, 감전사고방지 등 여러가지장점이 있으나 공사비가 가공전선로에 비하여 약 5~7배의 막대한 금액이 소요되는단점이 있습니다. 그래서 한전에서는 가공설비 유지 보수 및 확충이 기술적으로곤란한 지역을 우선으로 지중화공사를 추진하고 있습니다.'],
#  [324,
#   ['배선/NNG', '차단기/NNG', 'N/OL', 'F/OL', 'B/OL', '무엇/NNG'],
#   '배선용차단기(N.F.B)는 교류 600V 이하, 또는 직류 750V 이하의 저압 옥내회로에 과부하나단락(합선)이 일어난 경우 전원으로부터 회로를 자동 차단하여 보호하는 개폐장치로써 휴즈가없기 때문에 No Fuse Breaker라고도 합니다. 소형이며 조작이 안전하고 휴즈를 갈아 끼울필요가 없기 때문에 카바나이프 스위치(두꺼비집)대신에 널리 사용되고 있습니다.'],
#  [325,
#   ['전기/NNG', '공사/NNG', '사용/NNG', '자재/NNG', '사용/NNG'],
#   '전기공사에 사용하는 모든 자재는 정부나 공신력 있는 기관에서 보증하고 인정하는 (KS), (KC), (K), (전), (품), (검), (Q), (열)등이 표시된 형식승인 규격자재를 사용하셔야 안전합니다.값이 싸다고 불량자재를 사용하시는 일은 매우 위험하오니 반드시(KS), (KC), (K), (전), (품), (검), (Q), (열) 자 등이 표시된 자재인가를 확인하신 다음에 구입하여야 하겠습니다.'],
#  [326,
#   ['한전/NNG',
#    '배/NNG',
#    '전선로/NNG',
#    '운영/NNG',
#    '기존/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '보강/NNG',
#    '공사/NNG',
#    '고객/NNG',
#    '부담/NNG',
#    '시설/NNG',
#    '부담금/NNG',
#    '제외/NNG',
#    '기존/NNG',
#    '공급/NNG',
#    '설비/NNG',
#    '보강/NNG',
#    '경우/NNG'],
#   '신.증설 고객을 위한 전기공급설비공사시 기존 공급설비의 보강공사를 동시에 시공할 경우,기존공급설비 보강부분의 공사비는 한전에서 부담하며 기존공급설비를 보강하는 경우는 다음과 같습니다.(1) 기존 배전선로의 교체 또는 변경을 요하는 경우(2) 부하분리공사를 요하는 경우(3) 전압강하방지 및 보상공사를 요하는 경우(4) 단상 2선식 220V 공급을 위한 1선첨가공사를 요하는 경우'],
#  [327,
#   ['전기/NNG', '기기/NNG', '접지/NNG', '이유/NNG'],
#   '접지한다는 것은 전력설비, 통신설비, 전기기기 등을 대지(지구)와 전기적으로 결합시켜대지의 전위(전압)와 동일한 상태로 만드는 것입니다. 지구는 아무리 많은 전류가 흘러들어가더라도 지구자체의 전위는 변하는 일이 없어 상시 전위는 0(Zero)을 유지하게됩니다. 정상상태에서 전기기기는 전기가 충전되어 있어도 충전부와 외함간에 절연이되어 있어 기기외함을 만져도 전기가 통하지 않으나 절연이 불량하여 외함에 누전이되면 대지와 기기외함간에 전압이 나타나게 됩니다. 이때 인체가 외함에 접촉하게되면 외함인체대지를 통해 전기가 흐르기 때문에 감전이 됩니다. 외함이 접지되어있으면 누전되는 전류가 대지로 직접 흘러 외함과 대지와의 사이의 전압은 0볼트에가까워 접촉되어도 전류가 흐르지 않아 감전을 면하게 됩니다. 또한 이동하여 사용하는전기기계 기구의 금속제 외함의 접지는 접지선을 사용하여야 합니다.'],
#  [328,
#   ['접지/NNG', '공사/NNG', '접지/NNG', '저항/NNG', '유지/NNG'],
#   '접지공사별 접지저항은 다음값 이하로 유지하여야 합니다.접지공사별 접지저항접지공사의 종류접지저항치제1종 접지공사10옴제2종 접지공사변압기의 고압측 또는 특별고압측 전로 1선지락 전류값을 150으로 나눈값 이하의 저항값이어야 합니다. 단, 고압 또는 3만6천볼트 이하 특별고압전로가 저압측 전로와 혼촉에 의하여 대지전압이 150볼트를 넘는 경우로서 1초를 넘고 2초 이내에 자동적으로 고압측 또는 3만5천볼트 이하의 특별고압전로를 차단하는 장치를 설치할 때는 300, 1초 이내에 자동적으로 고압전로 또는 사용전압이 3만5천볼트 이하의 특별 고압전로를 차단하는 장치를 설치할 때는 600으로 나눈 값 이하의 저항값이어야 합니다.제3종 접지공사100옴특별 제3종 접지공사10옴'],
#  [329,
#   ['옥내/NNG', '배선/NNG', '굵기/NNG', '얼마/NNG'],
#   '옥내배선은 사용부하에 따라 허용전류를 초과하지 않도록 적정 굵기 이상의 전선을 사용해야하며, 허용전류는 전선의 종류, 배선방법등에 따라 달라지므로세부적인 사항은 인근의 전기공사업 면허를 가진 업체에 문의하시기 바랍니다.'],
#  [330,
#   ['절연/NNG',
#    '저항/NNG',
#    '옥내/NNG',
#    '절연/NNG',
#    '저항/NNG',
#    '얼마/NNG',
#    '이상/NNG',
#    '유지/NNG'],
#   '옥내의 전기설비는 비닐, 고무, 면 등 절연체로 피복되어 있습니다. 따라서 절연저항이란절연체의 절연상태를 측정하는 것으로 절연된 두 물체간에 전압을 가했을 때 표면과 내부에약간의 누설전류가 흐릅니다. 이때 가한 전압과 누설전류의 비(인가전압류)를절연저항(Insulation resistance)이라 하고 그 측정은 절연저항계(Megger)를 사용하는데절연저항의 단위는 메가오옴(MΩ)으로 표시하며 보통 전압종별에 따라 아래의 절연저항계(Megger)를사용합니다.ㅇ 특별고압회로：2,000V메거ㅇ 고압회로：1,000V메거ㅇ 저압회로：500V메거 옥내 절연저항은 누설전류가 허용한계를 넘지 못하도록 규제하기 위한 것으로다음값 이상을 유지하도록 해야 합니다.절연저항전로의 사용전압의 구분절연저항치400볼트 이하대지전압이 150볼트이하인 경우0.1메가옴대지전압 150볼트이상~300볼트이하 0.2메가옴기타0.3메가옴400볼트이상0.4메가옴'],
#  [331,
#   ['접지/NNG', '공사/NNG', '접지선/NNG', '굵기/NNG'],
#   '▣ 사용전검사 고객이 자가용 전기설비를 설치하였을 경우에는 전기안전관리자를 선임하여 시도지사에게 공사계획신고(인가)를 하고(받아서) 시도지사가 발행하는 공사계획 신고수리서(인가서) 사본을 첨부하여 한국전기안전공사에 사용전검사를 신청하여 받은 후 사용전 검사필 확인증(현장발행)을 관할 한전지점에 제출하시면 됩니다. ※ 수전설비의 일부가 완성되어 그 완성된 설비만을 사용하고자 하는 경우는 1공장 500kW에 대하여 부분검사를 신청할 수 있습니다.가. 구비서류 - 사용전검사신청서(전기사업법 시행규칙 별지 제36호 서식) 1부 - 공사계획인가(신고)서 사본 1부 (단, 인가(신고)서를 통보받은 경우 신고서 는 생략) - 전기 수용설비 단선결선도(전압 1천볼트 이상) 1부나. 신청시기 : 검사를 받고자 하는 날의 7일 전까지 신청다. 사용전검사의 기준 - 공사계획 신고내용과 현장설비의 일치(적합) 여부 - 전기설비가 기술기준에 적합한지의 여부 - 산업자원부장관이 검사에 필요하여 정하는 사항(시험성적 등의 확인)의 확인 등라. 준비사항 - 전기안전관리담당자와 시공업체 책임기술자(설비별 시공업체가 다를 경우 각각의 시공업체 책임기술자) - 고압이상 전기기계기구의 시험성적서 - 발전기의 부하운전시험 준비 - 시험계측장비에 필요한 사용전원 '],
#  [332,
#   ['전주/NNG', '위/NNG', '땅속/NNG', '접지선/NNG', '접촉/NNG', '위험/NNG'],
#   '접지선은 선로사고시에 많은 전류가 흐를 때를 대비하고 선로의 안정도를 높이기 위하여시설하여 놓은 것입니다. 평상시에 낮은 전압으로 충전되어 있는 경우도 있고 사고시에는특히 위험하니 만지지 말아야 합니다. 이 접지선은 안전을 위하여 땅속 75cm에서부터지상 2m부분까지 전기가 통하지 않는 물체로 덮어 놓도록 되어 있습니다. 어린이들의손닿을 위치에 전선이 보일 경우는 만지지 못하게 하시고 한전에 신고해 주시기 바랍니다.'],
#  [333,
#   ['고압/NNG',
#    '이상/NNG',
#    '공급/NNG',
#    '전압/NNG',
#    '변압기/NNG',
#    '결선/NNG',
#    '방법/NNG',
#    'Y/OL',
#    '공급/NNG',
#    '선로/NNG',
#    '구분/NNG',
#    '공급/NNG',
#    '전압/NNG',
#    '별/NNG',
#    '결선/NNG',
#    '방식/NNG'],
#   '전원부하의 결선방식으로는 결선과 Y(Star)결선방법이 있습니다. 결선이라 함은 변압기 상별결선이 모양이라는데서 유래하였으며 전선은 3선이 필요합니다. Y결선은 Y의 중심점을 연결하는 중성선이 필요하며 3상4선식 380V 공급방식과 같이 중성선을 이용하여 상전압으로도 이용하고 있습니다. 고압이상의 전압중 선로는 6,600V, 22,000V, 66,000V, 154,000V, 345,000V, 765,000V이며 Y선로는 22,900V입니다..'],
#  [334,
#   ['전선/NNG', '전선로/NNG'],
#   '전선은 전기를 보내기 위한 전기도체를 말하며, 전선로는 전선과 전선을 지지해 주는지지물 등을 포함하여 말할 때 사용됩니다.'],
#  [335,
#   ['전자파/NNG', '인체/NNG', '영향/NNG'],
#   '매우 강한 세기의 전자파에 노추된다면 우리 몸의 세포나 조직들이 영향을 받을 수 있습니다. 하지만, 일상생활에서 발생하는 극저주파 자계는 그 강도가 매우 미약하기 때문에 노출에 따른 인체 건강에 대한 영향은 과학적으로 밝혀진 바 없습니다.'],
#  [336,
#   ['송/NNG',
#    '변전/NNG',
#    '설비/NNG',
#    '발생/NNG',
#    '전자파/NNG',
#    '유해/NNG',
#    '논란/NNG',
#    '현황/NNG',
#    '대책/NNG'],
#   '전력설비 전자파의 국내기준은 산업통상자원부의 고시에 따라 전기설비기술기준 제 17조에 명시되어 있습니다(자계 : 83.3&mu;T). 또한 세계보건기구(WHO)에서는 국제 비전리방사선보호위원회(ICNIRP)의 가이드라인의 준용을 권고하고 있습니다.(자계 : 200&mu;T) '],
#  [337,
#   ['송/NNG', '전선/NNG', '로란/NNG', '무엇/NNG'],
#   '송전선로란 발전소에서 발전한 전력을 전기사용장소까지 전달하는 전기시설물로서 가공이나지중으로 구성되어 있습니다. 이와 같은 송전선로를 통해 전력을 보낼시 송전전압이 낮으면전류가 증대되어 전력손실이 많아지거나 전선규격이 굵어져야 합니다. 따라서, 송전전압을높여서 사용함으로서 전력손실이나 전선의 굵기를 줄일 수 있으며 전력의 대용량 전송도가능하게 됩니다. 현재 사용하고 있는 한전의 송전전압은 66kV, 154kV, 345kV, 765kV인데, 70년대후반부터 345kV 송전선이 건설되며 대용량 전력수송의 근간을 이루고 있습니다.이는 154kV 송전전압에 비해 약 5배의 전력수송 능력이 있어 상대적으로 송전선을 적게 건설하는효과를 가져와 국토의 효율적 이용에도 크게 기여하고 있습니다.한전에서는전력손실의 감소 및 보다 대용량의 전력수송을 위해 765kV급 송전선로를추진하여 현재 운영하고 있습니다.'],
#  [338,
#   ['송전/NNG', '선로/NNG', '아래/NNG', '안전/NNG', '작업/NNG', '거리/NNG', '정도/NNG'],
#   '안전이격거리는 아래와 같습니다만, 송전선로와 인접하여 작업이 이루어질 경우에는 반드시 사전에 관할 한전사업소에 연락하여 주시기 바랍니다.안전이격거리송전전압안전 이격거리22kV2.0m 이상66kV2.1m 이상154kV3.2m 이상345kV5.5m 이상'],
#  [339,
#   ['변전소/NNG', '기능/NNG', '곳/NNG'],
#   '변전소라함은 구외로부터 보내오는 66kV, 154kV, 345kV 등의 송전전압을 구내에 시설한 변압기등에 의하여 전압을 높이거나 낮추어 다시 구외로 보내는 장소로서 한전이 소유하는 것을 말합니다.전압을 변환하는 방법은 전자유도작용의 원리를 이용하여 만든 변압기를 사용하는데 변압기에는철심에 코일을 감아서 만든 것입니다. 또한 변전소는 변압기 이외에 차단기, 단로기, 모선 등으로구성되어 있습니다. 그러나 전압을 낮춰서 자기의 공장 또는 건물내에만 쓰는 경우는 변전소라하지 않고 수전실, 변전실 등의 명칭을 쓰고 있습니다.'],
#  [340,
#   ['사이버/NNG',
#    '지점/NNG',
#    '나의/NNG',
#    '고객/NNG',
#    '번호/NNG',
#    '등록/NNG',
#    '관리/NNG',
#    '방법/NNG'],
#   '개인고객의 경우 `고객번호관리(새창열림)`href=`https://cyber.kepco.co.kr/ckepco/front/jsp/MY/D/A/MYDAPP001.jsp`>MY KEPCO전기사용정보관리고객번호관리에서 고객번호 추가와 삭제가 가능합니다.이사 등으로 고객님의 전기사용 장소가 변경되었을 때에도 회원탈퇴하실 필요 없이 고객번호 관리를 통해 기존 고객번호를 삭제, 새로 이사간 장소의 고객번호를 추가하셔서전기요금 관련 유용한 정보를 제공받으실 수 있습니다.단, 고객번호 추가시고객번호의 계약자 정보(주민번호, 사업자번호, 법인번호 등 실제 등록된 정보)를 입력하여야 하며, 명의자가 이전 사용자로 되어 있거나 하여 명의변경이 필요한 경우 `사이버지점=`>사이버지점신청접수업무찾기에서 `명의 변경`을 검색하여 처리하시거나 한전 고객센터(국번없이 123)을 통해 명의변경 후이용하실 수 있습니다.'],
#  [341,
#   ['민원/NNG', '서식/NNG', '다운/NNG'],
#   '`서식자료실(새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/F/A/CYFAPP0015901.jsp`>사이버지점신청접수서식자료실에서 다운받으실 수 있습니다.인터넷으로 직접 신청가능한 민원을 확인하시려면 `업무찾기(새창열림)`>여기를 클릭하세요.'],
#  [342,
#   ['내가/NNG', '지역/NNG', '관할/NNG', '사/NNG', '업소/NNG', '위치/NNG', '연락처/NNG'],
#   '`전국사업소안내(새창열림)`href=`http://home.kepco.co.kr/kepco/CU/CUIBPP002/main.do.menuCd=FN120502`>고객지원전국사업소안내 에서 확인하실 수 있습니다.해당 사업소명이나 위치 및 연락처를 클릭하시면 세부 업무별 담당자 연락처 조회도 가능합니다.'],
#  [343,
#   ['아이디/NNG', '비밀/NNG', '번호/NNG'],
#   '아이디 또는 비밀번호를 분실한 경우 `아이디비밀번호찾기(새창열림)`href=`https://cyber.kepco.co.kr/ckepco/front/jsp/ME/D/A/MEDAPP00101.jsp`>아이디 비밀번호 찾기로 가셔서 아래 3가지 방법 중 하나로 찾으실 수 있습니다.아이디를 먼저 찾으신 후 비밀번호 찾기가 가능합니다.1.회원정보 : 사이버지점 회원가입시 등록한 이메일주소 또는핸드폰 번호 이용 (다만, 회원가입시의 이메일 또는 핸드폰번호가 변경되었을 경우 2~4번 이용)2.본인명의 휴대폰: 회원 본인명의로 되어 있는 휴대폰 인증(회원명의와 이동통신사를 통한 본인 일치여부 확인)3. 아이핀 : 아이핀에 가입되어 있는 정보를 통해 본인 확인'],
#  [344,
#   ['민원/NNG', '신청/NNG', '현황/NNG', '확인/NNG'],
#   '`나의서비스조회(새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/F/A/CYFAPP0016001.jsp`>사이버지점신청접수나의서비스조회에서 사이버지점에서 신청한 민원 및 전화나 사업소 방문을 통한 민원처리 내역을 확인하실 수 있습니다.'],
#  [345,
#   ['사이버/NNG', '지점/NNG', '전기/NNG', '요금/NNG', '조회/NNG', '서비스/NNG', '이용/NNG'],
#   '사이버지점 전기요금은 간편조회와 상세조회로 나누어집니다. 개인정보 보보 강화를 위하여 간편조회 및 상세조회 서비스에 본인 인증절차가 도입되었습니다. 또한, 간편조회 이용을 위한 사전 신청 및 해지 절차는 폐지되었습니다.조회하시는 고객번호의 명의자 휴대폰 본인인증 또는 한전에 등록되어 있는(명의자 또는 지불자) 휴대폰 번호 인증 후 간편조회를 이용할 수 있습니다.※ 한전에 등록된 번호가 부정확하여 이용에 어려움이 있으신 경우 한전 고객센터(국번없이 123)로 문의하여 주시기 바랍니다.'],
#  [346,
#   ['전기/NNG', '공급/NNG', '약관/NNG'],
#   '전기공급약관은 `전력거래약관(새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/D/C/CYDCHP00101.jsp`>사이버지점제도약관전력거래약관 에서 확인하실 수 있습니다.'],
#  [347,
#   ['법인/NNG', '회원/NNG', '가입/NNG', '방법/NNG'],
#   '개인회원으로 가입하신 후, `기업서비스이용신청(새창열림)`href=`https://cyber.kepco.co.kr/ckepco/front/jsp/MY/C/A/MYCAPP001.jsp`>MY KEPCO기업서비스이용기업서비스이용신청에서 법인사이버지점 신규서비스 신청을하시면 이용가능합니다.<span class=`pointRe`>회사정보가 변경된 경우는`기본회사정보 수정(새창열림)`href=`https://cyber.kepco.co.kr/ckepco/front/jsp/MY/B/B/MYBBPP001.jsp`>기본회사정보 수정에서 수정 가능하며, 입력된 사업자번호로한전에 등록되어 있는고객번호에 대한 정보 조회가 가능합니다.※ 사업자번호 등록 후에도 <ahref=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/E/A/CYEAPP002.jsp`><font title=`상세조회(새창열림)` color=`#3366ff`>사이버지점조회납부상세조회에서 고객번호가 보이지 않는 경우는 `법인고객번호(새창열림)`href=`https://cyber.kepco.co.kr/ckepco/front/jsp/MY/D/A/MYDAPP002.jsp`>여기를 클릭하여 법인고객번호 하단의최신정보로 갱신을 눌러 주세요.'],
#  [348,
#   ['전기/NNG', '요금/NNG', '계산/NNG'],
#   '`전기요금계산기(새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/J/A/CYJAPP000.jsp`>사이버지점전기요금계산기에서 가능합니다.'],
#  [349,
#   ['아파트/NNG',
#    '관리/NNG',
#    '사무소/NNG',
#    '종합/NNG',
#    '계약/NNG',
#    '단일/NNG',
#    '계약/NNG',
#    '비교/NNG'],
#   '`아파트·오피스텔요금비교(새창열림)`href=`http://cyber.kepco.co.kr/ckepco/front/jsp/CY/J/D/CYJDPP00101.jsp`>사이버지점아파트오피스텔요금비교에서 가능합니다.※ 종합계약은 호별 요금을 계산하여 합산하는 방식이므로,단일계약아파트의 경우 종합계약과의 비교를 위해서는 호별 사용량을 엑셀양식에 넣어주셔야 합니다.'],
#  [350,
#   ['고객/NNG', '번호/NNG', '무엇/NNG', '확인/NNG'],
#   '○ 고객번호는 전기사용 계약단위별로 부여되는 고유번호입니다. 전기요금 청구서 우측 상단에서 확인하실 수 있으며 이를 통해 사이버지점에서 전기 사용 관련 유용한 정보를 제공받으실 수 있습니다.○ 만약 고객님의 전기요금이 아파트 관리비 청구서에 포함되어 청구된다면 아파트 전체를 하나의 고객번호로 한전과 계약한 경우로 이때, 세대별로 부여되는 고객번호는 없습니다. 다만, 대가족요금, 복지할인요금 등은 아파트 전체의 고객번호로 신청이 가능하오니 아파트 관리사무소나 한전 고객센터(국번없이 123)로 아파트 고객번호를 문의하시기 바랍니다.']]

# %%
# make model
    import multiprocessing
    cores = multiprocessing.cpu_count()
    d2v_faqs = doc2vec.Doc2Vec(
                                    vector_size=50,
                                    alpha=0.025,
                                    min_alpha=0.025,
                                    hs=1,
                                    negative=0,
                                    dm=1,
                                    window=3,
                                    dbow_words = 1,
                                    min_count = 5,
                                    workers = cores,
                                    seed=0,
                                    epochs=20
                                    )
    d2v_faqs.build_vocab(tagged_faqs)

    # train document vectors
    for epoch in range(50):
        d2v_faqs.train(tagged_faqs,
                                   total_examples = d2v_faqs.corpus_count,
                                   epochs = d2v_faqs.epochs
                                   )
        d2v_faqs.alpha -= 0.0025 # decrease the learning rate
        d2v_faqs.min_alpha = d2v_faqs.alpha # fix the learning rate, no decay

# %%
test_string = "전기요금을 자동이체하는 계좌에 잔액이 부족하면 어떻게 됩니까."
tokened_test_string = tokenize_kkma(test_string)
tokened_test_string
# Out:
# ['전기/NNG', '요금/NNG', '자동/NNG', '계좌/NNG', '잔액/NNG', '부족/NNG']

# %%
test_vector = d2v_faqs.infer_vector(tokened_test_string)
result = d2v_faqs.docvecs.most_similar([test_vector], topn=5)
for i in range(1):
    print("{}순위 {}번의 질문 [{}]".format(i+1, result[i][0], df_faq['제목'][result[i][0]]))
# Out:
# 1순위 264번의 질문 [전기요금을 자동이체하는 계좌에 잔액이 부족하면 어떻게 됩니까.]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# 성능 측정
raten = 1
found = 0
for i in range(len(df_faq)):
    tstr = df_faq['제목'][i]
    ttok = tokenize_kkma(tstr)
    tvec = d2v_faqs.infer_vector(ttok)
    re = d2v_faqs.docvecs.most_similar([tvec], topn = raten)
    for j in range(raten):
        if i == re[j][0]: found = found + 1

print("정확도 = {} % ({}/{} )  ".format(found/len(df_faq),found, len(df_faq)))
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 정확도 = 0.2962962962962963 % (104/351 )
